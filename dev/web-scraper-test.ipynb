# %% [markdown]
# ## Installs

# %%
# !pip install requests bs4
# Out:
# Requirement already satisfied: requests in /Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: bs4 in /Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages (0.0.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages (from requests) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: beautifulsoup4 in /Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages (from beautifulsoup4->bs4) (2.3.2.post1)

# %% [markdown]
# ## Setup

# %%
import logging
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup

# %%
logging.basicConfig(
    format='%(asctime)s %(levelname)s:%(message)s',
    level=logging.INFO)

# %%
class Crawler:

    def __init__(self, urls=[]):
        self.visited_urls = []
        self.urls_to_visit = urls

    def download_url(self, url):
        return requests.get(url).text

    def get_linked_urls(self, url, html):
        soup = BeautifulSoup(html, 'html.parser')
        for link in soup.find_all('a'):
            path = link.get('href')
            if path and path.startswith('/'):
                path = urljoin(url, path)
            yield path

    def add_url_to_visit(self, url):
        if url not in self.visited_urls and url not in self.urls_to_visit:
            self.urls_to_visit.append(url)

    def crawl(self, url):
        html = self.download_url(url)
        for url in self.get_linked_urls(url, html):
            self.add_url_to_visit(url)

    def run(self):
        while self.urls_to_visit:
            url = self.urls_to_visit.pop(0)
            logging.info(f'Crawling: {url}')
            try:
                self.crawl(url)
            except Exception:
                logging.exception(f'Failed to crawl: {url}')
            finally:
                self.visited_urls.append(url)

# %%
if __name__ == '__main__':
    Crawler(urls=['https://www.cadencebank.com/']).run()
# Out:
# 2023-05-24 14:59:35,521 INFO:Crawling: https://www.cadencebank.com/
# 2023-05-24 14:59:36,130 INFO:Crawling: #main
# 2023-05-24 14:59:36,131 ERROR:Failed to crawl: #main
# Traceback (most recent call last):
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 32, in run
#     self.crawl(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 23, in crawl
#     html = self.download_url(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 8, in download_url
#     return requests.get(url).text
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#main': No scheme supplied. Perhaps you meant http://#main?
# 2023-05-24 14:59:36,135 INFO:Crawling: https://www.cadencebank.com/
# 2023-05-24 14:59:36,621 INFO:Crawling:
# 2023-05-24 14:59:36,622 ERROR:Failed to crawl:
# Traceback (most recent call last):
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 32, in run
#     self.crawl(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 23, in crawl
#     html = self.download_url(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 8, in download_url
#     return requests.get(url).text
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '': No scheme supplied. Perhaps you meant http://?
# 2023-05-24 14:59:36,623 INFO:Crawling: https://www.cadencebank.com/about
# 2023-05-24 14:59:36,921 INFO:Crawling: https://www.cadencebank.com/about/careers
# 2023-05-24 14:59:37,373 INFO:Crawling: https://www.cadencebank.com/contact
# 2023-05-24 14:59:37,662 INFO:Crawling: https://www.cadencebank.com/find-a-location
# 2023-05-24 14:59:38,364 INFO:Crawling: #
# 2023-05-24 14:59:38,365 ERROR:Failed to crawl: #
# Traceback (most recent call last):
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 32, in run
#     self.crawl(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line
INFO:Crawling: https://www.cadencebank.com/insurance/industry-expertise
# 2023-05-24 15:00:33,880 INFO:Crawling: https://www.cadencebank.com/insurance/employer-solutions
# 2023-05-24 15:00:34,424 INFO:Crawling: https://www.cadencebank.com/insurance/online-services-and-resources
# 2023-05-24 15:00:34,913 INFO:Crawling: https://www.cadencebank.com/insights-and-articles/personal/guide-for-creating-monthly-budget
# 2023-05-24 15:00:35,327 INFO:Crawling: https://www.cadencebank.com/resource-center
# 2023-05-24 15:00:36,349 INFO:Crawling: https://www.cadencebank.com/thenewcadence
# 2023-05-24 15:00:37,121 INFO:Crawling: https://www.cadencebank.com/resource-center/faqs
# 2023-05-24 15:00:37,707 INFO:Crawling: https://www.cadencebank.com/resource-center/calculators-and-tools
# 2023-05-24 15:00:38,277 INFO:Crawling: https://www.cadencebank.com/resource-center/fraud-and-security-center
# 2023-05-24 15:00:38,844 INFO:Crawling: https://www.cadencebank.com/resource-center/videos
# 2023-05-24 15:00:39,133 INFO:Crawling: https://www.cadencebank.com/insights-and-articles#insightslanding_audience=Personal
# 2023-05-24 15:00:39,466 INFO:Crawling: https://www.cadencebank.com/insights-and-articles#insightslanding_audience=Business
# 2023-05-24 15:00:39,746 INFO:Crawling: https://www.cadencebank.com/insights-and-articles#insightslanding_audience=Commercial
# 2023-05-24 15:00:40,017 INFO:Crawling: https://www.cadencebank.com/insights-and-articles#insightslanding_audience=Insurance
# 2023-05-24 15:00:40,282 INFO:Crawling: https://www.cadencebank.com/insights-and-articles#insightslanding_content%20type=Podcast
# 2023-05-24 15:00:40,578 INFO:Crawling: https://online.cadencebank.com/ForgotPassword.aspx
# 2023-05-24 15:00:41,320 INFO:Crawling: https://online.cadencebank.com/ForgotUserID.aspx
# 2023-05-24 15:00:42,015 INFO:Crawling: https://online.cadencebank.com/RegistrationDisclosure.aspx
# 2023-05-24 15:00:42,748 INFO:Crawling: https://www.businesstrack.com/manage/landing
# 2023-05-24 15:00:42,911 INFO:Crawling: https://ipabcprod.fiservsco.com/WebCaptureWeb/
# 2023-05-24 15:00:43,159 INFO:Crawling: https://www2.transcard.com/ThemedLogin.aspx?customtheme=BANC
# 2023-05-24 15:00:43,511 INFO:Crawling: https://www.transcardgift.com/Account/Login?ReturnUrl=%2F
# 2023-05-24 15:00:43,756 INFO:Crawling: https://www.centresuite.com/centre?cadence
# 2023-05-24 15:00:44,124 INFO:Crawling: https://www.go-retire.com/cadencebank
# 2023-05-24 15:00:44,226 INFO:Crawling: https://clientpoint.fisglobal.com/tdcb/main/UserLogon?bankNumber=Z7
# 2023-05-24 15:00:44,487 INFO:Crawling: https://portal.cadencebank.com/SignOn.aspx
# 2023-05-24 15:00:44,689 INFO:Crawling: https://www.cadencebank.com/8monthcd?sc_trk=CDSpecialHeroClick
# 2023-05-24 15:00:45,025 INFO:Crawling: https://www.cadencebank.com/insights-and-articles/business/how-cadence-prioritizes-business-banking-relationships
# 2023-05-24 15:00:45,350 INFO:Crawling: https://www.cadencebank.com/insights-and-articles
# 2023-05-24 15:00:45,619 INFO:Crawling: None
# 2023-05-24 15:00:45,620 ERROR:Failed to crawl: None
# Traceback (most recent call last):
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 32, in run
#     self.crawl(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 23, in crawl
#     html = self.download_url(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 8, in download_url
#     return requests.get(url).text
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL 'None': No scheme supplied. Perhaps you meant http://None?
# 2023-05-24 15:00:45,621 INFO:Crawling: https://online.cadencebank.com/login.aspx
# 2023-05-24 15:00:47,909 INFO:Crawling: https://www.cadencebank.com/about/diversity-and-inclusion
# 2023-05-24 15:00:48,662 INFO:Crawling: https://www.cadencebank.com/about/community
# 2023-05-24 15:00:49,255 INFO:Crawling: https://www.cadencebank.com/about/history
# 2023-05-24 15:00:49,747 INFO:Crawling: https://www.cadencebank.com/about/leadership
# 2023-05-24 15:00:50,272 INFO:Crawling: https://www.cadencebank.com/about/news-and-stories
# 2023-05-24 15:00:51,030 INFO:Crawling: https://cadcdnprod01v2-daffhpb7b8cdfkhx.z01.azurefd.net/-/media/project/cadencebank/cadence/lenders/nmls-listing/nmls-monthly-listing-4-25-2023.pdf?rev=092233f3fbd1403a8be62b30d8d13824&hash=090901E4022F2816AE9775D7FAF19E11
# 2023-05-24 15:00:51,683 INFO:Crawling: https://ir.cadencebank.com/
# 2023-05-24 15:00:52,010 INFO:Crawling: https://itunes.apple.com/us/app/bancorpsouth-mobile/id469981191?mt=8
# 2023-05-24 15:00:52,927 INFO:Crawling: https://play.google.com/store/apps/details?id=com.bancorpsouth.android&hl=en
# 2023-05-24 15:00:53,238 INFO:Crawling: https://www.facebook.com/CadenceBank
# 2023-05-24 15:00:53,433 INFO:Crawling: https://www.instagram.com/CadenceBank
# 2023-05-24 15:00:54,086 INFO:Crawling: https://www.twitter.com/CadenceBank
# 2023-05-24 15:00:54,476 INFO:Crawling: https://www.linkedin.com/company/Cadence-Bank
# 2023-05-24 15:00:54,597 INFO:Crawling: https://www.youtube.com/user/CadenceBanking
# 2023-05-24 15:00:54,779 INFO:Crawling: https://www.cadencebank.com/policies-and-disclosures
# 2023-05-24 15:00:55,130 INFO:Crawling: https://www.cadencebank.com/about
# 2023-05-24 15:00:55,522 INFO:Crawling: https://www.cadencebank.com/about/vision-mission-and-values
# 2023-05-24 15:00:56,084 INFO:Crawling: https://cadcdnprod01v2-daffhpb7b8cdfkhx.z01.azurefd.net/-/media/project/cadencebank/cadence/pdfs/about/2022-esg-report.pdf?rev=24055d25c2ce4d6d802b5401ea171745&sc_lang=en&hash=647B0B7F03E5BF33BDC70EBE2145197B
# 2023-05-24 15:00:57,207 INFO:Crawling: https://www.cadencebank.com/about/careers
# 2023-05-24 15:00:57,490 INFO:Crawling: https://career8.successfactors.com/career?company=2203091P
# 2023-05-24 15:00:57,946 INFO:Crawling: https://career8.successfactors.com/career?company=2203091P
# 2023-05-24 15:00:58,252 INFO:Crawling: https://www.cadencebank.com/about/careers/life-at-cadence
# 2023-05-24 15:00:58,815 INFO:Crawling: https://www.cadencebank.com/about/careers/benefits
INFO:Crawling: https://www.cadencebank.com/insurance/business-solutions/umbrella-insurance
# 2023-05-24 15:02:28,074 INFO:Crawling: https://www.cadencebank.com/insurance/business-solutions/workers-compensation
# 2023-05-24 15:02:28,529 INFO:Crawling: https://www.cadencebank.com/insurance/employer-solutions/analytics
# 2023-05-24 15:02:29,001 INFO:Crawling: https://www.cadencebank.com/insurance/employer-solutions/benefits-administration
# 2023-05-24 15:02:29,668 INFO:Crawling: https://www.cadencebank.com/insurance/employer-solutions/benefits-strategy
# 2023-05-24 15:02:30,215 INFO:Crawling: https://www.cadencebank.com/insurance/employer-solutions/captive-solutions
# 2023-05-24 15:02:30,670 INFO:Crawling: https://www.cadencebank.com/insurance/employer-solutions/compliance-support-and-oversight
# 2023-05-24 15:02:31,348 INFO:Crawling: https://www.cadencebank.com/insurance/employer-solutions/employee-engagement-and-communication
# 2023-05-24 15:02:32,010 INFO:Crawling: https://www.cadencebank.com/insurance/employer-solutions/pharmacy-benefits-management
# 2023-05-24 15:02:32,466 INFO:Crawling: https://www.cadencebank.com/insurance/consumer-solutions
# 2023-05-24 15:02:33,090 INFO:Crawling: https://secure.consumerratequotes.com/ConsumerV2?id=56905
# 2023-05-24 15:02:33,284 INFO:Crawling: https://www.aspcapetinsurance.com/cadence#/start
# 2023-05-24 15:02:34,034 INFO:Crawling: https://www.travelinsured.com/agency/
# 2023-05-24 15:02:34,281 INFO:Crawling: https://www.cadencebank.com/insurance/online-services-and-resources/get-a-quote
# 2023-05-24 15:02:34,833 INFO:Crawling: https://saferhub.com/
# 2023-05-24 15:02:35,313 INFO:Crawling: https://apps.trustmineral.com/auth/login
# 2023-05-24 15:02:35,593 INFO:Crawling: https://www.lossfreerx.com/Foyer.aspx?guid=89629586-d8ef-4516-81c5-a2def69fdad5
# 2023-05-24 15:02:36,262 ERROR:Failed to crawl: https://www.lossfreerx.com/Foyer.aspx?guid=89629586-d8ef-4516-81c5-a2def69fdad5
# Traceback (most recent call last):
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/urllib3/connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/urllib3/util/ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='www.lossfreerx.com', port=443): Max retries exceeded with url: /Foyer.aspx?guid=89629586-d8ef-4516-81c5-a2def69fdad5 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 32, in run
#     self.crawl(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 23, in crawl
#     html = self.download_url(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 8, in download_url
#     return requests.get(url).text
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/adapters.py", line 563, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='www.lossfreerx.com', port=443): Max retries exceeded with url: /Foyer.aspx?guid=89629586-d8ef-4516-81c5-a2def69fdad5 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# 2023-05-24 15:02:36,266 INFO:Crawling: https://cadcdnprod01v2-daffhpb7b8cdfkhx.z01.azurefd.net/-/media/project/cadencebank/cadence/insurance/cd_2793094_i_storm_guide_220713.pdf?rev=5987feafd76f477ab4df367b274ce329&hash=F83821C6877D870939EF558B9A14602F
# 2023-05-24 15:02:42,114 INFO:Crawling: https://cadcdnprod01v2-daffhpb7b8cdfkhx.z01.azurefd.net/-/media/project/cadencebank/cadence/insurance/claims_reporting_guide_2_21_23.pdf?rev=eb8c1f79a485431eacb2da9cd937176c&hash=E6EB8E1277782AC16531FB7256A41A31
# 2023-05-24 15:02:43,709 INFO:Crawling: https://portal.csr24.com/mvc/Account/SignUp?AgencyKey=3363200
# 2023-05-24 15:02:44,099 INFO:Crawling: https://apps.thinkhr.com/login/
# 2023-05-24 15:02:45,181 INFO:Crawling: https://www.cadencebank.com/cdn-cgi/l/email-protection#692a06071a1c040c1b3a06051c1d0006071a390c1b1a060708053b001a02280d1f001a061b1a290a080d0c070a0c00071a1c1b08070a0c470a0604
# 2023-05-24 15:02:45,241 INFO:Crawling: https://www.cadencebank.com/insurance/careers
# 2023-05-24 15:02:45,719 INFO:Crawling: https://www.facebook.com/CadenceIns/
# 2023-05-24 15:02:45,925 INFO:Crawling: https://www.linkedin.com/company/CadenceInsurance
# 2023-05-24 15:02:46,010 INFO:Crawling: https://www.cadencebank.com/insights-and-articles/personal/difference-between-debit-and-credit-cards
# 2023-05-24 15:02:46,301 INFO:Crawling: https://www.frbsf.org/cash/publications/fed-notes/2021/may/2021-findings-from-the-diary-of-consumer-payment-choice/
# 2023-05-24 15:02:46,650 INFO:Crawling: https://www.cadencebank.com/insights-and-articles/personal/how-do-credit-cards-work
# 2023-05-24 15:02:47,046 INFO:Crawling: https://consumer.ftc.gov/articles/lost-or-stolen-credit-atm-debit-cards
# 2023-05-24 15:02:50,580 INFO:Crawling: https://www.cadencebank.com/resource-center/calculators-and-tools/credit-card-payoff-calculator
# 2023-05-24 15:02:51,124 INFO:Crawling: https://www.cadencebank.com/insights-and-articles/personal/personal-loan-vs-line-of-credit
# 2023-05-24 15:02:51,486 INFO:Crawling: https://www.cadencebank.com/insights-and-articles/personal/what-credit-score-is-needed-to-buy-a-house-and-tips-to-bring-up-your-credit
# 2023-05-24 15:02:51,813 INFO:Crawling: https://www.consumer.ftc.gov/articles/0219-disputing-credit-card-charges
# 2023-05-24 15:02:52,381 INFO:Crawling: https://www.cadencebank.com/insights-and-articles/personal/7-common-credit-card-myths-and-facts
# 2023-05-24 15:02:52,941 INFO:Crawling: javascript:window.print();
# ...
#     return requests.get(url).text
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#_ftnref20': No scheme supplied. Perhaps you meant http://#_ftnref20?
# 2023-05-24 15:08:17,531 INFO:Crawling: #_ftnref21
# 2023-05-24 15:08:17,531 ERROR:Failed to crawl: #_ftnref21
# Traceback (most recent call last):
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 32, in run
#     self.crawl(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 23, in crawl
#     html = self.download_url(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 8, in download_url
#     return requests.get(url).text
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#_ftnref21': No scheme supplied. Perhaps you meant http://#_ftnref21?
# 2023-05-24 15:08:17,532 INFO:Crawling: #_ftnref22
# 2023-05-24 15:08:17,533 ERROR:Failed to crawl: #_ftnref22
# Traceback (most recent call last):
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 32, in run
#     self.crawl(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 23, in crawl
#     html = self.download_url(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 8, in download_url
#     return requests.get(url).text
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#_ftnref22': No scheme supplied. Perhaps you meant http://#_ftnref22?
# 2023-05-24 15:08:17,535 INFO:Crawling: #_ftnref23
# 2023-05-24 15:08:17,536 ERROR:Failed to crawl: #_ftnref23
# Traceback (most recent call last):
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 32, in run
#     self.crawl(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 23, in crawl
#     html = self.download_url(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 8, in download_url
#     return requests.get(url).text
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#_ftnref23': No scheme supplied. Perhaps you meant http://#_ftnref23?
# 2023-05-24 15:08:17,537 INFO:Crawling: #_ftnref24
# 2023-05-24 15:08:17,538 ERROR:Failed to crawl: #_ftnref24
# Traceback (most recent call last):
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 32, in run
#     self.crawl(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 23, in crawl
#     html = self.download_url(url)
#   File "/var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_25569/525982781.py", line 8, in download_url
#     return requests.get(url).text
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/Users/mikegoodman/Documents/developer/venv/lib/python3.9/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#_ftnref24': No scheme supplied. Perhaps you meant http://#_ftnref24?
# 2023-05-24 15:08:17,539 INFO:Crawling: https://fred.stlouisfed.org/series/WCURCIR
# 2023-05-24 15:08:17,787 INFO:Crawling: https://www.frbsf.org/cash/publications/fed-notes/2019/june/2019-findings-from-the-diary-of-consumer-payment-choice/
# 2023-05-24 15:08:18,123 INFO:Crawling: https://www.frbsf.org/cash/publications/fed-notes/2022/may/2022-findings-from-the-diary-of-consumer-payment-choice/
# 2023-05-24 15:08:18,436 INFO:Crawling: https://www.frbsf.org/site-policies
# 2023-05-24 15:08:18,786 INFO:Crawling: https://www.frbsf.org/privacy
# 2023-05-24 15:08:19,136 INFO:Crawling: https://www.frbsf.org/our-district/contact-us
# 2023-05-24 15:08:19,471 INFO:Crawling: https://www.frbsf.org/our-district/careers
# 2023-05-24 15:08:19,621 INFO:Crawling: https://www.experian.com/blogs/ask-experian/research/consumer-debt-study/
# 2023-05-24 15:08:20,163 INFO:Crawling: https://money.usnews.com/credit-cards/articles/fee-survey
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 if __name__ == '__main__':
# ----> 2     Crawler(urls=['https://www.cadencebank.com/']).run()
#
# Cell In[5], line 32, in Crawler.run(self)
#      30 logging.info(f'Crawling: {url}')
#      31 try:
# ---> 32     self.crawl(url)
#      33 except Exception:
#      34     logging.exception(f'Failed to crawl: {url}')
#
# Cell In[5], line 23, in Crawler.crawl(self, url)
#      22 def crawl(self, url):
# ---> 23     html = self.download_url(url)
#      24     for url in self.get_linked_urls(url, html):
#      25         self.add_url_to_visit(url)
#
# Cell In[5], line 8, in Crawler.download_url(self, url)
#       7 def download_url(self, url):
# ----> 8     return requests.get(url).text
#
# File ~/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/developer/venv/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/Documents/developer/venv/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/Documents/developer/venv/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/Documents/developer/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/Documents/developer/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Documents/developer/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
