# %% [markdown]
# # Transcribe audio using STT

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Installs

# %%
# Install Vertex AI LLM SDK, langchain and dependencies
#!pip install google-cloud-aiplatform vertexai --upgrade --quiet

# %% [markdown]
# ### Imports

# %%
from datetime import datetime
import time
import pandas as pd
import numpy as np
import json
import os

from IPython.display import Markdown

import vertexai
from vertexai.language_models import TextGenerationModel, TextEmbeddingModel
from vertexai.preview.language_models import TextGenerationModel as TextGenerationModel_preview
from google.cloud import aiplatform
from google.cloud import storage
from google.cloud import bigquery

print("Vertex AI version: " + str(aiplatform.__version__))
# Out:
# Vertex AI version: 1.34.0

# %% [markdown]
# ### Env variables and Setup

# %%
project = !gcloud config get-value project
PROJECT_ID = project[0]
PROJECT_ID
# Out:
# 'mg-ce-demos'

# %%
REGION = 'us-central1'
LOCATION = 'us'
GCS_BUCKET = PROJECT_ID
BLOB_PATH = 'audio_data/test' #update with your GCS blob where the audio file is

# %%
# gcs client
gcs = storage.Client(project = PROJECT_ID)

# vertex ai clients
vertexai.init(project = PROJECT_ID, location = REGION)
aiplatform.init(project = PROJECT_ID, location = REGION)

# %% [markdown]
# ### Functions

# %%
# get audio data from GCS
def get_audio_data(gcs_bucket, blob_path):
    bucket = gcs.bucket(gcs_bucket)

    # Get the list of blobs
    blobs = bucket.list_blobs()

    # Loop through the blobs
    audio_data = []
    for blob in blobs:
        if blob.name.startswith(blob_path):
            if blob.name.endswith('.mp3'):
                #print(blob.name)
                audio_data.append([blob.name, blob.content_type, f'gs://{GCS_BUCKET}/{blob.name}'])
                
    return {
        'data_name': audio_data[-1][0],
        'data_type': audio_data[-1][1],
        'data_uri': audio_data[-1][2]
    }

# %% [markdown]
# ## Data: Get data from GCS
#
# Can loop through GCS to pick up multiple files.  This iteration is built for one file at a time but easy to update.

# %% [markdown]
# Loop through GCS bucket(s) for audio files to transcribe

# %%
sample_uri = get_audio_data(GCS_BUCKET, BLOB_PATH)['data_uri']
print(sample_uri)
# Out:
# gs://mg-ce-demos/audio_data/test/Mapping_uncharted_undersea_volcanoes,_and_elephant_seals_dive_deep_to_sleep.mp3

# %% [markdown]
# ## Transcribe: STT v2 - long

# %%
# STT using cloud speech v2
from google.api_core.client_options import ClientOptions
from google.cloud.speech_v2 import SpeechClient as SpeechClient_v2
from google.cloud.speech_v2.types import cloud_speech as cloud_speech_v2

def transcribe_gcs_v2(model, gcs_uri: str) -> str:
    TIMEOUT_DEFAULT = 3600
    if model == "long":
        word_conf = True
    else:
        word_conf = False
    

    # Instantiates a client
    client = SpeechClient_v2(
        client_options=ClientOptions(
            api_endpoint="us-central1-speech.googleapis.com",
        )
    )
    
    config = cloud_speech_v2.RecognitionConfig(
        auto_decoding_config=cloud_speech_v2.AutoDetectDecodingConfig(),
        language_codes=["en-US"],
        model=model,
        features=cloud_speech_v2.RecognitionFeatures(
            enable_automatic_punctuation=True, #only if using long
            enable_word_confidence=word_conf
        )
    )
    
    file_metadata = cloud_speech_v2.BatchRecognizeFileMetadata(uri=gcs_uri)

    request = cloud_speech_v2.BatchRecognizeRequest(
        recognizer=f"projects/{PROJECT_ID}/locations/{REGION}/recognizers/long-recognizer",
        config=config,
        files=[file_metadata],
        recognition_output_config=cloud_speech_v2.RecognitionOutputConfig(
            inline_response_config=cloud_speech_v2.InlineOutputConfig(),
        ),
    )

    # Transcribes the audio into text
    operation = client.batch_recognize(request=request)

    print("Waiting for operation to complete...")
    try:
        response = operation.result(timeout=TIMEOUT_DEFAULT)       # The default is 3600 seconds, 1 hour

    except:
        response = operation.result(timeout=1.5 * TIMEOUT_DEFAULT) # 5400 seconds, 1 hour and 30 minutes

    finally:
        response = operation.result(timeout=2 * TIMEOUT_DEFAULT)   # 7200 seconds, 2 hours

    return response

# %%
start_time = time.time()

MODEL = "long"
response_v2 = transcribe_gcs_v2(MODEL, sample_uri)

end_time = time.time()
total_time = (end_time - start_time)/60
print(f'{total_time} minutes')
# Out:
# Waiting for operation to complete...
# 17.02648857831955 minutes

# %%
print(f'{response_v2.total_billed_duration.seconds/60} billed minutes')
# Out:
# 18.4 billed minutes

# %% [markdown]
# Build transcription, by speaker, grabbing words passing the confidence threshold

# %%
response_v2
# Out:
# results {
#   key: "gs://mg-ce-demos/audio_data/test/Mapping_uncharted_undersea_volcanoes,_and_elephant_seals_dive_deep_to_sleep.mp3"
#   value {
#     transcript {
#       results {
#         alternatives {
#           transcript: "This podcast is supported by the icon school of medicine at Mount Sinai. The academic arm of the Mount Sinai health system in New York City. And one of America\'s leading research medical schools, what are researchers working on to advance our understanding of the brain and to improve care for such disorders as depression, dementia and drug addiction."
#           confidence: 0.982306718826294
#           words {
#             word: "This"
#             confidence: 0.9955734014511108
#           }
#           words {
#             word: "podcast"
#             confidence: 0.9902135729789734
#           }
#           words {
#             word: "is"
#             confidence: 0.9062939882278442
#           }
#           words {
#             word: "supported"
#             confidence: 0.9973752498626709
#           }
#           words {
#             word: "by"
#             confidence: 0.9992499947547913
#           }
#           words {
#             word: "the"
#             confidence: 0.999804675579071
#           }
#           words {
#             word: "icon"
#             confidence: 0.9198810458183289
#           }
#           words {
#             word: "school"
#             confidence: 0.9724873900413513
#           }
#           words {
#             word: "of"
#             confidence: 0.9990928173065186
#           }
#           words {
#             word: "medicine"
#             confidence: 0.993704617023468
#           }
#           words {
#             word: "at"
#             confidence: 0.9337716102600098
#           }
#           words {
#             word: "Mount"
#             confidence: 0.9610437750816345
#           }
#           words {
#             word: "Sinai."
#             confidence: 0.9251943826675415
#           }
#           words {
#             word: "The"
#             confidence: 0.9988971948623657
#           }
#           words {
#             word: "academic"
#             confidence: 0.9942575693130493
#           }
#           words {
#             word: "arm"
#             confidence: 0.9874553680419922
#           }
#           words {
#             word: "of"
#             confidence: 0.9948451519012451
#           }
#           words {
#             word: "the"
#             confidence: 0.9997484087944031
#           }
#           words {
#             word: "Mount"
#             confidence: 0.9736644625663757
#           }
#           words {
#             word: "Sinai"
#             confidence: 0.9130250215530396
#           }
#           words {
#             word: "health"
#             confidence: 0.9893815517425537
#           }
#           words {
#             word: "system"
#             confidence: 0.989340603351593
#           }
#           words {
#             word: "in"
#             confidence: 0.999140739440918
#           }
#           words {
#             word: "New"
#             confidence: 0.9952182769775391
#           }
#           words {
#             word: "York"
#             confidence: 0.9952182769775391
#           }
#           words {
#             word: "City."
#             confidence: 0.9974350333213806
#           }
#           words {
#             word: "And"
#             confidence: 0.9975000023841858
#           }
#           words {
#             word: "one"
#             confidence: 0.9896399974822998
#           }
#           words {
#             word: "of"
#             confidence: 0.9955828785896301
#           }
#           words {
#             word: "America\'s"
#             confidence: 0.9728421568870544
#           }
#           words {
#             word: "leading"
#             confidence: 0.9952690005302429
#           }
#           words {
#             word: "research"
#             confidence: 0.9767456650733948
#           }
#           words {
#             word: "medical"
#             confidence: 0.9986202716827393
#           }
#           words {
#             word: "schools,"
#             confidence: 0.9946081638336182
#           }
#           words {
#             word: "what"
#             confidence: 0.9300763607025146
#           }
#           words {
#             word: "are"
#             confidence: 0.9420724511146545
#           }
#           words {
#             word: "researchers"
#             confidence: 0.9833077192306519
#           }
#           words {
#             word: "working"
#             confidence: 0.9985429048538208
#           }
#           words {
#             word: "on"
#             confidence: 0.9976937174797058
#           }
#           words {
#             word: "to"
#             confidence: 0.9961163997650146
#           }
#           words {
#             word: "advance"
#             confidence: 0.9944992065429688
#           }
#           words {
#             word: "our"
#             confidence: 0.9945958256721497
#           }
#           words {
#             word: "understanding"
#             confidence: 0.9974159002304077
#           }
#           words {
#             word: "of"
#             confidence: 0.9962319731712341
#           }
#           words {
#             word: "the"
#             confidence: 0.9991982579231262
#           }
#           words {
#             word: "brain"
#             confidence: 0.9952966570854187
#           }
#           words {
#             word: "and"
#             confidence: 0.9812503457069397
#           }
#           words {
#             word: "to"
#             confidence: 0.9972376823425293
#           }
#           words {
#             word: "improve"
#             confidence: 0.9961292743682861
#           }
#           words {
#             word: "care"
#             confidence: 0.9898133873939514
#           }
#           words {
#             word: "for"
#             confidence: 0.9967549443244934
#           }
#           words {
#             word: "such"
#             confidence: 0.9984081387519836
#           }
#           words {
#             word: "disorders"
#             confidence: 0.9947519898414612
#           }
#           words {
#             word: "as"
#             confidence: 0.9972189664840698
#           }
#           words {
#             word: "depression,"
#             confidence: 0.9948019981384277
#           }
#           words {
#             word: "dementia"
#             confidence: 0.9427757263183594
#           }
#           words {
#             word: "and"
#             confidence: 0.9893946051597595
#           }
#           words {
#             word: "drug"
#             confidence: 0.9531309008598328
#           }
#           words {
#             word: "addiction."
#             confidence: 0.9572581052780151
#           }
#         }
#         language_code: "en-us"
#       }
#       results {
#         alternatives {
#           transcript: " To find out. We invite you to read a special supplement to Science magazine prepared by icon Mount Sinai in partnership with science."
#           confidence: 0.9794511198997498
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "To"
#             confidence: 0.878638505935669
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "find"
#             confidence: 0.9651493430137634
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "out."
#             confidence: 0.9851697087287903
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "We"
#             confidence: 0.9980292916297913
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "invite"
#             confidence: 0.9983751773834229
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "you"
#             confidence: 0.99931800365448
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "to"
#             confidence: 0.998775064945221
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "read"
#             confidence: 0.9983830451965332
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "a"
#             confidence: 0.9976219534873962
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "special"
#             confidence: 0.9984082579612732
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "supplement"
#             confidence: 0.9915836453437805
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "to"
#             confidence: 0.99687659740448
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "Science"
#             confidence: 0.9952911138534546
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "magazine"
#             confidence: 0.9937663078308105
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "prepared"
#             confidence: 0.9928145408630371
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "by"
#             confidence: 0.9984933137893677
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "icon"
#             confidence: 0.9612275958061218
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "Mount"
#             confidence: 0.9360746741294861
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "Sinai"
#             confidence: 0.8952565789222717
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "in"
#             confidence: 0.971265435218811
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "partnership"
#             confidence: 0.9930421113967896
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "with"
#             confidence: 0.9887387752532959
#           }
#           words {
#             start_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             end_offset {
#               seconds: 20
#               nanos: 200000000
#             }
#             word: "science."
#             confidence: 0.9950774312019348
#           }
#         }
#         language_code: "en-us"
#       }
#       results {
#         alternatives {
#           transcript: " Just visit our website at www.science.org and search for frontiers of medical research -brainscience. The icon school of medicine at Mount Sinai."
#           confidence: 0.8501939177513123
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "Just"
#             confidence: 0.9982317090034485
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "visit"
#             confidence: 0.9987273812294006
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "our"
#             confidence: 0.99368816614151
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "website"
#             confidence: 0.950597882270813
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "at"
#             confidence: 0.9391806125640869
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "www.science.org"
#             confidence: 0.200978085398674
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "and"
#             confidence: 0.9652157425880432
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "search"
#             confidence: 0.9763935208320618
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "for"
#             confidence: 0.9690544009208679
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "frontiers"
#             confidence: 0.880828857421875
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "of"
#             confidence: 0.9755856394767761
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "medical"
#             confidence: 0.9455906748771667
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "research"
#             confidence: 0.8827627897262573
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "-brainscience."
#             confidence: 0.20251049101352692
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "The"
#             confidence: 0.9715029001235962
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "icon"
#             confidence: 0.742526113986969
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "school"
#             confidence: 0.944679319858551
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "of"
#             confidence: 0.9865567088127136
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "medicine"
#             confidence: 0.919241189956665
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "at"
#             confidence: 0.975394606590271
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "Mount"
#             confidence: 0.6870405673980713
#           }
#           words {
#             start_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             end_offset {
#               seconds: 28
#               nanos: 80000000
#             }
#             word: "Sinai."
#             confidence: 0.5979775786399841
#           }
#         }
#         language_code: "en-us"
#       }
#       results {
#         alternatives {
#           transcript: "Those little slopes these changes in the angle of the water. You can make a pretty, pretty good, guess of the seamount and depth of the cement. So the new study did this worldwide and how many new seamounts were identified or mapped in this research, 19,000 over 19,000. And how many do we know about before? I think it was about 25,000, we know about four a lot of those with previous kind of versions of this technique. This is just an improvement reflecting that there are more capable satellites that have been up there for, you know, a decade now, and you improve the resolution. You can improve the number of size of sea mounts, you can see. So, these are specially smaller sea mounts that they\'ve been able to identify now, what\'s a smaller seam out? How big would that be, you know, people love to quibble about the definition of it. But usually to be, you know, a proper seam out, you need to be. These are essentially underwater volcanoes like a kilometer high or taller. Okay. It\'s pretty big but it\'s still buried."
#           confidence: 0.5445874929428101
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "Those"
#             confidence: 0.5632022619247437
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "little"
#             confidence: 0.994186520576477
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "slopes"
#             confidence: 0.9939855933189392
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "these"
#             confidence: 0.9874633550643921
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "changes"
#             confidence: 0.9941225647926331
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "in"
#             confidence: 0.857783317565918
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "the"
#             confidence: 0.9583123326301575
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "angle"
#             confidence: 0.9638124108314514
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "of"
#             confidence: 0.9842140674591064
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "the"
#             confidence: 0.994515597820282
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "water."
#             confidence: 0.9713327288627625
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "You"
#             confidence: 0.9969101548194885
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "can"
#             confidence: 0.9992281198501587
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "make"
#             confidence: 0.9982808828353882
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "a"
#             confidence: 0.9970095157623291
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "pretty,"
#             confidence: 0.9897993803024292
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "pretty"
#             confidence: 0.9875320792198181
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "good,"
#             confidence: 0.9939525723457336
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "guess"
#             confidence: 0.9719691276550293
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "of"
#             confidence: 0.998060405254364
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "the"
#             confidence: 0.9852786064147949
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "seamount"
#             confidence: 0.8297417163848877
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "and"
#             confidence: 0.9930839538574219
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "depth"
#             confidence: 0.9586939215660095
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "of"
#             confidence: 0.9969754219055176
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "the"
#             confidence: 0.990818440914154
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "cement."
#             confidence: 0.8508406281471252
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "So"
#             confidence: 0.9912257790565491
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "the"
#             confidence: 0.9792730808258057
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "new"
#             confidence: 0.981988251209259
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "study"
#             confidence: 0.9890493154525757
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "did"
#             confidence: 0.9995982050895691
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "this"
#             confidence: 0.9993504881858826
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "worldwide"
#             confidence: 0.9259272217750549
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "and"
#             confidence: 0.9896508455276489
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "how"
#             confidence: 0.9988196492195129
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "many"
#             confidence: 0.9998270869255066
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "new"
#             confidence: 0.9753368496894836
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "seamounts"
#             confidence: 0.9340513944625854
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "were"
#             confidence: 0.973647952079773
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "identified"
#             confidence: 0.9945905208587646
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "or"
#             confidence: 0.966092050075531
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "mapped"
#             confidence: 0.5009154081344604
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "in"
#             confidence: 0.9946527481079102
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "this"
#             confidence: 0.9986653327941895
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "research,"
#             confidence: 0.9958732724189758
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "19,000"
#             confidence: 0.7819162607192993
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "over"
#             confidence: 0.9925909042358398
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "19,000."
#             confidence: 0.7413110733032227
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "And"
#             confidence: 0.9948596954345703
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "how"
#             confidence: 0.9977868795394897
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "many"
#             confidence: 0.9998181462287903
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "do"
#             confidence: 0.9878273606300354
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "we"
#             confidence: 0.9771887063980103
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "know"
#             confidence: 0.9771887063980103
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "about"
#             confidence: 0.9890930652618408
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "before?"
#             confidence: 0.9911120533943176
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "I"
#             confidence: 0.969607949256897
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "think"
#             confidence: 0.9729021191596985
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "it"
#             confidence: 0.9878417253494263
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "was"
#             confidence: 0.9878417253494263
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "about"
#             confidence: 0.993023157119751
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "25,000,"
#             confidence: 0.627516508102417
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "we"
#             confidence: 0.9023092985153198
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "know"
#             confidence: 0.9641998410224915
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "about"
#             confidence: 0.9664456248283386
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "four"
#             confidence: 0.6662877202033997
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "a"
#             confidence: 0.9631646871566772
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "lot"
#             confidence: 0.9631646871566772
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "of"
#             confidence: 0.9935209155082703
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "those"
#             confidence: 0.9968721270561218
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "with"
#             confidence: 0.9627931714057922
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "previous"
#             confidence: 0.9860286116600037
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "kind"
#             confidence: 0.9232175350189209
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "of"
#             confidence: 0.9232175350189209
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "versions"
#             confidence: 0.9156142473220825
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "of"
#             confidence: 0.9338862299919128
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "this"
#             confidence: 0.8570881485939026
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "technique."
#             confidence: 0.9182311296463013
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "This"
#             confidence: 0.9407288432121277
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "is"
#             confidence: 0.9330329298973083
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "just"
#             confidence: 0.934813916683197
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "an"
#             confidence: 0.8142122626304626
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "improvement"
#             confidence: 0.7559546232223511
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "reflecting"
#             confidence: 0.038472730666399
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "that"
#             confidence: 0.5663153529167175
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "there"
#             confidence: 0.06056089326739311
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "are"
#             confidence: 0.15651468932628632
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "more"
#             confidence: 0.3348669111728668
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             word: "capable"
#             confidence: 0.1600579172372818
#           }
#           words {
#             start_offset {
#               seconds: 143
#               nanos: 470000000
#             }
#             end_offset {
# ...
#               nanos: 400000000
#             }
#             word: "aaas.org,"
#             confidence: 0.5587379932403564
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "you"
#             confidence: 0.9987643957138062
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "can"
#             confidence: 0.9796424508094788
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "listen"
#             confidence: 0.9985837936401367
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "to"
#             confidence: 0.9991494417190552
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "the"
#             confidence: 0.9936835765838623
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "show"
#             confidence: 0.9974249601364136
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "on"
#             confidence: 0.9926188588142395
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "our"
#             confidence: 0.9908960461616516
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "website,"
#             confidence: 0.9935585856437683
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "science.org/podcast,"
#             confidence: 0.5605635643005371
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "or"
#             confidence: 0.9596554040908813
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "search"
#             confidence: 0.9975966811180115
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "for"
#             confidence: 0.9985602498054504
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "Science"
#             confidence: 0.9845859408378601
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "magazine"
#             confidence: 0.9790889620780945
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "on"
#             confidence: 0.9907774925231934
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "any"
#             confidence: 0.9797397255897522
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "podcasting"
#             confidence: 0.8820253610610962
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "app."
#             confidence: 0.9742825627326965
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "This"
#             confidence: 0.9993639588356018
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "show"
#             confidence: 0.9975000023841858
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "is"
#             confidence: 0.9535257816314697
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "edited"
#             confidence: 0.9571976065635681
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "by"
#             confidence: 0.9947720170021057
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "me."
#             confidence: 0.9789930582046509
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "Sarah,"
#             confidence: 0.6985464096069336
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "crespi."
#             confidence: 0.6261934638023376
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "And"
#             confidence: 0.9942030310630798
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "Kevin"
#             confidence: 0.9646548628807068
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "McClain"
#             confidence: 0.7299174070358276
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "with"
#             confidence: 0.9963768124580383
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "production,"
#             confidence: 0.9919935464859009
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "help"
#             confidence: 0.9782760143280029
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "from"
#             confidence: 0.9953859448432922
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "Prodigy."
#             confidence: 0.9352058172225952
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "Jeffrey"
#             confidence: 0.6803109049797058
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "cook"
#             confidence: 0.7039778828620911
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "compose"
#             confidence: 0.8554530143737793
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "the"
#             confidence: 0.9642339944839478
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "music"
#             confidence: 0.9776968955993652
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "on"
#             confidence: 0.925198495388031
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "behalf"
#             confidence: 0.9142400026321411
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "of"
#             confidence: 0.9142400026321411
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "Science"
#             confidence: 0.9374039769172668
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "and"
#             confidence: 0.9783412218093872
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "it\'s"
#             confidence: 0.8656527400016785
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "publisher."
#             confidence: 0.5968126058578491
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "Triple"
#             confidence: 0.4865347445011139
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "AAS,"
#             confidence: 0.38899466395378113
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "thanks"
#             confidence: 0.6114929914474487
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "for"
#             confidence: 0.9031408429145813
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "joining"
#             confidence: 0.08255938440561295
#           }
#           words {
#             start_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             end_offset {
#               seconds: 1755
#               nanos: 400000000
#             }
#             word: "us."
#             confidence: 0.048076365143060684
#           }
#         }
#         language_code: "en-us"
#       }
#     }
#   }
# }
# total_billed_duration {
#   seconds: 1104
# }

# %%
transcript_df = pd.DataFrame(columns=['file', 'order', 'text'])

for result in response_v2.results[sample_uri].transcript.results:
    transcript_df.loc[len(transcript_df.index)] = [sample_uri, order, result.alternatives[0].transcript]
    order += 1

transcript_df.head()
transcript_string = transcript_df['text'].str.cat(sep=' ')

# %%
transcript_string
# Out:
# "This podcast is supported by the icon school of medicine at Mount Sinai. The academic arm of the Mount Sinai health system in New York City. And one of America's leading research medical schools, what are researchers working on to advance our understanding of the brain and to improve care for such disorders as depression, dementia and drug addiction.  To find out. We invite you to read a special supplement to Science magazine prepared by icon Mount Sinai in partnership with science.  Just visit our website at www.science.org and search for frontiers of medical research -brainscience. The icon school of medicine at Mount Sinai. Those little slopes these changes in the angle of the water. You can make a pretty, pretty good, guess of the seamount and depth of the cement. So the new study did this worldwide and how many new seamounts were identified or mapped in this research, 19,000 over 19,000. And how many do we know about before? I think it was about 25,000, we know about four a lot of those with previous kind of versions of this technique. This is just an improvement reflecting that there are more capable satellites that have been up there for, you know, a decade now, and you improve the resolution. You can improve the number of size of sea mounts, you can see. So, these are specially smaller sea mounts that they've been able to identify now, what's a smaller seam out? How big would that be, you know, people love to quibble about the definition of it. But usually to be, you know, a proper seam out, you need to be. These are essentially underwater volcanoes like a kilometer high or taller. Okay. It's pretty big but it's still buried. Are a ton of water. We can detect it by looking at the surface of the water and finding like little changes in the slope and we got another 19,000 of these females. One thing I'm curious about is, is the distribution different and we're basically almost doubling the number of seamounts, are they cropping up in unexpected places or they denser or more generally randomly distributed? This is just the, the map coming out. They didn't do analyzes on, you know, that more of that will come but this has filled in kind of blank spaces. So they're a bunch around Antarctica that weren't visible before, at least smaller sea mounts. Also up in the North Atlantic. These were kind of just blank maps for sea mountains and all the sudden. Oh, hello the old pair. Yeah. These females are volcanoes, so, where they are and where they form can tell us something about what's going on with Magma, with the cross with tectonic plates. Yeah, please have been used in the debate over hotspots and like mantle plumes of as you know, A lot of them are around mid-ocean ridges, right? Where the tectonic plates are spreading apart, and you get magma coming up. Others are due to hot spots. Like the Hawaiian chain of islands, are your classic chain of sea mount islands. And the kind of number of them, the volume of them can inform these type of debates, very cool seamount's, really? They just have so many implications. When you first mention this, the story in a meeting, I was like, oh, see mounts, okay, more underwater mountains and it's like, no, this is also where a ton of sea life congregates and it's like little ecosystems almost like underwater islands of life. So this is going to really change our understanding of that as well as one biologist put it. You can't protect these places. If you don't know they're there, right? You know, these are like little skyscrapers of Life. They go up through the water column. Each part of the water column has its own type of Life associated with it. The very good for corals because they have hard surfaces when you have more of these, oh, you can find interesting. Draw ones. You can also kind of get these bigger questions of how interconnected they are, you know, are they kind of isolated pockets evolving distinct life, or are they stepping stones that let life skip through the ocean to migr ...

# %% [markdown]
# ## Transcribe: STT v2 - chirp

# %%
# STT using cloud speech v2
from google.api_core.client_options import ClientOptions
from google.cloud.speech_v2 import SpeechClient as SpeechClient_v2
from google.cloud.speech_v2.types import cloud_speech as cloud_speech_v2

def transcribe_gcs_v2(model, gcs_uri: str) -> str:
    TIMEOUT_DEFAULT = 3600
    if model == "long":
        word_conf = True
    else:
        word_conf = False
    

    # Instantiates a client
    client = SpeechClient_v2(
        client_options=ClientOptions(
            api_endpoint="us-central1-speech.googleapis.com",
        )
    )
    
    config = cloud_speech_v2.RecognitionConfig(
        auto_decoding_config=cloud_speech_v2.AutoDetectDecodingConfig(),
        language_codes=["en-US"],
        model=model,
        features=cloud_speech_v2.RecognitionFeatures(
            enable_automatic_punctuation=True, #only if using long
            enable_word_confidence=word_conf
        )
    )
    
    file_metadata = cloud_speech_v2.BatchRecognizeFileMetadata(uri=gcs_uri)

    request = cloud_speech_v2.BatchRecognizeRequest(
        recognizer=f"projects/{PROJECT_ID}/locations/{REGION}/recognizers/long-recognizer",
        config=config,
        files=[file_metadata],
        recognition_output_config=cloud_speech_v2.RecognitionOutputConfig(
            inline_response_config=cloud_speech_v2.InlineOutputConfig(),
        ),
    )

    # Transcribes the audio into text
    operation = client.batch_recognize(request=request)

    print("Waiting for operation to complete...")
    try:
        response = operation.result(timeout=TIMEOUT_DEFAULT)       # The default is 3600 seconds, 1 hour

    except:
        response = operation.result(timeout=1.5 * TIMEOUT_DEFAULT) # 5400 seconds, 1 hour and 30 minutes

    finally:
        response = operation.result(timeout=2 * TIMEOUT_DEFAULT)   # 7200 seconds, 2 hours

    return response

# %%
start_time = time.time()

MODEL = "chirp"
response_v2 = transcribe_gcs_v2(MODEL, sample_uri)

end_time = time.time()
total_time = (end_time - start_time)/60
print(f'{total_time} minutes')
# Out:
# Waiting for operation to complete...
# 1.1238877177238464 minutes

# %%
print(f'{response_v2.total_billed_duration.seconds/60} billed minutes')
# Out:
# 18.4 billed minutes

# %% [markdown]
# Build transcription, by speaker, grabbing words passing the confidence threshold

# %%
response_v2
# Out:
# results {
#   key: "gs://mg-ce-demos/audio_data/test/Mapping_uncharted_undersea_volcanoes,_and_elephant_seals_dive_deep_to_sleep.mp3"
#   value {
#     transcript {
#       results {
#         alternatives {
#           transcript: " This podcast is supported by the Icon School of Medicine at Mount Sinai, the academic arm of the Mount Sini health system in New York City and one of America\'s leading research medical schools. What are researcher is working on to advance our understanding of the brain and to improve care for such disorders as depression, dementia and drug addiction? To find out, we invite you to read a special supplement to science magazine prepared by Icon Mountsieni in partnership with science. Just visit our website at."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " www.science.org and search for frontiers ofmedical research-brainscience. the icon school of medicine at Mount Sinai. We find a way. This is the science podcast for April 21st 2023. I\'m Sarah Crespy. First up this week, so many seamounts. Staff newswriter Paul Vouson joins me to discuss a study that nearly doubled the number of these."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " submarine volcanoes. Next up, how to mammals that spend 90% of their time in the water, get any sleep? Jessica Kendelbar is here to talk about her work, exploring the sleep of elephant seals, by capturing their brain waves as they dive down deep to get some sleep. and in a sponsored segment from our custom publishing office, assistant editor of custom publishing, jackie oburst talks with addiction researchers, Eric Nesler and Paul Kenny about what researchers have discovered."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " about addiction over the last five years and where the field is going? only about 25% of the ocean floor has been charted or mapped. we don\'t know where all the big dips like trenches are or the big peaks like seamounts. we don\'t know where those are either. today we have staff newswriter Paulson. he wrote this week about a study that nearly doubled the count of known."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " seamounts, hi Paul, hello, why is the ocean so mysterious, why don\'t we know have more of it mapped? what\'s the hold up here? well uh, just a lot of water, but uh, oceanographers will always tell you is we know the surface of the moon or Mars better than we know the ocean, which is true, it\'s just uh, you know, all that water kind gets in the way of seeing what\'s down there, 4,000 meters, 5,000 meters down,"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " and the best method we have for doing this is sonar, it\'s acoustic pings, but that requires expensive ships, so even with a big push in recent years to do mapping better, we\'re only at 25% of the ocean mapped with sonar, your story actually opens with a collision, at least the draft that I read, so there are unmapped areas where ships spend time and they can run into seamounts, that\'s that\'s actually a thing that happens, well ships usually."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " but submarines to, there we go, that makes more sense, yeah, so this is a particular hazard for submarines because a lot of the closest seamounts that are closest to the surface are known or their islands, but uh, yeah, you can even see them kind of underwater, they\'re close enough to the surface with satellite imaging, but yeah, there\'s a couple of famous incidents where the US navy has run into uncharted seamounts, including most recently, a year and a half ago in the south China sea, so the new study did not use sonar."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " which is kind of the standard what people might expect for mapping underwater, what technology do they use instead to try to find all these seamounts? yeah, so this is building off a technique that\'s been used for a couple of decades where you have these radar equipped satellites that measure the height of the ocean worldwide. these are the satellites that provide us with sea level rise from climate change, but they can also they can detect changes in slope in the water, the ocean surface and"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " these can indicate gravity of seamounts underwater kind of bunching up a little bit of water above them, and so with those little slopes, these changes in the angle of the water, you can make a pretty pretty good guess of the seam and depth of the seam. so the new study did this worldwide and how many new seamounts were identified or mapped in this research? 1900, over 19,000. and how many do we know about before? i think it was about."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " 2500 we knew about before a lot of those with previous kind of versions of this technique, this is just an improvement reflecting that there are more capable satellites that have been up there for you a decade now and you improve the resolution, you can improve the number and size of seamounts you can see, so these are especially smaller seamounts that they\'ve been able to identify now, what\'s a smaller seamount? how big would that be? people love to quibble about the definition of it, but usually to be you know a proper seem you need to be"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " these are essentially underwater volcanoes like a kilometer high or taller. okay, it\'s pretty big, but it\'s still buried under a ton of water, we can detect it by looking at the surface of the water and finding like..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " changes in the slope and we got another 19,000 of these seamounts. one thing i\'m curious about is is the distribution different and we\'re basically almost doubling the number of seamounts. are they cropping up in unexpected places? are they denser or more generally randomly distributed? this is just the the map coming out, they didn\'t do analysis on that more of that will come, but this has filled in kind of blank spaces, so there are a bunch around antarctica that weren\'t visible."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " for these smaller seamounts, also up in the North Atlantic, these were kind of just blank maps for seamounts, and all of a sudden, oh hello, they all appear, yeah, these seamounts are volcanoes, so where they are and where they form can tell us something about what\'s going on with magma, with the crust, with tectonic plates, yeah, these have been used in the debate over hot spots and like mantle plumes, because a lot of them are around mid-ocean ridges right, where the tectonic plates are spreading apart."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " and you get magma coming up, others are due to hot spots like the Hawaiian chain of islands are your classic chain of seaunt islands and the kind of number of them, the volume of them can inform these type of debates. Very cool, seamounts really, they just have so many implications. When you first mentioned this this story in a meeting, I was like, oh, seamounts, okay, more underwater mountains and it\'s like, no, this is also where a ton of sea life congregates and it\'s like little ecosystems, almost like under."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " islands of life, so this is going to really change our understanding of that as well, as one biologist put it, you can\'t protect these places if you don\'t know they\'re there, these are like little skyscrapers of life, they go up through the water column each part of the water column has its own type of life associated with it, they\'re very good for corals because they have hard surfaces, when you have more of these, oh you can find interesting individual ones, you can also kind of get these bigger questions of how interconnected they are,"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " are they kind of isolated pockets revolving a distinct life or are they stepping stones that let life skip through the ocean to migrate across? so we\'ve talked about magma, we\'ve talked about sea life and we\'ve talked about not bumping into the seamounts. these are all really important results from getting the maps right, but you actually say in your story that the most important results of this are a better understanding of their effect on the ocean itself, can you"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " spend on that? yeah, for a long time there\'s been this big debate, so you have this big circulation in the ocean, the overturning circulation that moves all the heat and carbon on earth, and we know why the water goes down, and we know why water goes up in like shallow areas because of wind, especially in Antarctica, but there\'s been a lot of debate of why it goes up from the abis, like the deepest part of the ocean upward, it\'s dense, why does it go up? for a long time it was thought to go up evenly distributed, but to the..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " mid layer of the ocean, but there\'s been over the past decade research showing that actually it\'s kind of topography, kind of turbulent breaking against topography or wakes created by topography that can allow this denser water to mix upwards and seamounts are famously walter munk a famous oceanographer put it the kind of stirring rods of the ocean or the straws that stir the ocean something like that and it\'s becoming very clear that they could be in a pre-print using the old atlas of seamounts."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " kind of the dominant force driving the upward circulation, well so we\'re going to be able to map this better and then get a better idea of how it interacts with circulation once we kind of have a true count and a true map. how true this is, these are still geophysical, like people will be like, well, you know, you got to go out and ping it with a acoustic soner, but is that what\'s next? there needs to be confirmation of these satellite observations with on not the ground but on the water, checks, actually the national geospace."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " intelligence agency, which is partly sponsoring this work is commissioning sail drone, has these autonomous sail boats that are now starting to carry multi-beam sonars to go out and check some of these that are look like could be the most hazardous, on the previous catalog, NGA has actually in his partners navy, have checked out 50% of them already and kind of confirmed them, oh wow, all right, thank you so much Paul, yeah, no problem, Paulson is a staff newswriter for science, you can find a link,"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " to the story we discussed at science.org/podcast. don\'t touch that phone, iPod, alexa, whatever. next up is my interview with Jessica kendelbar who had the pleasure of watching sial\'s slumber for her research. for mammals that live most of their lives in the water, like whales or some seals, it\'s not always easy to"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " grab a nap or sleep deeply, hanging out at the surface can make them an easy target for predators. going down deep means no breathing during sleep. this weekend science, Jessica Kendlebar and colleagues looked into..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " elephant seal sleep and found some unexpected things, we\'re going to talk about how they figured it out and what it means for sleeping. hi, Jessica, welcome to the science podcast. hi, thank you for having me. oh, sure. so i outlined a few challenges of sleeping in the ocean if you need to breathe air. was it a big question then of where they decided to sleep if they spend so much time underwater? yeah, so we didn\'t know when they found time to sleep, because they basically spend most of their time."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " during these long forging dives that go very deep and only maybe one to two minutes at the surface at a time and what about land? do they ever just go take a nap on the beach? yeah, so northern elephant seals come on land twice a year, once to breed and once to molt, and they spend a lot of time sleeping during that time, but that\'s not the most accurate representation of what their activity budgets are when they\'re out at see, right? they don\'t just sleep twice a year, right? no."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " Yeah, so when we start talking about the challenges of being a sea creature that needs to breathe and sleep, it really just reminds me like about the basic mystery of sleep, why we need it, how much do we need, all these different strategies for getting it when you can, depending on where you live in the environment, and you how flexible can we be? can you talk about some of the other marine mammals approaches to sleeping in the ocean, whales or dolphins or other kinds of seals, what do we know about them? you"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " have heard that dolphins and actually first seals as well can sleep in just half of their brain at a time, okay, that\'s called a unihemispheric sleep, and that allows them basically to keep one eye open and help monitor predators while they might be getting the the benefits of sleep, yeah, for half their brain, and then they take a turn on the other side, yep, that\'s that\'s the idea, so if you had to guess, what would it be like to have?"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " sleep like this, unihemispheric sleep like a dolphin? so i don\'t know that i have to guess, although we we definitely don\'t do it to the same extent as dolphins, but there is this documented effect called the first night effect, so when you go to a new place you might just be slightly more aware and there\'s some evidence that there\'s a little bit of a symmetry in the degree to which your each of your hemispheres are engaging in slow-wave sleep."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " Again, it\'s probably more like asymmetrical slow-wave sleep as opposed to unihemispheric slow-wave sleep, but this first night effect you know where you\'re kind of generally aware of things, you might feel like you\'ve opened some eyes or, I know exactly what you\'re talking about, yeah, I hate it, so I don\'t want to be a dolphin, so for this study, you were looking at elephant seals, they spend a lot of time out in the water, they spend a lot of time very deep, and they hold their breath,"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " kind of these extreme divers spending a ton of time underwater. how are you able to see? i would have put quotations around that what they were doing whether far from shore and deep underwater. that\'s definitely a challenge, especially since the the areas where they\'re diving are for the most part pitch black. yeah, so we used basically these sleep monitors that we attached to the seals and then they were able to to take those sleep monitors to see and come back."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " with this gold mine of data about where they went and what they did, and we also had sensors that monitor their motion in three dimensions. something that I\'m really passionate about is this ability to see and sort of experience what it\'s like to be a seal under underwater, so I built these tools so that we can create data driven animations where we see the seals sort of traveling hundreds of meters below the ocean surface."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " what they\'re doing with their bodies in terms of the pitch, role, how their swimming behavior might change in frequency, and then be able to see these beautiful sleep spirals that they yeah, they do under the ocean surface, yeah, this is just amazing looking data, it\'s pretty great, i wish you could show everybody who is listening, but they can checkly check out the animation online and look at the figures in the paper, they do a really good job kind of explaining, we\'re going to try to say, we\'re going to try to put it in their ears right now, so in terms of the sleep model"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " is this what we think of when we you somebody\'s in a sleep study and they have electrodes on their scalp? exactly. we use the same sensors that are used in human sleep studies and i actually tried a lot of these methods out on myself and spent some time floating in shallow water and trying to sleep to see if it was working all right. that is so fun. how are you able to put those on i mean elephant seals are pretty big, i guess we should remind people like the males are the ones with the crazy faces, but the females are also very large animals right? definitely."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " they\'re very big and they can be pretty dangerous when we\'re working with the animals in order to ensure the safety of our own crew and the animals, they\'re often sedated and then we\'ll have the time to work with the animal."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " attach everything, make sure there\'s no flaps that are going to create drag for the animal, and then we send them off with these basically little headcaps that are monitoring sleep and a little data logger on the back to store the data that we collect. so you did this with like a smaller group of elephant seals, we\'re going to talk about the larger data set in a minute, and so what you know, let\'s talk about the patterns that you saw, what conclusions we able to draw from the readings out of their brain and then what their bodies were doing in the water."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " and their depth, what what did you figure out about their sleep patterns? one of the big challenges is I\'m trying to interpret nine electrophysiological channels so that signals from what the heart\'s doing, what the muscles are doing, what the brain is doing. I\'m also trying to look at all of these three-dimensional motion sensors and piece together what the animals doing in three-dimensional space, so something that I found myself doing a lot was creating these 3D plots and then I would map one of the variables on to."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " so I would be able to see if the plot changed color, that was a shift in state, so one of the first things that I did is I analyzed the sleep recordings on their own, so what happens for an animal including us, as we fall asleep and go into slow wave sleep is the signals in your brain, basically your neurons start to sink up, that creates these large slow waves, and then as you transition to rem sleep, your brain waves start to sort of transition back to..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " what they look like during waking, but you\'re not aware yet, and your heartbeat becomes erratic, and often for humans,s our bodies become paralyzed, right? that prevents us from acting out our dreams and uh, you know, violent behaviors that we might dream of, and that keeps us safe in our bed, but you can imagine for a seal at see that is becoming paralyzed under the ocean, yeah, that sounds kind of scary, potentially."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " so anyway, so I plotted those colors onto the 3D plot and was able to see these transitions based on color in the three-dimensional plot, and I remember this time when I switched the meaning of color from sleep state to roll, so basically whether the animal was on its belly or upside down, and I noticed that it didn\'t really change, there looked to be the same pattern, so I made sure I was doing my coating correctly, and"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " and i found out that around the same time that they\'re shifting to rem sleep, they\'re flipping upside down and they\'re starting to spin in a circle, and i think that\'s one of the important things that our study showed is that they\'re able to sleep and go into slow wave sleep while they\'re still, you know, they might look like they\'re awake, they\'re just gliding and they\'re they\'re getting deeper right, their belly down, going deeper, and then they\'ll switch to rem sleep, flip upside down, and that\'s when they\'..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " start to do the spiral, so if we were only thinking that they slept during the spirals, we would be really misinterpreting what the bigger picture is. yeah, and now is it unusual that they have rem sleep as an ocean mammal? i certainly think so. we haven\'t recorded sleep in any other wild marine mammel, so i can\'t tell you for sure how unusual that is, but right? um, i know for sure that the animals that they\'ve recorded in the lab environment, dolphins and fur seals don\'t seem to exhibit."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " rem sleep, or if they do, first seals may exhibit 1 to 10 seconds of rem sleep at a time, but what happens is their head kind of falls under the surface, they start to blow bubbles and then they\'re like, oh, i got to breathe, right, right, so that\'s the and then they\'re doing the half hemisphere, the one hemisphere sleep too, right? exactly, so it seems like maybe that unihemispheric sleep is sort of replacing in some way the needs of rem sleep, which is really interesting for us to understand."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " the function of these different types of sleep in animals in other mammals such as ourselves, but it sounds like we need to do more in the wild in order to better understand what happens in different depths and in different situations for these animals. definitely, it\'s possible that some of the good breath holders might be able to exhibit rem sleep somewhere safe. yeah, we should talk about how long they\'re sleeping for, because they are, they\'re going on this the slow wave sleep and you can think of it as a slow incline slide into these deep depths now."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " at like 200, 300 meters and they\'re doing the spiral down with the tail up and the rem sleep, how long does this process take? so the animals that we equipped with sleep monitors were juvenile animals with a slightly lower dive capacity, so their average sleep duration was somewhere around 5 minutes at a time, and those dives were about 15 to 20 minutes long, i think as long as 25 minutes and then when we use that data to tra"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " to find naps in other data sets with just time and depth, those animals are adults with larger dive capacities, and their dives were much longer, about 30 minutes and they were able to"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " to sleep for a grand total of 10 minutes per dive. yeah, let\'s talk about this larger data set. so you took what you knew from these experiments with the wild animals wearing the sensors and you kind of came up with a pattern of what sleep look like and then you went to another data set where the behavior and the position of elephant seals over a much larger group had been recorded and then you could pick out what look like sleep from the that data set. how many animals are we talking here?"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " how many sleep sessions are we talking here? we had a subset of data that had both time depth records and stroking information so we could verify okay they\'re actually not stroking during this time so it it\'s reasonable to call this five minute period where they\'re not moving at all sleep and then the larger data set is as big as 334 seals uh which is an incredible data set to work with dan costa"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " UC Santa Cruz who is my advisor for my Ph.D. has been working for over 25 years to collect time depth records and track these elephant seals as they embark on seven months long migrations. That\'s just a really amazing opportunity to extrapolate what I\'m finding in a small number of seals to this population level. When you look at the population you see these sleep dives, you see the variation in time kind of depending on use of their dive capacity."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " how much sleep do they get in a day on average that if this dive takes them 15 minutes and they spend five minutes sleeping, how many times are they doing that? what\'s a day like for an elephant seal? the vast majority of the records are these dives that go out to see, they\'re called this palagic foraging strategy where they\'ll go almost halfway to Japan and back, and for those animals, they\'re sleeping about two hours a day, and for the long"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " longer trips it\'s slightly more and for the shorter trips it\'s slightly less and so that\'s sort of the typical pattern, but then there\'s also these animals that take a different foraging strategy and they travel up the coast, so they often go to British Columbia or the Lucian islands and sort of hug the coast all the way up through Alaska, and they\'re foruraging much deeper, some of these animals are foruraging below 1,000 meters, oh wow, deep, yeah."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " and then they only perform maybe three or four, somewhere between three or four and and 10 foraging dives a day and they spend the rest of the time sleeping, so they sort of flip this pattern, and they\'re sleeping sometimes upwards of 10 hours per day in these naps that just take up most of the day and then they\'re doing these deep forging dives, so just shows how important it is to to look at these patterns and not assume anything from a si"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " recording and be able to look at patterns of 334 seals. yeah, i love how you call it a sleepscape, like looking across the whole population, and i mean really this really does emphasize like a flexibility in their sleeping patterns, which i don\'t, people don\'t really seem to have that much flexibility. how does uh their heart rate fit in with all of this? is that also kind of on the extreme end of things? it\'s like flexible because they\'re diving, sleeping underwater, expending a lot of energy."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " swimming around, it can really depend on the age of the animal and sort of how much they\'ve built up this mamalian dive response to lower their heart rate when they\'re diving, but in my records i recorded heart rates that were as high as over 200 beats per minute and as low as five beats per minute. those recordings of five beats per minute happened after they potentially found a killer whale out at sea, and uh..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " they lowered their heart rate immediately and sort of dove back down, you can see it in the dive profile too, they got pretty close to the surface and then they decided, nope. i think that really again points out the value of studying these animals in the wild, doing these different activities, having all these different interactions. so yeah, i think these studies of sleep are really important so that we can figure out how, where and when these animals are sleeping in the wild, and we can use that information to better manage and..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " protect their critical resting habitats. Thank you so much, Jessica. Yeah, Jessica Kendell Bar is the Schmitt, AI in Science Post Doctoral Fellow at the Scrips Institution of Oceanography at U.C. San Diego. You can find a link to the paper we discussed at Science.org/podcast. Up next we have a custom segment sponsored by the Icon School of Medicine at Mount Sinai. Custom publishing assistant editor Jacky Oburst chats with Eric Nesler and Paul Kenny, two experts on addiction."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " about the latest research in the field, hello to our podcast listeners and welcome to the..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " custom sponsored interview from the science as custom publishing office and brought to you by the icon school of medicine at mount Sini. My name is Jackie Oburst and I\'m assistant editor for custom publishing at science. Whether it\'s a problem with alcohol, opioids, cocaine or any other substance, addiction, or substance used disorder, is a chronic mental health condition that kills hundreds of thousands of Americans every year and impacts millions of lives. Addictions can destroy marriages, friendships and careers and threaten a person\'s basic health and safety."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " is a medical problem that needs medical solutions. Today I\'m very pleased to welcome two renowned experts on addiction. They are co-authors with several colleagues on an upcoming article about the science of addiction in a neuroscience supplement of science that will come out in June. Dr. Eric Nesler, who is the Nash family professor of neuroscience, director of the Friedmann Brain Institute, Dean for Academic Affairs at the Icon School of Medicine at Mount Sini and Chief Officer of the Mount Sini health system. His laboratory studies the molecular mechanisms of drug"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " addiction and depression in animal models. We also have Dr. Paul Kenny, who is the Ward Colleman\'s professor and chair of the Nash family department of neuroscience as well as a director of the drug discovery Institute at the Icon School of Medicine at Mount Sini. His multidisciplinary research involves the study of behavioral paradigms, physiological analyses and the molecular underpinnings of neurobehavioral disorders such as schizophrenia, and drug addiction. Eric and Paul, thank you so much for taking the time to talk with me today. Eric, I\'d like to."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " our listeners to the topic: how do researchers define addiction? researchers define addiction the same way clinicians do, and this is one of the major gaps in our knowledge. addiction, like all psychiatric syndromes can only be diagnosed by talking to a person or their family members and finding out what types of abnormal behaviors they exhibit. no blood test, no genetic test, no brain scan can be used to diagnose addiction. Paul, could you please also way in? well,"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " is a very tricky word. I think the way that addictionologists would define addiction is a compulsive behavior that persists despite clear evidence suggesting that the behavior should stop, and the behavior is directed towards obtaining drug of abuse. And now I\'d like to focus on why this is an important issue. What is the impact that addiction has on society? On society, addiction has a devastating consequence. I think we all know about the opiide epidemic that\'s gripped the US over the past maybe 10 years. It\'s a leading cause of premature death here in the United States."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " elsewhere in the world, and it\'s not just death that is a a negative consequence of ilicit drug use, i mean the impact really on every aspect of life and society is marked. Eric, are addiction related deaths on the rise, if so, why? yes, so we we\'ve seen a an epidemic of addiction related deaths and I really want to underscore this, before the pandemic, it was reported that we about 70,000 Americans died every year of a drug overdose, and the vast"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " majority of that being unintentional, these are not people who are looking to hurt or harm themselves, these are people who die accidentally by taking too much drug. that number has increased dramatically since the pandemic, so the last data available would suggest that 100,000 Americans die each year now from drug overdose, and i\'d like to put that in some perspective. i was a teenager, young adult during the Vietnam war era. i generation was defined by that war. 58,"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " American combat troops died during a 15-year course of that war, and my generation was torn up over it, yet here we are in the United States, today losing 100,000 Americans every year because of addiction, and we don\'t seem to be able to marshall the resources to address it. Paul, your opinion on this, please, there\'s many reasons for the increased instance of death that we\'re seeing, one of the major reasons is related to just the..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " excessive amounts of opioids are consumed in the United States. the greatest quantities of opiide drugs are by far consumed in the United States. or does the magnitude above opioid consumption in other parts of the world, but it\'s not just opioids. we\'re seeing a real clear spike in the use of other elected drugs like psychomor stimulants, cocaine of course being the example of that, amphetamines, metamphetamine use is also on the increase and those drugs have devastating consequences as well. Eric, what do we know about the science of addiction that we didn\'t know?"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " five years ago? so several areas of advances have been made. first, we now understand what it is about a chemical substance that makes it able to cause addiction in a vulnerable person. drugs of abuse all share the ability to act on the brain\'s reward pathways. reward pathways are parts of the brain that are very old from an evolutionary point of view, and they develop to regulate an individual\'s responses to rewards in the..."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " environment, our behavior is shaped by rewards, the availability of food and water, sex, social interaction, and our actions are being continually refined in response to these cues."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " in the environment. when a person takes a drug of abuse, a person has the experience as if they\'ve had the most rewarding experience possible without actually having something useful happening to them, no food, no drink associated with it. the power and persistence of these actions of drugs on the brain reward circuitry triggers chemical changes in the brain that basically corrupt the brain\'s ability to analyze reward. now an individual who\'s addicted,"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " is not rewarded by natural things, things that most of us are rewarded by, but instead require the sledge hammer effects of a drug of abuse in order to feel that natural reward, and that is one of the reasons why people with addictions are driven so strongly to take drugs, because it is the only way for their brains for themselves to feel normal. in addition to identifying parts of the brain that regulate these responses to drugs of abuse, we\'ve also begun to understand the chemical changes that"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " drugs produce in those brain regions to cause an addiction and for that much of the effort has focused on molecular biology, changes in the ability of certain genes within nerve cells in these brain reward regions to make their protein products and somehow these changes in gene expression as we would call it drive addiction behavior. Paul, your thoughts please. we now are in a position where we can apply really nice tools to understand the most fundamental"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " actions of drugs abuse in the brain, the the molecular, cellular circuit level, also even the underline genetics, what kinds of gene variants are we born with that may influence the likelihood that you\'ll use drugs, if you use them that you\'ll go off and develop a habit and the difficulty that you will have quitting. so applications. Eric, what are the most promising directions in current and future research and treatments? There are some medications that can be quite effective, so in the case of opioid addiction, we are fortunate to have treatments like method."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " and buperonorphine, the brand name for buperonorphine with a co-medication is called soboxone, and methadone and ciboxone can be extremely effective, and I\'d urge your listeners to check out a hulu series called Dopesic, which was really an excellent depiction first of what obeoid addiction can be like, how it can attack anybody regardless of their station in life, but it also depicted quite nicely that when people are given the right kinds of treatment,"
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " like saboxon, they can really do quite well and begin to recover toward a normal life. Paul, your opinion on this please. the most promising trends in the treatment of drug addiction is the fact that we\'re now actually seeing compounds advance through the pre-clinical development pipeline and into human clinical trials and without those types of data, of course we won\'t identify new therapeutic. also without those kind of data we won\'t know from moving the right direction, using the right tools and thinking the right way, so we need those types of human experiments if you will help guide."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " pre-clinical drug development and the likelihood that we can generate not just one therapeutic but in a whole army of therapeutics that can address was a very complex syndrome of behavior abnormality. behavioral therapies can be effective interventions for substance use disorders. holl: what do we now know about the biological mechanisms of action of behavioral therapies? really surprisingly little. i think that\'s an area of research in our field that really would benefit from a lot more attention. you\'re absolutely right. in fact even the most effective therapeutic is about."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " effective as a behavioral intervention, and the best way currently of treating someone who\'s suffering from substance used disorder is a therapeutic and kind of compound that\'s beneficial, bunorpham being an example and behavior therapy combined. why that is the case, we really don\'t know, if I had to guess I was suggested something around the fact that humans are social animals and that social rewards are so critically important for us as a species and that the reward circuitries that are coopted by drugs abuse to some degree at least are likely involved in social orward related behaviors."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " Eric, your thoughts, please. Behavioral therapies are the main stay for addiction treatment. For the majority of people, behavioral therapies are what are available, and they\'re effective in some people, over time, but again, with very high rates of relapse, an 80% chance of relapse within a year of abstinance, a person would go back to behavioral treatment, and the cycle continues again and again, and what you hear from so many patients and family members, is that a loved one has been in treatment repeatedly."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " and still as a high risk of relapse, so to keep hope, because there is always hope, and eventually, actually, most people do kick the habit. Eric and Paul, it\'s been a real pleasure having this opportunity. Thank you both for joining us. Our thanks to the Icon School of Medicine at Mount Synai for sponsoring this interview. This podcast has been edited and condensed for length by Erica Berk, director and senior editor of Custom Publishing, and me, Jackie Oburst. Thank you for listening."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " And that concludes this edition of the science podcast. If you have any comments or suggestions, write to us at Sciencepodcast. Aaaas.org. You can listen to the show on our website science.org."
#         }
#         language_code: "en-US"
#       }
#       results {
#         alternatives {
#           transcript: " Podcast or search for science magazine on any podcasting app. This show was edited by me, Sarah Crespy and Kevin Mclaim, with production help from Podig. Jeffrey Cook composed the music on behalf of science and its publisher. Thanks for joining us."
#         }
#         language_code: "en-US"
#       }
#     }
#   }
# }
# total_billed_duration {
#   seconds: 1104
# }

# %%
transcript_df = pd.DataFrame(columns=['file', 'order', 'text'])

for result in response_v2.results[sample_uri].transcript.results:
    transcript_df.loc[len(transcript_df.index)] = [sample_uri, order, result.alternatives[0].transcript]
    order += 1

transcript_df.head()
transcript_string = transcript_df['text'].str.cat(sep=' ')

# %%
transcript_string
# Out:
# " This podcast is supported by the Icon School of Medicine at Mount Sinai, the academic arm of the Mount Sini health system in New York City and one of America's leading research medical schools. What are researcher is working on to advance our understanding of the brain and to improve care for such disorders as depression, dementia and drug addiction? To find out, we invite you to read a special supplement to science magazine prepared by Icon Mountsieni in partnership with science. Just visit our website at.  www.science.org and search for frontiers ofmedical research-brainscience. the icon school of medicine at Mount Sinai. We find a way. This is the science podcast for April 21st 2023. I'm Sarah Crespy. First up this week, so many seamounts. Staff newswriter Paul Vouson joins me to discuss a study that nearly doubled the number of these.  submarine volcanoes. Next up, how to mammals that spend 90% of their time in the water, get any sleep? Jessica Kendelbar is here to talk about her work, exploring the sleep of elephant seals, by capturing their brain waves as they dive down deep to get some sleep. and in a sponsored segment from our custom publishing office, assistant editor of custom publishing, jackie oburst talks with addiction researchers, Eric Nesler and Paul Kenny about what researchers have discovered.  about addiction over the last five years and where the field is going? only about 25% of the ocean floor has been charted or mapped. we don't know where all the big dips like trenches are or the big peaks like seamounts. we don't know where those are either. today we have staff newswriter Paulson. he wrote this week about a study that nearly doubled the count of known.  seamounts, hi Paul, hello, why is the ocean so mysterious, why don't we know have more of it mapped? what's the hold up here? well uh, just a lot of water, but uh, oceanographers will always tell you is we know the surface of the moon or Mars better than we know the ocean, which is true, it's just uh, you know, all that water kind gets in the way of seeing what's down there, 4,000 meters, 5,000 meters down,  and the best method we have for doing this is sonar, it's acoustic pings, but that requires expensive ships, so even with a big push in recent years to do mapping better, we're only at 25% of the ocean mapped with sonar, your story actually opens with a collision, at least the draft that I read, so there are unmapped areas where ships spend time and they can run into seamounts, that's that's actually a thing that happens, well ships usually.  but submarines to, there we go, that makes more sense, yeah, so this is a particular hazard for submarines because a lot of the closest seamounts that are closest to the surface are known or their islands, but uh, yeah, you can even see them kind of underwater, they're close enough to the surface with satellite imaging, but yeah, there's a couple of famous incidents where the US navy has run into uncharted seamounts, including most recently, a year and a half ago in the south China sea, so the new study did not use sonar.  which is kind of the standard what people might expect for mapping underwater, what technology do they use instead to try to find all these seamounts? yeah, so this is building off a technique that's been used for a couple of decades where you have these radar equipped satellites that measure the height of the ocean worldwide. these are the satellites that provide us with sea level rise from climate change, but they can also they can detect changes in slope in the water, the ocean surface and  these can indicate gravity of seamounts underwater kind of bunching up a little bit of water above them, and so with those little slopes, these changes in the angle of the water, you can make a pretty pretty good guess of the seam and depth of the seam. so the new study did this worldwide and how many new seamounts were identified or mapped in this research? 1900, over 19,000. and how many do we know  ...

# %% [markdown]
# ## 32K Model Summarization Test

# %%
textgen_model_32k = TextGenerationModel_preview.from_pretrained('text-bison-32k')

# %%
if len(transcript_string) > 25000:
    print('full string is too long, chopping to 30K')
    transcript_string = transcript_string[0:30000]
    #print(transcript_string)
# Out:
# full string is too long, chopping to 30K

# %%
# 32k model summarization test
# Ask the LLM
prompt = """Summarize the text below.  Write the summary in bullet form with 1-2 sentences per bullet highlighting key points.

Text:
{}""".format(transcript_string)

# Send prompt to LLM
response_32k = textgen_model_32k.predict(
   (prompt),
    max_output_tokens=5000,
    temperature=0.4,
    top_p=0.8,
    top_k=40,
)
display(Markdown(str(response_32k)))
# Out:
#  - Newswriter Paul Vousden discusses a study that nearly doubled the number of known seamounts, submarine volcanoes, from 2,500 to over 19,000.
#  - The new study used radar-equipped satellites to measure the height of the ocean worldwide, detecting changes in slope that indicate the presence of seamounts.
#  - Seamounts are important because they provide habitats for diverse marine life, can affect ocean circulation, and pose hazards to shipping.
#  - Jessica Kendell Bar, a postdoctoral fellow at the Scripps Institution of Oceanography, discusses her research on the sleep patterns of elephant seals.
#  - Elephant seals spend most of their lives in the water and can dive to great depths.
#  - Kendell Bar's study found that elephant seals sleep in short periods of time, both during deep dives and at the surface.
#  - The study also found that elephant seals experience REM sleep, which is unusual for marine mammals.
#  - Eric Nesler and Paul Kenny, addiction researchers at the Icahn School of Medicine at Mount Sinai, discuss the latest research on addiction.
#  - Addiction is a chronic mental health condition that affects millions of people worldwide.
#  - Researchers define addiction as a compulsive behavior that persists despite negative consequences.
#  - Addiction-related deaths have increased dramatically in recent years, with over 100,000 Americans dying each year from drug overdoses.
#  - The increase in deaths is due to factors such as the excessive consumption of opioids and other drugs in the United States.
#  - Advances in the science of addiction have improved our understanding of how drugs of abuse affect the brain and have led to the development of new treatments.

# %% [markdown]
# ## Transcribe: STT v1

# %%
# STT using cloud speech v1
from google.cloud import speech_v1p1beta1 as speech
from google.cloud.speech_v1p1beta1 import SpeechClient
from google.cloud.speech_v1p1beta1.types import cloud_speech

def transcribe_gcs_v1(gcs_uri: str) -> str:

    TIMEOUT_DEFAULT = 3600

    client = SpeechClient()

    audio = cloud_speech.RecognitionAudio(uri=gcs_uri)
    config = cloud_speech.RecognitionConfig(
        encoding=cloud_speech.RecognitionConfig.AudioEncoding.MP3,    # Configure audio file type to MP3
        sample_rate_hertz = 16000,                                     # Sampling rate set to 44.1KHz
        language_code="en-US",                                        # Language: U. S. English
        enable_automatic_punctuation=True,                            # Enabled automatic punctuation while transforming
        enable_word_confidence=True,                                  # Enabled confidence scores for transcriptions
        model="latest_long",                                          # Works for most of the audio files including long files over 10 minutes
        #diarization_config=cloud_speech.SpeakerDiarizationConfig(     # Enabled speaker diarization
        #    enable_speaker_diarization=True
        #)
    )

    operation = client.long_running_recognize(config=config, audio=audio)   # Execute long running recognition job

    print("Waiting for operation to complete...")

    try:
        response = operation.result(timeout=TIMEOUT_DEFAULT)       # The default is 3600 seconds, 1 hour

    except:
        response = operation.result(timeout=1.5 * TIMEOUT_DEFAULT) # 5400 seconds, 1 hour and 30 minutes

    finally:
        response = operation.result(timeout=2 * TIMEOUT_DEFAULT)   # 7200 seconds, 2 hours

    #print("Building transcriptions...")
    #transcript_builder = []
    # Each result is for a consecutive portion of the audio. Iterate through
    # them to get the transcripts for the entire audio file.
    #for result in response.results:
    #    alternative = result.alternatives[0]

        # The first alternative is the most likely one for this portion.
    #    transcript_builder.append(f"\n{result.alternatives[0].transcript}")
        # transcript_builder.append(f"\nConfidence: {result.alternatives[0].confidence}")

    #transcript = ''.join(transcript_builder)

    #return transcript_builder
    return response

# %%
start_time = time.time()

response_v1 = transcribe_gcs_v1(sample_uri)

end_time = time.time()
total_time = (end_time - start_time)/60
print(f'{total_time} minutes')
# Out:
# Waiting for operation to complete...
# 32.93471109867096 minutes

# %%
response_v1
# Out:
# results {
#   alternatives {
#     transcript: "cash power"
#     confidence: 0.9721954464912415
#     words {
#       word: "cash"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "power"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 11
#     nanos: 530000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " Potter"
#     confidence: 0.8984012603759766
#     words {
#       word: "Potter"
#       confidence: 0.8984012603759766
#     }
#   }
#   result_end_time {
#     seconds: 21
#     nanos: 740000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 30
#     nanos: 400000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you are here"
#     confidence: 0.9665749073028564
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "are"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "here"
#       confidence: 0.9553337693214417
#     }
#   }
#   result_end_time {
#     seconds: 40
#     nanos: 870000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " sure you"
#     confidence: 0.9721954464912415
#     words {
#       word: "sure"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 76
#     nanos: 330000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " just"
#     confidence: 0.7099609375
#     words {
#       word: "just"
#       confidence: 0.7099609375
#     }
#   }
#   result_end_time {
#     seconds: 99
#     nanos: 100000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh you"
#     confidence: 0.9414867162704468
#     words {
#       word: "oh"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9107779264450073
#     }
#   }
#   result_end_time {
#     seconds: 107
#     nanos: 810000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " know"
#     confidence: 0.6868470311164856
#     words {
#       word: "know"
#       confidence: 0.6868470311164856
#     }
#   }
#   result_end_time {
#     seconds: 137
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " I\'m sure"
#     confidence: 0.8986877202987671
#     words {
#       word: "I\'m"
#       confidence: 0.8986877202987671
#     }
#     words {
#       word: "sure"
#       confidence: 0.8986877202987671
#     }
#   }
#   result_end_time {
#     seconds: 141
#     nanos: 90000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " forces that show"
#     confidence: 0.8636531829833984
#     words {
#       word: "forces"
#       confidence: 0.788181722164154
#     }
#     words {
#       word: "that"
#       confidence: 0.8406892418861389
#     }
#     words {
#       word: "show"
#       confidence: 0.9620887041091919
#     }
#   }
#   result_end_time {
#     seconds: 149
#     nanos: 310000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " just"
#     confidence: 0.9721954464912415
#     words {
#       word: "just"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 169
#     nanos: 900000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " ah sorry"
#     confidence: 0.9721954464912415
#     words {
#       word: "ah"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "sorry"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 182
#     nanos: 110000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 185
#     nanos: 20000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 195
#     nanos: 310000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " yes"
#     confidence: 0.8701844811439514
#     words {
#       word: "yes"
#       confidence: 0.8701844811439514
#     }
#   }
#   result_end_time {
#     seconds: 208
#     nanos: 880000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "fashion"
#     confidence: 0.906799852848053
#     words {
#       word: "fashion"
#       confidence: 0.906799852848053
#     }
#   }
#   result_end_time {
#     seconds: 211
#     nanos: 780000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " ash good for you"
#     confidence: 0.9339354038238525
#     words {
#       word: "ash"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "good"
#       confidence: 0.9661555886268616
#     }
#     words {
#       word: "for"
#       confidence: 0.9661555886268616
#     }
#     words {
#       word: "you"
#       confidence: 0.8312348127365112
#     }
#   }
#   result_end_time {
#     seconds: 221
#     nanos: 480000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " are sure"
#     confidence: 0.9721954464912415
#     words {
#       word: "are"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "sure"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 258
#     nanos: 650000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " yeah"
#     confidence: 0.8366950154304504
#     words {
#       word: "yeah"
#       confidence: 0.8366950154304504
#     }
#   }
#   result_end_time {
#     seconds: 275
#     nanos: 990000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh yeah"
#     confidence: 0.6403403282165527
#     words {
#       word: "oh"
#       confidence: 0.5574273467063904
#     }
#     words {
#       word: "yeah"
#       confidence: 0.7232533097267151
#     }
#   }
#   result_end_time {
#     seconds: 283
#     nanos: 610000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " yeah"
#     confidence: 0.7134532928466797
#     words {
#       word: "yeah"
#       confidence: 0.7134532928466797
#     }
#   }
#   result_end_time {
#     seconds: 302
#     nanos: 850000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     confidence: 0.9721954464912415
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 307
#     nanos: 120000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     confidence: 0.7025739550590515
#     words {
#       word: "you"
#       confidence: 0.7025739550590515
#     }
#   }
#   result_end_time {
#     seconds: 322
#     nanos: 260000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "hmm"
#     confidence: 0.5655456185340881
#     words {
#       word: "hmm"
#       confidence: 0.5655456185340881
#     }
#   }
#   result_end_time {
#     seconds: 337
#     nanos: 520000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " wow"
#     confidence: 0.86448073387146
#     words {
#       word: "wow"
#       confidence: 0.86448073387146
#     }
#   }
#   result_end_time {
#     seconds: 351
#     nanos: 560000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "if"
#     confidence: 0.8453381061553955
#     words {
#       word: "if"
#       confidence: 0.8453381061553955
#     }
#   }
#   result_end_time {
#     seconds: 376
#     nanos: 800000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "you"
#     confidence: 0.5995973348617554
#     words {
#       word: "you"
#       confidence: 0.5995973348617554
#     }
#   }
#   result_end_time {
#     seconds: 414
#     nanos: 800000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh"
#     confidence: 0.5289238691329956
#     words {
#       word: "oh"
#       confidence: 0.5289238691329956
#     }
#   }
#   result_end_time {
#     seconds: 439
#     nanos: 570000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " I wash more"
#     confidence: 0.885221540927887
#     words {
#       word: "I"
#       confidence: 0.850922703742981
#     }
#     words {
#       word: "wash"
#       confidence: 0.9477601051330566
#     }
#     words {
#       word: "more"
#       confidence: 0.8569818735122681
#     }
#   }
#   result_end_time {
#     seconds: 443
#     nanos: 790000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " videos"
#     confidence: 0.6859915256500244
#     words {
#       word: "videos"
#       confidence: 0.6859915256500244
#     }
#   }
#   result_end_time {
#     seconds: 453
#     nanos: 920000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "so how"
#     confidence: 0.9314126968383789
#     words {
#       word: "so"
#       confidence: 0.8906298875808716
#     }
#     words {
#       word: "how"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 473
#     nanos: 930000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " are you"
#     confidence: 0.9615331292152405
#     words {
#       word: "are"
#       confidence: 0.960885226726532
#     }
#     words {
#       word: "you"
#       confidence: 0.962181031703949
#     }
#   }
#   result_end_time {
#     seconds: 483
#     nanos: 700000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " travel for you"
#     confidence: 0.814812958240509
#     words {
#       word: "travel"
#       confidence: 0.6750107407569885
#     }
#     words {
#       word: "for"
#       confidence: 0.8712048530578613
#     }
#     words {
#       word: "you"
#       confidence: 0.8982232809066772
#     }
#   }
#   result_end_time {
#     seconds: 523
#     nanos: 940000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "if"
#     confidence: 0.8908767700195312
#     words {
#       word: "if"
#       confidence: 0.8908767700195312
#     }
#   }
#   result_end_time {
#     seconds: 572
#     nanos: 30000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     confidence: 0.7076488137245178
#     words {
#       word: "you"
#       confidence: 0.7076488137245178
#     }
#   }
#   result_end_time {
#     seconds: 577
#     nanos: 250000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " are"
#     confidence: 0.6050093173980713
#     words {
#       word: "are"
#       confidence: 0.6050093173980713
#     }
#   }
#   result_end_time {
#     seconds: 590
#     nanos: 220000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " yeah however"
#     confidence: 0.8428034782409668
#     words {
#       word: "yeah"
#       confidence: 0.8428035378456116
#     }
#     words {
#       word: "however"
#       confidence: 0.8428034782409668
#     }
#   }
#   result_end_time {
#     seconds: 600
#     nanos: 230000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "solution"
#     confidence: 0.7121646404266357
#     words {
#       word: "solution"
#       confidence: 0.7121646404266357
#     }
#   }
#   result_end_time {
#     seconds: 645
#     nanos: 100000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 647
#     nanos: 770000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "was just"
#     confidence: 0.9721954464912415
#     words {
#       word: "was"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "just"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 677
#     nanos: 850000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " right here"
#     confidence: 0.9568697810173035
#     words {
#       word: "right"
#       confidence: 0.964568018913269
#     }
#     words {
#       word: "here"
#       confidence: 0.9491715431213379
#     }
#   }
#   result_end_time {
#     seconds: 700
#     nanos: 570000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "Frozen"
#     confidence: 0.7913557291030884
#     words {
#       word: "Frozen"
#       confidence: 0.7913557291030884
#     }
#   }
#   result_end_time {
#     seconds: 712
#     nanos: 260000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " and over here"
#     confidence: 0.7930356860160828
#     words {
#       word: "and"
#       confidence: 0.9005856513977051
#     }
#     words {
#       word: "over"
#       confidence: 0.7830697298049927
#     }
#     words {
#       word: "here"
#       confidence: 0.6954514980316162
#     }
#   }
#   result_end_time {
#     seconds: 740
#     nanos: 150000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " yes you"
#     confidence: 0.9488543272018433
#     words {
#       word: "yes"
#       confidence: 0.9530490040779114
#     }
#     words {
#       word: "you"
#       confidence: 0.9446595907211304
#     }
#   }
#   result_end_time {
#     seconds: 774
#     nanos: 840000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " how"
#     confidence: 0.8399963974952698
#     words {
#       word: "how"
#       confidence: 0.8399963974952698
#     }
#   }
#   result_end_time {
#     seconds: 778
#     nanos: 890000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     words {
#       word: "you"
#     }
#   }
#   result_end_time {
#     seconds: 785
#     nanos: 120000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " not just"
#     confidence: 0.9016212224960327
#     words {
#       word: "not"
#       confidence: 0.8532117605209351
#     }
#     words {
#       word: "just"
#       confidence: 0.9500306844711304
#     }
#   }
#   result_end_time {
#     seconds: 808
#     nanos: 710000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " and not copper fruits"
#     confidence: 0.8744746446609497
#     words {
#       word: "and"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "not"
#       confidence: 0.8419010043144226
#     }
#     words {
#       word: "copper"
#       confidence: 0.8419010043144226
#     }
#     words {
#       word: "fruits"
#       confidence: 0.8419010043144226
#     }
#   }
#   result_end_time {
#     seconds: 818
#     nanos: 570000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " of water"
#     confidence: 0.9431381225585938
#     words {
#       word: "of"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "water"
#       confidence: 0.9140807390213013
#     }
#   }
#   result_end_time {
#     seconds: 825
#     nanos: 580000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "over here"
#     confidence: 0.9721954464912415
#     words {
#       word: "over"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "here"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 851
#     nanos: 470000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh yeah"
#     confidence: 0.7790406942367554
#     words {
#       word: "oh"
#       confidence: 0.8610106110572815
#     }
#     words {
#       word: "yeah"
#       confidence: 0.697070837020874
#     }
#   }
#   result_end_time {
#     seconds: 875
#     nanos: 790000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 882
#     nanos: 30000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " Round Rock"
#     confidence: 0.5879426002502441
#     words {
#       word: "Round"
#       confidence: 0.6320266723632812
#     }
#     words {
#       word: "Rock"
#       confidence: 0.5438584685325623
#     }
#   }
#   result_end_time {
#     seconds: 908
#     nanos: 380000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " You"
#     confidence: 0.6176670789718628
#     words {
#       word: "You"
#       confidence: 0.6176670789718628
#     }
#   }
#   result_end_time {
#     seconds: 911
#     nanos: 390000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 921
#     nanos: 970000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "wow"
#     confidence: 0.8261190056800842
#     words {
#       word: "wow"
#       confidence: 0.8261190056800842
#     }
#   }
#   result_end_time {
#     seconds: 947
#     nanos: 380000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "I"
#     confidence: 0.5710717439651489
#     words {
#       word: "I"
#       confidence: 0.5710717439651489
#     }
#   }
#   result_end_time {
#     seconds: 969
#     nanos: 640000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " challenge"
#     confidence: 0.576621949672699
#     words {
#       word: "challenge"
#       confidence: 0.576621949672699
#     }
#   }
#   result_end_time {
#     seconds: 973
#     nanos: 530000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     confidence: 0.9721954464912415
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 990
#     nanos: 630000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " all part of"
#     confidence: 0.9718300700187683
#     words {
#       word: "all"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "part"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "of"
#       confidence: 0.9710992574691772
#     }
#   }
#   result_end_time {
#     seconds: 1002
#     nanos: 130000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "if"
#     confidence: 0.5230130553245544
#     words {
#       word: "if"
#       confidence: 0.5230130553245544
#     }
#   }
#   result_end_time {
#     seconds: 1043
#     nanos: 230000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "you hammers for you"
#     confidence: 0.9713081121444702
#     words {
#       word: "you"
#       confidence: 0.9714856147766113
#     }
#     words {
#       word: "hammers"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "for"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9693560600280762
#     }
#   }
#   result_end_time {
#     seconds: 1077
#     nanos: 440000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " first search"
#     confidence: 0.9694525003433228
#     words {
#       word: "first"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "search"
#       confidence: 0.9667096138000488
#     }
#   }
#   result_end_time {
#     seconds: 1098
#     nanos: 680000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "the second yeah"
#     confidence: 0.7541070580482483
#     words {
#       word: "the"
#       confidence: 0.8465052843093872
#     }
#     words {
#       word: "second"
#       confidence: 0.8465051651000977
#     }
#     words {
#       word: "yeah"
#       confidence: 0.5693107843399048
#     }
#   }
#   result_end_time {
#     seconds: 1112
#     nanos: 920000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " sure"
#     confidence: 0.9721954464912415
#     words {
#       word: "sure"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 1120
#     nanos: 500000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " how do you"
#     confidence: 0.9721954464912415
#     words {
#       word: "how"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "do"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 1148
#     nanos: 300000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " here"
#     confidence: 0.8213449120521545
#     words {
#       word: "here"
#       confidence: 0.8213449120521545
#     }
#   }
#   result_end_time {
#     seconds: 1161
#     nanos: 640000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " for you"
#     confidence: 0.9534288048744202
#     words {
#       word: "for"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9346621632575989
#     }
#   }
#   result_end_time {
#     seconds: 1170
#     nanos: 710000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1174
#     nanos: 300000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "here"
#     words {
#       word: "here"
#     }
#   }
#   result_end_time {
#     seconds: 1204
#     nanos: 200000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1221
#     nanos: 140000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " here"
#     confidence: 0.7310192584991455
#     words {
#       word: "here"
#       confidence: 0.7310192584991455
#     }
#   }
#   result_end_time {
#     seconds: 1225
#     nanos: 440000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "forever challenge"
#     confidence: 0.7689170837402344
#     words {
#       word: "forever"
#       confidence: 0.9418373703956604
#     }
#     words {
#       word: "challenge"
#       confidence: 0.5959967374801636
#     }
#   }
#   result_end_time {
#     seconds: 1241
#     nanos: 80000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh sure"
#     confidence: 0.9721954464912415
#     words {
#       word: "oh"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "sure"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 1260
#     nanos: 530000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " here"
#     confidence: 0.7982811331748962
#     words {
#       word: "here"
#       confidence: 0.7982811331748962
#     }
#   }
#   result_end_time {
#     seconds: 1268
#     nanos: 40000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     confidence: 0.5877469778060913
#     words {
#       word: "you"
#       confidence: 0.5877469778060913
#     }
#   }
#   result_end_time {
#     seconds: 1273
#     nanos: 710000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "you you"
#     confidence: 0.9007974863052368
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.8293994665145874
#     }
#   }
#   result_end_time {
#     seconds: 1316
#     nanos: 340000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " of course"
#     confidence: 0.6418235301971436
#     words {
#       word: "of"
#       confidence: 0.7151519060134888
#     }
#     words {
#       word: "course"
#       confidence: 0.5684952139854431
#     }
#   }
#   result_end_time {
#     seconds: 1331
#     nanos: 980000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " and"
#     confidence: 0.6861359477043152
#     words {
#       word: "and"
#       confidence: 0.6861359477043152
#     }
#   }
#   result_end_time {
#     seconds: 1346
#     nanos: 490000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " the first"
#     confidence: 0.8898954391479492
#     words {
#       word: "the"
#       confidence: 0.8898954391479492
#     }
#     words {
#       word: "first"
#       confidence: 0.8898954391479492
#     }
#   }
#   result_end_time {
#     seconds: 1369
#     nanos: 360000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you watch"
#     confidence: 0.9319194555282593
#     words {
#       word: "you"
#       confidence: 0.968300461769104
#     }
#     words {
#       word: "watch"
#       confidence: 0.8955383896827698
#     }
#   }
#   result_end_time {
#     seconds: 1388
#     nanos: 450000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "power"
#     confidence: 0.6071709990501404
#     words {
#       word: "power"
#       confidence: 0.6071709990501404
#     }
#   }
#   result_end_time {
#     seconds: 1404
#     nanos: 260000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " of love for you"
#     confidence: 0.9429243206977844
#     words {
#       word: "of"
#       confidence: 0.9429243206977844
#     }
#     words {
#       word: "love"
#       confidence: 0.952614963054657
#     }
#     words {
#       word: "for"
#       confidence: 0.9039626121520996
#     }
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 1418
#     nanos: 170000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " yeah"
#     confidence: 0.6112266182899475
#     words {
#       word: "yeah"
#       confidence: 0.6112266182899475
#     }
#   }
#   result_end_time {
#     seconds: 1432
#     nanos: 500000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " how short"
#     confidence: 0.9121780395507812
#     words {
#       word: "how"
#       confidence: 0.9121780395507812
#     }
#     words {
#       word: "short"
#       confidence: 0.9121779799461365
#     }
#   }
#   result_end_time {
#     seconds: 1439
#     nanos: 560000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1451
#     nanos: 140000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " ones"
#     confidence: 0.9712148904800415
#     words {
#       word: "ones"
#       confidence: 0.9712148904800415
#     }
#   }
#   result_end_time {
#     seconds: 1470
#     nanos: 460000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "of you"
#     confidence: 0.9465432167053223
#     words {
#       word: "of"
#       confidence: 0.9455000162124634
#     }
#     words {
#       word: "you"
#       confidence: 0.9475864171981812
#     }
#   }
#   result_end_time {
#     seconds: 1487
#     nanos: 40000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1489
#     nanos: 640000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "here you"
#     confidence: 0.8232009410858154
#     words {
#       word: "here"
#       confidence: 0.9657719135284424
#     }
#     words {
#       word: "you"
#       confidence: 0.6806300282478333
#     }
#   }
#   result_end_time {
#     seconds: 1515
#     nanos: 400000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1525
#     nanos: 710000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1533
#     nanos: 700000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " for"
#     confidence: 0.6062003970146179
#     words {
#       word: "for"
#       confidence: 0.6062003970146179
#     }
#   }
#   result_end_time {
#     seconds: 1558
#     nanos: 470000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " sure"
#     confidence: 0.9481346011161804
#     words {
#       word: "sure"
#       confidence: 0.9481346011161804
#     }
#   }
#   result_end_time {
#     seconds: 1566
#     nanos: 60000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " of subscribe"
#     confidence: 0.9721954464912415
#     words {
#       word: "of"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "subscribe"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 1588
#     nanos: 680000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " for our"
#     confidence: 0.9076921939849854
#     words {
#       word: "for"
#       confidence: 0.9076921939849854
#     }
#     words {
#       word: "our"
#       confidence: 0.9076921939849854
#     }
#   }
#   result_end_time {
#     seconds: 1592
#     nanos: 840000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1595
#     nanos: 620000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " her sister"
#     confidence: 0.885749340057373
#     words {
#       word: "her"
#       confidence: 0.8455556631088257
#     }
#     words {
#       word: "sister"
#       confidence: 0.9259430170059204
#     }
#   }
#   result_end_time {
#     seconds: 1602
#     nanos: 910000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1611
#     nanos: 770000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh okay"
#     confidence: 0.8909369707107544
#     words {
#       word: "oh"
#       confidence: 0.926639974117279
#     }
#     words {
#       word: "okay"
#       confidence: 0.8552340269088745
#     }
#   }
#   result_end_time {
#     seconds: 1623
#     nanos: 760000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " Luxor"
#     confidence: 0.5956848859786987
#     words {
#       word: "Luxor"
#       confidence: 0.5956848859786987
#     }
#   }
#   result_end_time {
#     seconds: 1626
#     nanos: 360000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " your"
#     confidence: 0.7986921072006226
#     words {
#       word: "your"
#       confidence: 0.7986921072006226
#     }
#   }
#   result_end_time {
#     seconds: 1628
#     nanos: 540000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " must"
#     confidence: 0.6996540427207947
#     words {
#       word: "must"
#       confidence: 0.6996540427207947
#     }
#   }
#   result_end_time {
#     seconds: 1636
#     nanos: 710000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "ache"
#     confidence: 0.6959347128868103
#     words {
#       word: "ache"
#       confidence: 0.6959347128868103
#     }
#   }
#   result_end_time {
#     seconds: 1646
#     nanos: 170000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "so marvelous the last"
#     confidence: 0.9689028263092041
#     words {
#       word: "so"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "marvelous"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "the"
#       confidence: 0.9656102061271667
#     }
#     words {
#       word: "last"
#       confidence: 0.9656102657318115
#     }
#   }
#   result_end_time {
#     seconds: 1684
#     nanos: 370000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " hot"
#     confidence: 0.6861336827278137
#     words {
#       word: "hot"
#       confidence: 0.6861336827278137
#     }
#   }
#   result_end_time {
#     seconds: 1692
#     nanos: 840000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " one"
#     confidence: 0.9585609436035156
#     words {
#       word: "one"
#       confidence: 0.9585609436035156
#     }
#   }
#   result_end_time {
#     seconds: 1697
#     nanos: 850000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1700
#     nanos: 400000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1704
#     nanos: 490000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1707
#     nanos: 50000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1708
#     nanos: 470000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " and such an expert And subscribe"
#     confidence: 0.9519121050834656
#     words {
#       word: "and"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "such"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "an"
#       confidence: 0.9417703151702881
#     }
#     words {
#       word: "expert"
#       confidence: 0.9417703151702881
#     }
#     words {
#       word: "And"
#       confidence: 0.9417703151702881
#     }
#     words {
#       word: "subscribe"
#       confidence: 0.9417703151702881
#     }
#   }
#   result_end_time {
#     seconds: 1742
#     nanos: 340000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " fortunately recognition"
#     confidence: 0.9578683972358704
#     words {
#       word: "fortunately"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "recognition"
#       confidence: 0.9435413479804993
#     }
#   }
#   result_end_time {
#     seconds: 1748
#     nanos: 820000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1753
#     nanos: 80000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1755
#     nanos: 710000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " sure you"
#     confidence: 0.8505111932754517
#     words {
#       word: "sure"
#       confidence: 0.7305574417114258
#     }
#     words {
#       word: "you"
#       confidence: 0.9704648852348328
#     }
#   }
#   result_end_time {
#     seconds: 1769
#     nanos: 40000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " Russia here you are"
#     confidence: 0.9240307211875916
#     words {
#       word: "Russia"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "here"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9457107782363892
#     }
#     words {
#       word: "are"
#       confidence: 0.8060212135314941
#     }
#   }
#   result_end_time {
#     seconds: 1785
#     nanos: 790000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " Versace"
#     confidence: 0.9721954464912415
#     words {
#       word: "Versace"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 1812
#     nanos: 480000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1816
#     nanos: 940000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 1822
#     nanos: 380000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh welcome or financials and"
#     confidence: 0.9678598642349243
#     words {
#       word: "oh"
#       confidence: 0.950517475605011
#     }
#     words {
#       word: "welcome"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "or"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "financials"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "and"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 1848
#     nanos: 130000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " yeah"
#     confidence: 0.7990153431892395
#     words {
#       word: "yeah"
#       confidence: 0.7990153431892395
#     }
#   }
#   result_end_time {
#     seconds: 1854
#     nanos: 940000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " wow"
#     confidence: 0.9542374014854431
#     words {
#       word: "wow"
#       confidence: 0.9542374014854431
#     }
#   }
#   result_end_time {
#     seconds: 1892
#     nanos: 300000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " are you"
#     confidence: 0.9721954464912415
#     words {
#       word: "are"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 1923
#     nanos: 810000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " however you"
#     confidence: 0.9511305093765259
#     words {
#       word: "however"
#       confidence: 0.9300655126571655
#     }
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 1959
#     nanos: 140000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " her friends and traditions very interesting and"
#     confidence: 0.8760762810707092
#     words {
#       word: "her"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "friends"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "and"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "traditions"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "very"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "interesting"
#       confidence: 0.7652749419212341
#     }
#     words {
#       word: "and"
#       confidence: 0.5062819719314575
#     }
#   }
#   result_end_time {
#     seconds: 1990
#     nanos: 880000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " and understand I said that has happened"
#     confidence: 0.8780640959739685
#     words {
#       word: "and"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "understand"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "I"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "said"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "that"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "has"
#       confidence: 0.6643576622009277
#     }
#     words {
#       word: "happened"
#       confidence: 0.6211137771606445
#     }
#   }
#   result_end_time {
#     seconds: 2013
#     nanos: 510000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " and you"
#     confidence: 0.8516215085983276
#     words {
#       word: "and"
#       confidence: 0.9000343680381775
#     }
#     words {
#       word: "you"
#       confidence: 0.8032086491584778
#     }
#   }
#   result_end_time {
#     seconds: 2020
#     nanos: 480000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     confidence: 0.8264647722244263
#     words {
#       word: "you"
#       confidence: 0.8264647722244263
#     }
#   }
#   result_end_time {
#     seconds: 2026
#     nanos: 670000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " know"
#     confidence: 0.9287518858909607
#     words {
#       word: "know"
#       confidence: 0.9287518858909607
#     }
#   }
#   result_end_time {
#     seconds: 2036
#     nanos: 480000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     confidence: 0.6863285303115845
#     words {
#       word: "you"
#       confidence: 0.6863285303115845
#     }
#   }
#   result_end_time {
#     seconds: 2048
#     nanos: 140000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " are you"
#     confidence: 0.5908008813858032
#     words {
#       word: "are"
#       confidence: 0.5908008813858032
#     }
#     words {
#       word: "you"
#       confidence: 0.5908008813858032
#     }
#   }
#   result_end_time {
#     seconds: 2054
#     nanos: 80000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " tractor"
#     confidence: 0.9524878263473511
#     words {
#       word: "tractor"
#       confidence: 0.9524878263473511
#     }
#   }
#   result_end_time {
#     seconds: 2056
#     nanos: 960000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 2061
#     nanos: 970000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 2064
#     nanos: 500000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " *"
#     confidence: 0.8869349360466003
#     words {
#       word: "*"
#       confidence: 0.8869349360466003
#     }
#   }
#   result_end_time {
#     seconds: 2087
#     nanos: 640000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " faster remember this"
#     confidence: 0.907413899898529
#     words {
#       word: "faster"
#       confidence: 0.887610137462616
#     }
#     words {
#       word: "remember"
#       confidence: 0.9670562744140625
#     }
#     words {
#       word: "this"
#       confidence: 0.8675752282142639
#     }
#   }
#   result_end_time {
#     seconds: 2101
#     nanos: 960000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " here you"
#     confidence: 0.9721954464912415
#     words {
#       word: "here"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 2153
#     nanos: 470000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "have attention"
#     confidence: 0.9093002080917358
#     words {
#       word: "have"
#       confidence: 0.846405029296875
#     }
#     words {
#       word: "attention"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 2193
#     nanos: 640000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " huh"
#     confidence: 0.8355656862258911
#     words {
#       word: "huh"
#       confidence: 0.8355656862258911
#     }
#   }
#   result_end_time {
#     seconds: 2197
#     nanos: 310000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " so for you"
#     confidence: 0.7963119149208069
#     words {
#       word: "so"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "for"
#       confidence: 0.7083702087402344
#     }
#     words {
#       word: "you"
#       confidence: 0.7083702087402344
#     }
#   }
#   result_end_time {
#     seconds: 2214
#     nanos: 80000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " are you"
#     confidence: 0.9721954464912415
#     words {
#       word: "are"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 2220
#     nanos: 620000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " that I I"
#     confidence: 0.9721954464912415
#     words {
#       word: "that"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "I"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "I"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 2253
#     nanos: 930000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " just"
#     confidence: 0.9721954464912415
#     words {
#       word: "just"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 2262
#     nanos: 970000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 2271
#     nanos: 80000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " and"
#     confidence: 0.8719599843025208
#     words {
#       word: "and"
#       confidence: 0.8719599843025208
#     }
#   }
#   result_end_time {
#     seconds: 2294
#     nanos: 440000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " happersh"
#     confidence: 0.9721954464912415
#     words {
#       word: "happersh"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 2303
#     nanos: 190000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 2313
#     nanos: 460000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 2318
#     nanos: 770000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " attention"
#     confidence: 0.9721954464912415
#     words {
#       word: "attention"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 2327
#     nanos: 680000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " function"
#     confidence: 0.8504788875579834
#     words {
#       word: "function"
#       confidence: 0.8504788875579834
#     }
#   }
#   result_end_time {
#     seconds: 2329
#     nanos: 600000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " something you"
#     confidence: 0.9374679327011108
#     words {
#       word: "something"
#       confidence: 0.9444578886032104
#     }
#     words {
#       word: "you"
#       confidence: 0.9304779767990112
#     }
#   }
#   result_end_time {
#     seconds: 2336
#     nanos: 740000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " have a national choice"
#     confidence: 0.8923459053039551
#     words {
#       word: "have"
#       confidence: 0.9447197914123535
#     }
#     words {
#       word: "a"
#       confidence: 0.9447197914123535
#     }
#     words {
#       word: "national"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "choice"
#       confidence: 0.7077487111091614
#     }
#   }
#   result_end_time {
#     seconds: 2376
#     nanos: 810000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you heard you"
#     confidence: 0.9090518355369568
#     words {
#       word: "you"
#       confidence: 0.8324282765388489
#     }
#     words {
#       word: "heard"
#       confidence: 0.9225318431854248
#     }
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 2403
#     nanos: 10000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "are the best powers first reception first"
#     confidence: 0.82663494348526
#     words {
#       word: "are"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "the"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "best"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "powers"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "first"
#       confidence: 0.7014907002449036
#     }
#     words {
#       word: "reception"
#       confidence: 0.6634423732757568
#     }
#     words {
#       word: "first"
#       confidence: 0.5327303409576416
#     }
#   }
#   result_end_time {
#     seconds: 2417
#     nanos: 560000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you are here"
#     confidence: 0.9591509699821472
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "are"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "here"
#       confidence: 0.9330618381500244
#     }
#   }
#   result_end_time {
#     seconds: 2461
#     nanos: 770000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " position"
#     confidence: 0.5496422648429871
#     words {
#       word: "position"
#       confidence: 0.5496422648429871
#     }
#   }
#   result_end_time {
#     seconds: 2465
#     nanos: 360000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " Dash"
#     confidence: 0.8336414098739624
#     words {
#       word: "Dash"
#       confidence: 0.8336414098739624
#     }
#   }
#   result_end_time {
#     seconds: 2494
#     nanos: 970000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you are here"
#     confidence: 0.9631602168083191
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "are"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "here"
#       confidence: 0.9450897574424744
#     }
#   }
#   result_end_time {
#     seconds: 2523
#     nanos: 860000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " here you"
#     confidence: 0.814598560333252
#     words {
#       word: "here"
#       confidence: 0.8311789631843567
#     }
#     words {
#       word: "you"
#       confidence: 0.7980181574821472
#     }
#   }
#   result_end_time {
#     seconds: 2532
#     nanos: 800000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "here Emulsion Rush attack"
#     confidence: 0.9721954464912415
#     words {
#       word: "here"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "Emulsion"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "Rush"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "attack"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 2545
#     nanos: 80000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 2547
#     nanos: 760000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 2556
#     nanos: 720000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 2571
#     nanos: 170000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " for future"
#     confidence: 0.9677916169166565
#     words {
#       word: "for"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "future"
#       confidence: 0.9633877873420715
#     }
#   }
#   result_end_time {
#     seconds: 2593
#     nanos: 130000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " here you are"
#     confidence: 0.8587360978126526
#     words {
#       word: "here"
#       confidence: 0.8753620386123657
#     }
#     words {
#       word: "you"
#       confidence: 0.8753628134727478
#     }
#     words {
#       word: "are"
#       confidence: 0.825483500957489
#     }
#   }
#   result_end_time {
#     seconds: 2622
#     nanos: 200000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " some contest that purpose you"
#     confidence: 0.8741186261177063
#     words {
# ...
#     }
#   }
#   result_end_time {
#     seconds: 5215
#     nanos: 740000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you are"
#     confidence: 0.7406405806541443
#     words {
#       word: "you"
#       confidence: 0.899147629737854
#     }
#     words {
#       word: "are"
#       confidence: 0.5821335315704346
#     }
#   }
#   result_end_time {
#     seconds: 5250
#     nanos: 540000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     confidence: 0.8113822937011719
#     words {
#       word: "you"
#       confidence: 0.8113822937011719
#     }
#   }
#   result_end_time {
#     seconds: 5256
#     nanos: 940000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh yeah"
#     confidence: 0.6455918550491333
#     words {
#       word: "oh"
#       confidence: 0.709909975528717
#     }
#     words {
#       word: "yeah"
#       confidence: 0.5812736749649048
#     }
#   }
#   result_end_time {
#     seconds: 5293
#     nanos: 770000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh yeah"
#     confidence: 0.8340492248535156
#     words {
#       word: "oh"
#       confidence: 0.8340492248535156
#     }
#     words {
#       word: "yeah"
#       confidence: 0.8340492248535156
#     }
#   }
#   result_end_time {
#     seconds: 5320
#     nanos: 660000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5341
#     nanos: 250000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " for you"
#     confidence: 0.968285322189331
#     words {
#       word: "for"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9643752574920654
#     }
#   }
#   result_end_time {
#     seconds: 5354
#     nanos: 90000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "which"
#     confidence: 0.9659889936447144
#     words {
#       word: "which"
#       confidence: 0.9659889936447144
#     }
#   }
#   result_end_time {
#     seconds: 5383
#     nanos: 80000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you yeah"
#     confidence: 0.8176406621932983
#     words {
#       word: "you"
#       confidence: 0.92482990026474
#     }
#     words {
#       word: "yeah"
#       confidence: 0.7104513645172119
#     }
#   }
#   result_end_time {
#     seconds: 5411
#     nanos: 130000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5420
#     nanos: 570000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " good"
#     confidence: 0.3832395374774933
#     words {
#       word: "good"
#       confidence: 0.3832395374774933
#     }
#   }
#   result_end_time {
#     seconds: 5435
#     nanos: 260000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " are you"
#     confidence: 0.9363486766815186
#     words {
#       word: "are"
#       confidence: 0.9301245212554932
#     }
#     words {
#       word: "you"
#       confidence: 0.9425727725028992
#     }
#   }
#   result_end_time {
#     seconds: 5442
#     nanos: 310000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5447
#     nanos: 170000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " are you"
#     confidence: 0.9721954464912415
#     words {
#       word: "are"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 5472
#     nanos: 920000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "true"
#     words {
#       word: "true"
#     }
#   }
#   result_end_time {
#     seconds: 5481
#     nanos: 100000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5495
#     nanos: 60000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " wow people"
#     confidence: 0.8382583856582642
#     words {
#       word: "wow"
#       confidence: 0.8398036956787109
#     }
#     words {
#       word: "people"
#       confidence: 0.8367130160331726
#     }
#   }
#   result_end_time {
#     seconds: 5515
#     nanos: 660000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5526
#     nanos: 420000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh"
#     confidence: 0.6226210594177246
#     words {
#       word: "oh"
#       confidence: 0.6226210594177246
#     }
#   }
#   result_end_time {
#     seconds: 5539
#     nanos: 550000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5542
#     nanos: 570000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you you"
#     confidence: 0.7745400071144104
#     words {
#       word: "you"
#       confidence: 0.9627859592437744
#     }
#     words {
#       word: "you"
#       confidence: 0.5862940549850464
#     }
#   }
#   result_end_time {
#     seconds: 5560
#     nanos: 720000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " there are you"
#     confidence: 0.8343835473060608
#     words {
#       word: "there"
#       confidence: 0.8537917733192444
#     }
#     words {
#       word: "are"
#       confidence: 0.9635648727416992
#     }
#     words {
#       word: "you"
#       confidence: 0.6857941150665283
#     }
#   }
#   result_end_time {
#     seconds: 5574
#     nanos: 20000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " up just"
#     confidence: 0.7554408311843872
#     words {
#       word: "up"
#       confidence: 0.9400970339775085
#     }
#     words {
#       word: "just"
#       confidence: 0.5707846879959106
#     }
#   }
#   result_end_time {
#     seconds: 5602
#     nanos: 440000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " the wrong person structured out of this"
#     confidence: 0.9721955060958862
#     words {
#       word: "the"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "wrong"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "person"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "structured"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "out"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "of"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "this"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 5642
#     nanos: 960000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5648
#     nanos: 100000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh yeah"
#     confidence: 0.9721954464912415
#     words {
#       word: "oh"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "yeah"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 5682
#     nanos: 680000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5686
#     nanos: 940000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " to move"
#     confidence: 0.6858896017074585
#     words {
#       word: "to"
#       confidence: 0.6857776641845703
#     }
#     words {
#       word: "move"
#       confidence: 0.6860015988349915
#     }
#   }
#   result_end_time {
#     seconds: 5689
#     nanos: 250000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " I have"
#     confidence: 0.9721954464912415
#     words {
#       word: "I"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "have"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 5701
#     nanos: 460000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " the championship"
#     confidence: 0.943915843963623
#     words {
#       word: "the"
#       confidence: 0.943915843963623
#     }
#     words {
#       word: "championship"
#       confidence: 0.943915843963623
#     }
#   }
#   result_end_time {
#     seconds: 5730
#     nanos: 120000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5735
#     nanos: 180000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5738
#     nanos: 610000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5740
#     nanos: 80000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5752
#     nanos: 780000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh my gosh"
#     confidence: 0.8261182308197021
#     words {
#       word: "oh"
#       confidence: 0.8960428833961487
#     }
#     words {
#       word: "my"
#       confidence: 0.8960428833961487
#     }
#     words {
#       word: "gosh"
#       confidence: 0.6862689256668091
#     }
#   }
#   result_end_time {
#     seconds: 5757
#     nanos: 860000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " okay"
#     confidence: 0.7103754878044128
#     words {
#       word: "okay"
#       confidence: 0.7103754878044128
#     }
#   }
#   result_end_time {
#     seconds: 5762
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5763
#     nanos: 830000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " Power"
#     confidence: 0.8361656665802002
#     words {
#       word: "Power"
#       confidence: 0.8361656665802002
#     }
#   }
#   result_end_time {
#     seconds: 5767
#     nanos: 990000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " purpose"
#     confidence: 0.9721954464912415
#     words {
#       word: "purpose"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 5773
#     nanos: 500000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " that\'s right"
#     confidence: 0.9487757682800293
#     words {
#       word: "that\'s"
#       confidence: 0.9314736127853394
#     }
#     words {
#       word: "right"
#       confidence: 0.9660778641700745
#     }
#   }
#   result_end_time {
#     seconds: 5790
#     nanos: 220000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5805
#     nanos: 280000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5808
#     nanos: 330000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "and"
#     confidence: 0.818936824798584
#     words {
#       word: "and"
#       confidence: 0.818936824798584
#     }
#   }
#   result_end_time {
#     seconds: 5833
#     nanos: 510000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you"
#     words {
#       word: "you"
#     }
#   }
#   result_end_time {
#     seconds: 5845
#     nanos: 770000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " how far"
#     confidence: 0.9670642614364624
#     words {
#       word: "how"
#       confidence: 0.9670642614364624
#     }
#     words {
#       word: "far"
#       confidence: 0.9670642614364624
#     }
#   }
#   result_end_time {
#     seconds: 5870
#     nanos: 990000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh yeah and shut"
#     confidence: 0.92226243019104
#     words {
#       word: "oh"
#       confidence: 0.9225042462348938
#     }
#     words {
#       word: "yeah"
#       confidence: 0.9225044846534729
#     }
#     words {
#       word: "and"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "shut"
#       confidence: 0.8718454837799072
#     }
#   }
#   result_end_time {
#     seconds: 5893
#     nanos: 150000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: "of"
#     confidence: 0.8316186666488647
#     words {
#       word: "of"
#       confidence: 0.8316186666488647
#     }
#   }
#   result_end_time {
#     seconds: 5900
#     nanos: 540000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " the"
#     confidence: 0.5547626614570618
#     words {
#       word: "the"
#       confidence: 0.5547626614570618
#     }
#   }
#   result_end_time {
#     seconds: 5903
#     nanos: 320000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5906
#     nanos: 300000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5910
#     nanos: 680000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5912
#     nanos: 730000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5921
#     nanos: 50000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " such as"
#     confidence: 0.9721954464912415
#     words {
#       word: "such"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "as"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 5931
#     nanos: 700000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5935
#     nanos: 860000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " also shut up"
#     confidence: 0.9721954464912415
#     words {
#       word: "also"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "shut"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "up"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 5960
#     nanos: 920000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " of"
#     confidence: 0.8065859079360962
#     words {
#       word: "of"
#       confidence: 0.8065859079360962
#     }
#   }
#   result_end_time {
#     seconds: 5963
#     nanos: 520000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " Nashville hospital"
#     confidence: 0.9721954464912415
#     words {
#       word: "Nashville"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "hospital"
#       confidence: 0.9721954464912415
#     }
#   }
#   result_end_time {
#     seconds: 5973
#     nanos: 460000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5980
#     nanos: 460000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 5988
#     nanos: 140000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " and the church"
#     confidence: 0.720706045627594
#     words {
#       word: "and"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "the"
#       confidence: 0.6288785934448242
#     }
#     words {
#       word: "church"
#       confidence: 0.5610442161560059
#     }
#   }
#   result_end_time {
#     seconds: 6003
#     nanos: 950000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " however you hear"
#     confidence: 0.874021589756012
#     words {
#       word: "however"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "you"
#       confidence: 0.9365785717964172
#     }
#     words {
#       word: "hear"
#       confidence: 0.7132907509803772
#     }
#   }
#   result_end_time {
#     seconds: 6032
#     nanos: 400000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " you just"
#     confidence: 0.7562296986579895
#     words {
#       word: "you"
#       confidence: 0.9721954464912415
#     }
#     words {
#       word: "just"
#       confidence: 0.5402639508247375
#     }
#   }
#   result_end_time {
#     seconds: 6042
#     nanos: 470000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     transcript: " oh yes"
#     confidence: 0.828436017036438
#     words {
#       word: "oh"
#       confidence: 0.8586199283599854
#     }
#     words {
#       word: "yes"
#       confidence: 0.7982521653175354
#     }
#   }
#   result_end_time {
#     seconds: 6047
#     nanos: 680000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#   }
#   result_end_time {
#     seconds: 6058
#     nanos: 370000000
#   }
#   language_code: "en-us"
# }
# total_billed_time {
#   seconds: 6078
# }
# request_id: 7936143232025645630

# %%
print(f'{response_v1.total_billed_time.seconds/60} billed minutes')
# Out:
# 101.3 billed minutes

# %%
transcript_builder = []
# Each result is for a consecutive portion of the audio. Iterate through
# them to get the transcripts for the entire audio file.
for result in response_v1.results:
    alternative = result.alternatives[0]
# The first alternative is the most likely one for this portion.
    transcript_builder.append(f"\n{result.alternatives[0].transcript}")
    #transcript_builder.append(f"\nConfidence: {result.alternatives[0].confidence}")

transcript = ''.join(transcript_builder)

# %%
transcript
# Out:
# "\ncash power\n Potter\n\n you are here\n sure you\n just\n oh you\n know\n I'm sure\n forces that show\n just\n ah sorry\n\n\n yes\nfashion\n ash good for you\n are sure\n yeah\n oh yeah\n yeah\n you\n you\nhmm\n wow\nif\nyou\n oh\n I wash more\n videos\nso how\n are you\n travel for you\nif\n you\n are\n yeah however\nsolution\n\nwas just\n right here\nFrozen\n and over here\n yes you\n how\n you\n not just\n and not copper fruits\n of water\nover here\n oh yeah\n\n Round Rock\n You\n\nwow\nI\n challenge\n you\n all part of\nif\nyou hammers for you\n first search\nthe second yeah\n sure\n how do you\n here\n for you\n\nhere\n\n here\nforever challenge\n oh sure\n here\n you\nyou you\n of course\n and\n the first\n you watch\npower\n of love for you\n yeah\n how short\n\n ones\nof you\n\nhere you\n\n\n for\n sure\n of subscribe\n for our\n\n her sister\n\n oh okay\n Luxor\n your\n must\nache\nso marvelous the last\n hot\n one\n\n\n\n\n and such an expert And subscribe\n fortunately recognition\n\n\n sure you\n Russia here you are\n Versace\n\n\n oh welcome or financials and\n yeah\n wow\n are you\n however you\n her friends and traditions very interesting and\n and understand I said that has happened\n and you\n you\n know\n you\n are you\n tractor\n\n\n *\n faster remember this\n here you\nhave attention\n huh\n so for you\n are you\n that I I\n just\n\n and\n happersh\n\n\n attention\n function\n something you\n have a national choice\n you heard you\nare the best powers first reception first\n you are here\n position\n Dash\n you are here\n here you\nhere Emulsion Rush attack\n\n\n\n for future\n here you are\n some contest that purpose you\n yeah yeah\n for more\n have\n showers\n ready\n shortcut\n\n\n how are you\n for this\n first reference of\n channels\n and one must\n\n\n\n for sure\n for our heart\n\n and\n touch\n and\n son\n someone was\n awesome\n the mama of\n sex\n\n channel for more\n energy\n and I think that you\n\n understand\n oh yeah\nhere are you\n are you\n you\n I can't hear\n you\n how some are you\n Force first attention\nour\nare so that's\n\n and function of these\n instructions\n\n that I have\n if you\n\nsure you\n you\nsure I'm at this that I wash\n yeah possible\n starch too much\n and\n for my son\n and first\n you\n\nhe heard us will happen\n\n for half of\n yes yes\n are you\n;?\n\n huh\n\n\n information\n\n so you\nsure and you\n\nfor hash and War and\n much just\n why\n are\n structure\n the basement here\n\n for sure\n here you\n that\n sure you\n\n have four\n here from sacrament\n\n proportions Channel\n and not\n\n and here\n purpose\n\n reflection are you\n I have to know\n for this\n Russ you\nfirst\n time\n not\n can you\n um\nhere here\n\n ahhhhhhhhhhhhhhhhhhh\n oh yeah\n subscribe\n for her\n\n\n\n first time\n and the Final Round Here\n that's just\n you\n of\n detection appeared\n wow just\n\n that I suppose\n show you\n you\n\n convertible attraction and here\n you\n and\n you\n here you\n first\n however here\n part of\n you\n\n;?\n\n are you\n you\nyou are\n yeah\nwhat\n\n\n if you\n remember that to focus of you\n yeah you\nare you\n attached the harsh\n Palace\n to\n which\n ah look at what you\n child\n you\nof\n you\n are\noh\n yeah\n\nof\n\n\n yeah\n\nhere you\n\n he\n\n\n is\n you\nwash your trash\n\n\n\n\n who shot\n the Lord here\n\n\n\ngood oh yeah\n\n Shuffle Shuffle\n are you\n and\n oh yeah\nwow\n oh\n\n\n\n\n\nyou\n should\n\n\n right here\n and\n you are\n you\n oh yeah\n oh yeah\n\n for you\nwhich\n you yeah\n\n good\n are you\n\n are you\ntrue\n\n wow people\n\n oh\n\n you you\n there are you\n up just\n the wrong person structured out of this\n\n oh yeah\n\n to move\n I have\n the championship\n\n\n\n\n oh my gosh\n okay\n\n Power\n purpose\n that's right\n\n\nand\n you\n how far\n oh yeah and shut\nof\n the\n\n\n\n\n such as\n\n also shut up\n of\n Nashville hospital\n\n\n and the church\n however you hear\n you just\n oh yes\n"

# %%
result = response_v1.results[-1]
words_info = result.alternatives[0].words
#result
#words_info

# %%
speaker = 1
text = ''
order = 0
transcript = pd.DataFrame(columns=['file', 'order', 'speaker_tag', 'text'])

for word_info in words_info:
    if word_info.confidence >= 0.5:
        if word_info.speaker_tag==speaker:
            text=text+" "+word_info.word
        else:
            transcript.loc[len(transcript.index)] = [sample_uri, order, str('speaker_'+str(speaker)), text] 
            order += 1
            speaker=word_info.speaker_tag
            text=""+word_info.word

transcript.loc[len(transcript.index)] = [sample_uri, order, str('speaker_'+str(speaker)), text]

# %%
transcript['text'].replace('', np.nan, inplace=True)
transcript = transcript.dropna() 
' '.join(transcript["text"])
# Out:
# " cash power Potter you are here sure you just oh you know I'm sure Foster fish that show just are you fashion ashburton Church are sure yeah oh yeah yeah you hmm wow if oh I wash more videos so how are you travel for you if you are yeah whatever solution was just right here Frozen and over here if you however not just and not copper fruits of water over here oh yeah wow lunch wow I challenge you all part of if you hammers for you first search the second yeah sure how do you here for you however forever challenge oh sure here you you you of course and the first you watch power of love for you yeah how short ones of you here are for sure of subscribe for our prevention oh okay Luxor your must have happened so marvelous the last hot and just so and such that fortunately recognition sure you Russia that you are Versace oh welcome or financials and yeah wow are you however you her friends and traditions very interesting and and understand I said that has happened and you you know you are you tractor * faster remember this here you and have attention huh so first are you that I I just and happersh attention function something you have a national social numbers you heard you are the best powerful search for sure you are here position Dash you are here here you here Emulsion Rush attack for friendship are you and he said some contest that purpose you yeah yeah for more have showers ready shortcut how are you for this first offer you shoulders and one must for our heart and and son someone was awesome the managers are worshipers channel for more energy and I think that you understand oh here are you are you you I can't hear how some are you Force first attention are so that's and function of the safety of Destruction says that I just if you sure you you sure I'm at this time yeah possible starch too much and for my son and you he heard us will happen for happens yes yes are you ;? information so you sure and you for hash and War and much just why are structure are you for sure shut up that sure you have four here from sacrament proportions Channel and not and you purpose reflection are you I have no worries here here you time not can you um here here ahhhhhhhhhhhhhhhhhh oh yeah subscribe for her first time and the Final Round Here that's just you of our exporter detection appeared wow just that I suppose show you you convertible attraction and here you and you here you first have you here part of here are you you yeah if you remember that to focus of you yeah you are you attached the harsh Palace to Earth here you you oh yeah yeah here you he is you wash your trash who shot is all true good oh yeah Shuffle Shuffle are you and oh yeah wow yeah oh you should right here and you are you if you oh yeah for you which you yeah are you are you cruel wow people oh you you there are you up just the wrong person structured out of here oh yeah to move I have the championship oh my gosh power purpose that's right and how far oh yeah and shut of the such as also shut up of Nashville hospital and the church however yeah you just oh yes"

# %% [markdown]
# ## UI (WIP)

# %%
def upload_file(file):
    file_path = file.name
    file_name = os.path.basename(file_path)
    bucket = gcs.bucket(GCS_BUCKET)
    blob = bucket.blob(f'audio_data/cumulus/{file_name}')
    blob.upload_from_filename(f'{file_path}')
    #print("Uploaded")
    
    gcs_path = f'gs://{GCS_BUCKET}/{blob.name}'
    
    return gcs_path
    
#with gr.Blocks() as demo:
#    file_output = gr.File()
#    upload_button = gr.UploadButton("Click to Upload a File", file_types=["audio"])
#    upload_button.upload(upload_file, upload_button, file_output)

#demo.launch(share=False, debug=False)

# %%
# create a function that pulls all the steps together
def article_builder(gcs_uri):
# Out:
#   Cell In[32], line 3
#
#     ^
# IndentationError: expected an indented block

# %%
get_audio_data('mg-ce-demos')

# %%
import gradio as gr

demo = gr.Blocks()

with demo:
    audio_file = gr.Audio(type="filepath")
    text = gr.Textbox()
    label = gr.Label()

    b1 = gr.Button("Upload")
    b2 = gr.Button("Get GCS URI")
    b3 = gr.Button("Create Articles")

    b1.click(upload_file, inputs=audio_file, outputs=text)
    b2.click(get_audio_data, inputs=text, outputs=label)

if __name__ == "__main__":
    demo.launch()

# %%
with gr.Blocks() as demo:
    gr.Markdown(
    """
    ## Audio to Articles
    """)
    #with gr.Row():
    #    file_output = gr.File()
    #    upload_button = gr.UploadButton("Click to Transcribe and Draft Articles", file_types=["audio"])
    #    upload_button.upload(upload_file, upload_button, file_output)  
        
    with gr.Row():
        with gr.Column():
            input_text = gr.Textbox(label="Task", placeholder="Cloud Bucket Name")
    
    with gr.Row():
        find_gcs_uri = gr.Button("Select Audio File")
        
    with gr.Row():
        label1 = gr.Textbox(label="GCS URI")
        
    #with gr.Row():
    #    generate = gr.Button("Generate Response")

    #with gr.Row():
    #    label2 = gr.Textbox(label="Prompt")
    #with gr.Row():
    #    label3 = gr.Textbox(label="Response generated by LLM")

    generate.click(get_audio_data, input_text, label1)
    
demo.launch(share=False, debug=False)
