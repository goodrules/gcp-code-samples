# %% [markdown]
# # NLP AI Fun

# %%
from typing import Sequence
import os

# to show images being submitted
from google.cloud import storage
from IPython.display import Image
import base64
import numpy as np
import argparse
import cv2
import io
import urllib

# %%
SERIES = 'applied_apis'
EXPERIMENT = 'nlp_ai_fun'

REGION = 'us-central1'

# %%
DIR = f"temp/{EXPERIMENT}"

# %%
# !rm -rf {DIR}
# !mkdir -p {DIR}

# %%
gcs_client = storage.Client()

# %% [markdown]
# Functions:

# %% [markdown]
# ## Natural Language

# %% [markdown]
# ## Translation

# %%
lyric = """
Never gonna give you up. 
Never gonna let you down. 
Never gonna run around and desert you. 
Never gonna make you cry. 
Never gonna say goodbye. 
Never gonna tell a lie and hurt you.
"""
print(lyric)
# Out:
# Never gonna give you up.
# Never gonna let you down.
# Never gonna run around and desert you.
# Never gonna make you cry.
# Never gonna say goodbye.
# Never gonna tell a lie and hurt you.

# %% [markdown]
# ### Detect Language (Basic Edition)

# %%
from google.cloud import translate_v2 as translate
translate_client = translate.Client()

# %%
translate_client.detect_language(lyric)['language']
# Out:
# 'en'

# %% [markdown]
# ---
# ### Translation
#
# Create a list with multiple translation of lyric:
#
# Supported Languages: https://cloud.google.com/translate/docs/languages

# %% [markdown]
# Rick speaks French?

# %%
print(translate_client.translate(lyric,target_language='fr',format_='text')['translatedText'])
# Out:
# Je ne t'abandonnerai jamais.
# Je ne te laisserai jamais tomber.
# Je ne vais jamais courir et t'abandonner.
# Je ne te ferai jamais pleurer.
# Je ne dirai jamais au revoir.
# Je ne mentirai jamais et ne te blesserai jamais.

# %% [markdown]
# What languages can Rick speak?

# %%
languages = translate_client.get_languages(target_language='en')
for language in languages: print(language['name'])
# Out:
# Afrikaans
# Akan
# Albanian
# Amharic
# Arabic
# Armenian
# Assamese
# Aymara
# Azerbaijani
# Bambara
# Basque
# Belarusian
# Bengali
# Bhojpuri
# Bosnian
# Bulgarian
# Catalan
# Cebuano
# Chichewa
# Chinese (Simplified)
# Chinese (Traditional)
# Corsican
# Croatian
# Czech
# Danish
# Divehi
# Dogri
# Dutch
# English
# Esperanto
# Estonian
# Ewe
# Filipino
# Finnish
# French
# Frisian
# Galician
# Ganda
# Georgian
# German
# Goan Konkani
# Greek
# Guarani
# Gujarati
# Haitian Creole
# Hausa
# Hawaiian
# Hebrew
# Hindi
# Hmong
# Hungarian
# Icelandic
# Igbo
# Iloko
# Indonesian
# Irish
# Italian
# Japanese
# Javanese
# Kannada
# Kazakh
# Khmer
# Kinyarwanda
# Korean
# Krio
# Kurdish (Kurmanji)
# Kurdish (Sorani)
# Kyrgyz
# Lao
# Latin
# Latvian
# Lingala
# Lithuanian
# Luxembourgish
# Macedonian
# Maithili
# Malagasy
# Malay
# Malayalam
# Maltese
# Manipuri (Meitei Mayek)
# Maori
# Marathi
# Mizo
# Mongolian
# Myanmar (Burmese)
# Nepali
# Northern Sotho
# Norwegian
# Odia (Oriya)
# Oromo
# Pashto
# Persian
# Polish
# Portuguese
# Punjabi
# Quechua
# Romanian
# Russian
# Samoan
# Sanskrit
# Scots Gaelic
# Serbian
# Sesotho
# Shona
# Sindhi
# Sinhala
# Slovak
# Slovenian
# Somali
# Spanish
# Sundanese
# Swahili
# Swedish
# Tajik
# Tamil
# Tatar
# Telugu
# Thai
# Tigrinya
# Tsonga
# Turkish
# Turkmen
# Ukrainian
# Urdu
# Uyghur
# Uzbek
# Vietnamese
# Welsh
# Xhosa
# Yiddish
# Yoruba
# Zulu
# Hebrew
# Javanese
# Chinese (Simplified)

# %% [markdown]
# Translate the lyrics into all of Rick's languages!

# %%
for i, language in enumerate(languages):
    languages[i]['lyric'] = translate_client.translate(lyric,target_language=language['language'],format_='text')['translatedText']

# %%
for language in languages:
    print(language['name'],'\n',language['lyric'],"\n")
# Out:
# Afrikaans
#
# Gaan jou nooit opgee nie.
# Gaan jou nooit in die steek laat nie.
# Gaan nooit rondhardloop en jou in die steek laat nie.
# Sal jou nooit laat huil nie.
# Gaan nooit totsiens sê nie.
# Gaan nooit 'n leuen vertel en jou seermaak nie.
#
#
# Akan
#
# Ɛnsɛ sɛ wogyae wo ho da.
# Never gonna let wo abam bu.
# Never gonna run around na woagyae wo.
# Never gonna ma wosu.
# Never gonna ka asɛmpa.
# Never gonna tell a lie na wapira wo.
#
#
# Albanian
#
# Nuk do te le kurre.
# Nuk do të të zhgënjejë kurrë.
# Kurrë nuk do të vrapoj dhe do të të braktis.
# Nuk do të të bëj kurrë të qash.
# Nuk do të them kurrë lamtumirë.
# Kurrë nuk do të them një gënjeshtër dhe nuk do t'ju lëndoj.
#
#
# Amharic
#
# አሳልፌ አልሰጥህም.
# በፍፁም አላሳቀቅሽም።
# በፍፁም አይሮጥሽም እና አይተወሽም።
# በጭራሽ አታለቅስም።
# በጭራሽ አይሰናበትም።
# በጭራሽ ውሸት ተናግሮ አይጎዳህም ።
#
#
# Arabic
#
# لا تستسلم أبداً.
# أبدا ستعمل نخذلكم.
# لن أركض وأتركك.
# لن تجعلك تبكي.
# لن أقول وداعا.
# لن تكذب ابدا وتؤذيك.
#
#
# Armenian
#
# Երբեք չեմ հրաժարվի քեզնից:
# Երբեք քեզ հուսախաբ չեմ անի:
# Երբեք չեմ վազի և լքի քեզ:
# Երբեք քեզ չի ստիպի լաց լինել:
# Երբեք հրաժեշտ չեմ տա:
# Երբեք չեմ ասի սուտ ու վիրավորի քեզ:
#
#
# Assamese
#
# কেতিয়াও তোমাক এৰি নিদিব।
# কেতিয়াও আপোনাক নিৰাশ নকৰিব।
# কেতিয়াও দৌৰি ঘূৰি নাযাব আৰু আপোনাক মৰুভূমি।
# কেতিয়াও কান্দিব নোৱাৰিব।
# কেতিয়াও বিদায় ল’ব নোৱাৰিম।
# কেতিয়াও মিছা কথা কৈ আপোনাক আঘাত নিদিব।
#
#
# Aymara
#
# Janipuniw jaytkätamti.
# Janipuniw aynachtʼaykätamti.
# Janipuniw t’ijt’asin wasar pampar sarkätati.
# Janipuniw jachañamäkiti.
# Janipuniw despedida sañ munkti.
# Janipuniw kʼarinak parlkätati ukat chuym ustʼaykätamti.
#
#
# Azerbaijani
#
# Səndən heç vaxt imtina etməyəcəyəm.
# Heç vaxt səni ruhdan salmayacağam.
# Heç vaxt qaçıb səni tərk etməyəcəyəm.
# Heç vaxt səni ağlatmayacağam.
# Heç vaxt vidalaşmayacağım.
# Heç vaxt yalan danışıb səni incitməyəcəyəm.
#
#
# Bambara
#
# Never gonna ka i dabila.
# A tɛna i jigi tigɛ abada.
# Never gonna boli ka yaala ka i bila.
# Never gonna ka i kasi.
# Never gonna ka foli kɛ.
# Ne tɛna nkalon tigɛ abada ka i tɔɔrɔ.
#
#
# Basque
#
# Ez zaitut inoiz amore emango.
# Inoiz ez zaitut utziko.
# Inoiz ez zaitut korrika egingo eta desertatu.
# Inoiz ez zaitut negar egingo.
# Ez dut inoiz agur esango.
# Inoiz ez zaitut gezurrik esango eta minik egingo.
#
#
# Belarusian
#
# Ніколі цябе не кіну.
# Ніколі не падвяду.
# Ніколі не буду бегаць і кідаць цябе.
# Ніколі не прымусіць цябе плакаць.
# Ніколі не развітваюся.
# Ніколі не схлушу і прычыню табе боль.
#
#
# Bengali
#
# তোমাকে কখনো ছেড়ে দেব না।
# তোমাকে কখনো হতাশ করব না।
# কখনও দৌড়াবে না এবং আপনাকে পরিত্যাগ করবে না।
# তোমাকে কখনো কাঁদাবে না।
# কখনো বিদায় জানাবে না।
# কখনো মিথ্যা বলবো না এবং তোমাকে আঘাত করবে না।
#
#
# Bhojpuri
#
# कबो रउरा के ना छोड़े वाला बा.
# कबो तोहरा के निराश ना करे वाला।
# कबो इधर-उधर भाग के रउरा के छोड़ ना देब।
# कबो रउरा के रोवे वाला ना.
# कबो अलविदा ना कहब।
# कबो झूठ ना बोल के रउरा के चोट ना पहुंचाई।
#
#
# Bosnian
#
# Nikad neću odustati od tebe.
# Nikad te neću iznevjeriti.
# Nikada neću trčati okolo i napustiti te.
# Nikad te neću rasplakati.
# Nikad se neću oprostiti.
# Nikada neću reći laž i povrijediti te.
#
#
# Bulgarian
#
# Никога няма да те предам.
# Никога няма да те разочаровам.
# Никога няма да тичам наоколо и да те изоставя.
# Никога няма да те разплача.
# Никога няма да кажа сбогом.
# Никога няма да излъжа и да те нараня.
#
#
# Catalan
#
# Mai renunciaré a tu.
# Mai et defraudaré.
# Mai córrer i abandonar-te.
# Mai et faré plorar.
# Mai diré adéu.
# Mai diré una mentida i et faré mal.
#
#
# Cebuano
#
# Dili ko nimo biyaan.
# Dili gyud ka pasagdan.
# Dili na magdagan-dagan ug biyaan ka.
# Dili gyud ka magpahilak.
# Dili na gyud manamilit.
# Dili gayud mamakak ug masakitan ka.
#
#
# Chichewa
#
# Sindidzataya mtima.
# Sindidzakukhumudwitsani.
# Sindidzathamanga ndikukusiyani.
# Sindidzakupangitsani kulira.
# Sindidzatsanzika konse.
# Sindidzanama ndikukupwetekani.
#
#
# Chinese (Simplified)
#
# 绝不会放弃你。
# 永远不会让你失望。
# 永远不会跑来跑去抛弃你。
# 永远不会让你哭泣。
# 永不说再见。
# 永远不会说谎伤害你。
#
#
# Chinese (Traditional)
#
# 絕不會放棄你。
# 永遠不會讓你失望。
# 永遠不會跑來跑去拋棄你。
# 永遠不會讓你哭泣。
# 永不說再見。
# 永遠不會說謊傷害你。
#
#
# Corsican
#
# Ùn ti rinunciarà mai.
# Ùn ti lasciaraghju mai.
# Mai correrà in giro è ti disertarà.
# Ùn ti farà mai pienghje.
# Ùn diceraghju mai addiu.
# Ùn diceraghju mai una bugia è ti ferite.
#
#
# Croatian
#
# Nikada neću odustati od tebe.
# Nikad te neću iznevjeriti.
# Nikada neću trčati okolo i napustiti te.
# Nikad te neću rasplakati.
# Nikad neću reći zbogom.
# Nikada neću lagati i povrijediti te.
#
#
# Czech
#
# Nikdy se tě nevzdám.
# Nikdy tě nezklame.
# Nikdy tě neopustím.
# Nikdy tě nerozbrečí.
# Nikdy neřeknu sbohem.
# Nikdy nebudu lhát a neublížím ti.
#
#
# Danish
#
# Giver aldrig op.
# Vil aldrig svigte dig.
# Vil aldrig løbe rundt og forlade dig.
# Får dig aldrig til at græde.
# Vil aldrig sige farvel.
# Vil aldrig lyve og såre dig.
#
#
# Divehi
#
# ނެވަރ ގޯނާ ގިވް ޔޫ އަޕް.
# ނެވަރ ގޯނާ ލެޓް ޔޫ ޑައުން.
# ނެވަރ ގޯނާ ރަން އަރައުންޑް އެންޑް ޑެސަރޓް ޔޫ.
# ނެވަރ ގޯނާ މެކް ޔޫ ކްރައި.
# ނެވަރ ގޯނާ ސޭ ގުޑްބައި.
# ނެވަރ ގޯނާ ޓެލް އަ ލީ އެންޑް ހަރޓް ޔޫ.
#
#
# Dogri
#
# कभी तुझे न छोडने वाला।
# कदें बी तुसें गी निराश नेईं करने आह्ला।
# कदें बी इधर-उधर दौड़ना ते तुसें गी रेगिस्तान नेईं करना।
# कदें बी रोना नेईं देना।
# कदे अलविदा नहीं कहने वाला।
# कदें बी झूठ बोलना ते तुसेंगी चोट नेईं पजाना।
#
#
# Dutch
#
# Ik ga jou nooit op geven.
# Ik zal je nooit teleurstellen.
# Ik zal nooit rondrennen en je in de steek laten.
# Ik zal je nooit aan het huilen maken.
# Ik zal nooit vaarwel zeggen.
# Ik ga nooit liegen en je pijn doen.
#
#
# English
#
# Never gonna give you up.
# Never gonna let you down.
# Never gonna run around and desert you.
# Never gonna make you cry.
# Never gonna say goodbye.
# Never gonna tell a lie and hurt you.
#
#
# Esperanto
#
# Neniam forlasos vin.
# Neniam lasos vin.
# Neniam kuros kaj dizertos vin.
# Neniam ploros vin.
# Neniam diros adiaŭ.
# Neniam diros mensogon kaj vundos vin.
#
#
# Estonian
#
# Ei anna sind kunagi alla.
# Ei vea sind kunagi alt.
# Ei jookse kunagi ringi ega jäta sind maha.
# Ei pane sind kunagi nutma.
# Ei jäta kunagi hüvasti.
# Ei valeta kunagi ega tee sulle haiget.
#
#
# Ewe
#
# Maɖe asi le ŋuwò gbeɖe o.
# Maɖi gbɔ wò gbeɖe o.
# Maƒu du aƒo xlã wò gbeɖe o.
# Mawɔe be nàfa avi gbeɖe o.
# Never gonna do gbe na ame.
# Magblɔ alakpa gbeɖe eye wòawɔ nuvevi wò o.
#
#
# Filipino
#
# Hinding hindi kita ibibigay.
# Hinding hindi ka pababayaan.
# Hinding hindi ka tatakbo at iiwan ka.
# Hinding hindi ka paiiyakin.
# Never gonna say goodbye.
# Hinding-hindi ka magsisinungaling at sasaktan.
#
#
# Finnish
#
# En koskaan luovu sinusta.
# Ei koskaan petä sinua.
# En koskaan juokse ympäriinsä ja hylkää sinua.
# Ei saa sinua koskaan itkemään.
# Ei koskaan sano hyvästit.
# Älä koskaan valehtele ja satuta sinua.
#
#
# French
#
# Je ne t'abandonnerai jamais.
# Je ne te laisserai jamais tomber.
# Je ne vais jamais courir et t'abandonner.
# Je ne te ferai jamais pleurer.
# Je ne dirai jamais au revoir.
# Je ne mentirai jamais et ne te blesserai jamais.
#
#
# Frisian
#
# Jo sille jo noait opjaan.
# Nea sil lit dy del.
# Nea gonna rinne om en ferlitte dy.
# Nea gonna meitsje dy gûle.
# Nea gonna ôfskied nimme.
# Nea in leagen fertelle en dy sear dwaan.
#
#
# Galician
#
# Nunca te abandonarei.
# Nunca te defraudarei.
# Nunca vou correr e abandonarte.
# Nunca te fará chorar.
# Nunca me despedirei.
# Nunca vou dicir unha mentira e facerte dano.
#
#
# Ganda
#
# Never gonna okukuwaayo.
# Never gonna let you down.
# Never gonna run around nakudduka.
# Never gonna okukukaaba.
# Never gonna kusiibula.
# Never gonna tell a lie n'okukulumya.
#
#
# Georgian
#
# Არასდროს დანებდე.
# არასოდეს გაგაჩერებ.
# არასოდეს გავიქცევი და მიგატოვებ.
# არასოდეს გატირებს.
# არასოდეს დამშვიდობება.
# არასოდეს გეტყვი ტყუილს და გატკინებას.
#
#
# German
#
# Gebe dich nie auf.
# Ich werde dich nicht enttäuschen.
# Ich werde niemals herumrennen und dich verlassen.
# Ich werde dich niemals zum Weinen bringen.
# Ich werde niemals auf Wiedersehen sagen.
# Ich werde niemals eine Lüge erzählen und dich verletzen.
#
#
# Goan Konkani
#
# केन्नाच तुका सोडून दिवचे नात.
# केन्नाच तुका निराश जावचो ना.
# केन्नाच धांवून वचून तुका सोडून वचचो ना.
# केन्नाच रडोवंक ना.
# केन्नाच निरोप घेवपाचो ना.
# केन्नाच फट उलोवंक ना आनी तुका दुखोवचो ना.
#
#
# Greek
#
# Δεν θα σε παρατήσω ποτέ.
# Δεν θα σε απογοητεύσει ποτέ.
# Ποτέ δεν θα τρέξω και θα σε εγκαταλείψω.
# Ποτέ δεν θα σε κάνω να κλάψεις.
# Ποτέ δεν θα πει αντίο.
# Ποτέ δεν θα πω ψέματα και δεν θα σε πληγώσω.
#
#
# Guarani
#
# Araka'eve noñeme'ẽmo'ãi ndéve.
# Araka'eve ndohejamo'ãi ndéve.
# Araka'eve ndoñani mo'ãi ha nde deserta.
# Araka'eve ndojapomo'ãi nde repukavy.
# Araka'eve ndojedespedi mo'ãi.
# Araka'eve nde'imo'ãi japu ha nemoñeñandu vaíri.
#
#
# Gujarati
#
# હું ક્યારે પણ તારો સાથ નહિ છોડું.
# તમને ક્યારેય નિરાશ નહીં કરે.
# ક્યારેય તમારી આસપાસ દોડશે નહીં અને તમને છોડી દેશે નહીં.
# તને ક્યારેય રડાવશે નહીં.
# ક્યારેય ગુડબાય કહીશ નહીં.
# ક્યારેય જૂઠું બોલીને તમને નુકસાન પહોંચાડશે નહીં.
#
#
# Haitian Creole
#
# Pa janm pral lage ou.
# Pa janm pral kite ou desann.
# Pa janm pral kouri alantou ak abandone ou.
# Pa janm pral fè ou kriye.
# Pa janm pral di orevwa.
# Pa janm pral di yon manti ak fè ou mal.
#
#
# Hausa
#
# Ba za ku taɓa barin ku ba.
# Kada ku taɓa barin ku.
# Kada ku taɓa gudu ya bar ku.
# Kada ka taba yin kuka.
# Ba za a taɓa yin bankwana ba.
# Kada ku taɓa yin ƙarya kuma ku cutar da ku.
#
#
# Hawaiian
#
# ʻAʻole loa e haʻalele iā ʻoe.
# ʻAʻole loa e hoʻokuʻu iā ʻoe.
# ʻAʻole loa e holo a haʻalele iā ʻoe.
# ʻAʻole loa ʻoe e uē.
# ʻAʻole loa e ʻōlelo aloha.
# ʻAʻole loa e haʻi wahaheʻe a hōʻeha iā ʻoe.
#
#
# Hebrew
#
# לעולם לא אוותר עליך.
# לעולם לא יאכזב אותך.
# לעולם לא תרוץ ונוטש אותך.
# לעולם לא יגרום לך לבכות.
# לעולם לא אגיד שלום.
# לעולם אל אגיד שקר ויפגע בך.
#
#
# Hindi
#
# नेवर गोना गिव यू अप।
# आपको कभी निराश नहीं होने देंगे।
# कभी भी इधर-उधर नहीं भागेंगे और आपको छोड़ देंगे।
# आपको कभी रोने नहीं देंगे।
# कभी अलविदा नहीं कहूंगा।
# कभी झूठ नहीं बोलूंगा और आपको चोट पहुंचाऊंगा।
#
#
# Hmong
#
# Tsis txhob muab koj tso tseg.
# Tsis txhob cia koj poob.
# Tsis txhob khiav ncig thiab tso koj tseg.
# Tsis txhob ua rau koj quaj.
# Tsis txhob hais goodbye.
# Tsis txhob hais lus dag thiab ua phem rau koj.
#
#
# Hungarian
#
# Soha nem adlak fel.
# Soha nem hagylak cserben.
# Soha nem fogok elszaladni és elhagyni.
# Soha nem fog sírni.
# Soha nem fog búcsúzni.
# Soha nem fog hazudni és bántani.
#
#
# Icelandic
#
# Ætla aldrei að gefa þig upp.
# Ætla aldrei að svíkja þig.
# Ætla aldrei að hlaupa um og yfirgefa þig.
# Mun aldrei láta þig gráta.
# Ætla aldrei að kveðja.
# Ætla aldrei að ljúga og særa þig.
#
#
# Igbo
#
# Agaghị agbarapụ gị ma ncha.
# Agaghị emechu gị ihu.
# Agaghị agba ọsọ gbahapụ gị.
# Agaghị eme ka ị ibe ákwá.
# Agaghị asị nke ọma.
# Ya adịla mgbe ị ga-agha ụgha ma mejọọ gị.
#
#
# Iloko
#
# Never gonna sumuko kenka.
# Never gonna let you nga agpababa.
# Never gonna run around ken mangbaybay-a kenka.
# Never gonna make you nga agsangit.
# Never gonna agpakada.
# Never gonna tell a lie ken masaktannaka.
#
#
# Indonesian
#
# Tak akan menyerahkanmu.
# Tidak akan pernah mengecewakanmu.
# Tidak akan pernah berlarian dan meninggalkanmu.
# Tidak akan pernah membuatmu menangis.
# Tidak akan pernah mengucapkan selamat tinggal.
# Tidak akan pernah berbohong dan menyakitimu.
#
#
# Irish
#
# Ná tabhair suas tú choíche.
# Ná ligfidh tú síos go deo.
# Ná rith timpeall agus ní thréigfidh tú thú.
# Ná ligfidh tú do caoineadh go deo.
# Ná rá slán a fhágáil go deo.
# Ná inseoidh sé bréag agus ní ghortóidh sé tú.
#
#
# Italian
#
# Non ti lascerà mai stare.
# Non ti deluderò mai
# Non correrò mai in giro e ti abbandonerò.
# Non ti farò mai piangere.
# Non dirò mai addio.
# Non dirò mai una bugia e ti ferirò.
#
#
# Japanese
#
# あなたをあきらめるつもりはありません。
# あなたをがっかりさせることはありません。
# 走り回ってあなたを見捨てることは決してありません。
# あなたを泣かせるつもりはありません。
# さよならを言うつもりはありません。
# 決して嘘をついてあなたを傷つけるつもりはありません。
#
#
# Javanese
#
# Ora bakal nyerah.
# Ora bakal nguciwani sampeyan.
# Ora bakal mlayu lan ninggalake sampeyan.
# Ora bakal nggawe sampeyan nangis.
# Ora bakal pamit.
# Ora bakal ngapusi lan nglarani kowe.
#
#
# Kannada
#
# ನಿಮ್ಮನ್ನು ಎಂದಿಗೂ ಬಿಟ್ಟುಕೊಡುವುದಿಲ್ಲ.
# ನಿಮ್ಮನ್ನು ಎಂದಿಗೂ ನಿರಾಸೆಗೊಳಿಸುವುದಿಲ್ಲ.
# ಎಂದಿಗೂ ಓಡಿಹೋಗಿ ನಿಮ್ಮನ್ನು ಬಿಟ್ಟುಬಿಡುವುದಿಲ್ಲ.
# ನಿಮ್ಮನ್ನು ಎಂದಿಗೂ ಅಳುವಂತೆ ಮಾಡುವುದಿಲ್ಲ.
# ಎಂದಿಗೂ ವಿದಾಯ ಹೇಳುವುದಿಲ್ಲ.
# ಎಂದಿಗೂ ಸುಳ್ಳನ್ನು ಹೇಳಿ ನಿಮ್ಮನ್ನು ನೋಯಿಸುವುದಿಲ್ಲ.
#
#
# Kazakh
#
# Ешқашан сені қалдырмаймын.
# Сізді ешқашан түсірмеймін.
# Ешқашан жүгіріп, сені тастамаймын.
# Сізді ешқашан жылатпаймын.
# Ешқашан қоштаспаймын.
# Ешқашан өтірік айтып, сені ренжітпеймін.
#
#
# Khmer
#
# នឹង​មិន​ផ្ដល់​ឱ្យ​អ្នក​ឡើង។
# នឹងមិនធ្វើឱ្យអ្នកខកចិត្តឡើយ។
# មិនដែលរត់ចោលអ្នកឡើយ
# មិនដែលធ្វើឱ្យអ្នកយំទេ។
# មិនដែលនិយាយលាទេ។
# មិនដែលនិយាយកុហក និងធ្វើឱ្យអ្នកឈឺចាប់ឡើយ។
#
#
# Kinyarwanda
#
# Ntuzigera ugutererana.
# Ntuzigera ugutererana.
# Ntuzigere wiruka ukagutererana.
# Ntuzigere urira.
# Ntuzigera usezera.
# Ntuzigere uvuga ibinyoma kandi bikakubabaza.
#
#
# Korean
#
# 절대 당신을 포기하지 않을 것입니다.
# 당신을 실망시키지 않을 것입니다.
# 절대 뛰어다니고 널 버리지 않을거야.
# 절대 당신을 울게 만들지 않을 것입니다.
# 절대 작별 인사를 하지 않을거야.
# 절대 거짓말을 해서 당신을 다치게 하지 않을 것입니다.
#
#
# Krio
#
# Neva gonna giv yu up.
# Neva gonna let yu down.
# Neva gonna run around en desert yu.
# Neva gonna mek yu kray.
# Neva gonna se gudbai.
# Neva gonna tell a lie en hurt yu.
#
#
# Kurdish (Kurmanji)
#
# Tu carî dev ji we bernade.
# Dê tu carî te nehêle.
# Dê tu carî birevin û ji we nerevin.
# Dê tu carî te negirî.
# Tu carî xatir nabêje.
# Tu carî derewan nabêje û êşê nade te.
#
#
# Kurdish (Sorani)
#
# هەرگیز دەستبەردارت نابم.
# هەرگیز بێهیوات ناکات.
# هەرگیز بەدەوریدا ڕاناکەم و بەجێت ناهێڵم.
# هەرگیز ناتخاتە گریان.
# هەرگیز ماڵئاوایی ناکەم.
# هەرگیز درۆیەک ناڵێم و ئازارت نادات.
#
#
# Kyrgyz
#
# Сени эч качан таштабайм.
# Сени эч качан таштабайм.
# Эч качан ары-бери чуркап, сени таштап кетпейм.
# Сени эч качан ыйлатпайм.
# Эч качан коштошпойм.
# Эч качан калп айтып, сени капа кылбайм.
#
#
# Lao
#
# ບໍ່​ເຄີຍ​ຈະ​ໃຫ້​ທ່ານ​ເຖິງ​.
# ບໍ່ເຄີຍເຮັດໃຫ້ເຈົ້າຕົກໃຈ.
# ບໍ່​ເຄີຍ​ຈະ​ແລ່ນ​ອ້ອມ​ແລະ​ປະ​ຖິ້ມ​ທ່ານ​.
# ບໍ່ເຄີຍເຮັດໃຫ້ເຈົ້າຮ້ອງໄຫ້.
# ບໍ່ເຄີຍເວົ້າລາ.
# ບໍ່ເຄີຍເວົ້າຕົວະ ແລະທຳຮ້າຍເຈົ້າ.
#
#
# Latin
#
# Non te deseram.
# Numquam amet te descendit.
# Numquam amet discurrere ac deseram.
# Numquam agnus te clamare.
# Numquam agnus vale dicere.
# Numquam amet mendacium dicere et nocere tibi.
#
#
# Latvian
#
# Nekad nepadosies tev.
# Nekad tevi nepievils.
# Nekad neskraidīšu un nepametīšu tevi.
# Nekad neliks tev raudāt.
# Nekad neatvadīšos.
# Nekad nemelošu un nesāpināšu tevi.
#
#
# Lingala
#
# Jamais nakotika yo.
# Jamais nako décevoir yo.
# Jamais nako kima zinga zinga pe ko désert yo.
# Jamais ekosala yo olela.
# Jamais nakoloba adieux.
# Jamais nakoloba lokuta pe kozokisa yo.
#
#
# Lithuanian
#
# Niekada tavęs nepasiduos.
# Niekada tavęs nenuvils.
# Niekada nebėgsiu ir neapleisiu tavęs.
# Niekada neprivers tavęs verkti.
# Niekada neatsisveikinsiu.
# Niekada nemeluosiu ir tavęs neįskaudinsiu.
#
#
# Luxembourgish
#
# Ech ginn dech nimools op.
# Loosst dech ni erof.
# Ni lafe ronderëm an desertéieren.
# Ni wäert Iech kräischen.
# Ni wäert Äddi soen.
# Ni wäert eng Ligen soen an Iech verletzen.
#
#
# Macedonian
#
# Никогаш нема да се откажам од тебе.
# Никогаш нема да те изневерам.
# Никогаш нема да трчам наоколу и да те напуштам.
# Никогаш нема да те расплачам.
# Никогаш нема да се збогувам.
# Никогаш нема да кажам лага и да те повредам.
#
#
# Maithili
#
# कहियो अहाँकेँ हार नहि मानब।
# कहियो अहाँकेँ निराश नहि करब।
# कहियो दौड़ैत-दौड़ैत अहाँकेँ छोड़ि नहि देब।
# कहियो कानब नहि।
# कहियो विदाई नहि कहब।
# कहियो झूठ नहि बाजब आ अहाँ के चोट नहि पहुँचाब।
#
#
# Malagasy
#
# Never gonna give you up.
# Tsy hanadino anao mihitsy.
# Tsy hihazakazaka sy handao anao mihitsy.
# Tsy hampitomany anao mihitsy.
# Tsy hanao veloma mihitsy.
# Tsy handainga mihitsy ka handratra anao.
#
#
# Malay
#
# Tidak akan pernah menyerah kalah.
# Tidak akan mengecewakan anda.
# Tidak akan pernah berlari dan meninggalkan anda.
# Takkan pernah buat awak menangis.
# Tidak akan pernah mengucapkan selamat tinggal.
# Tidak akan pernah bercakap bohong dan menyakiti anda.
#
#
# Malayalam
#
# ഒരിക്കലും നിന്നെ ഉപേക്ഷിക്കാൻ പോകുന്നില്ല.
# നിങ്ങളെ ഒരിക്കലും നിരാശപ്പെടുത്തില്ല.
# ഒരിക്കലും ഓടിച്ചെന്ന് നിങ്ങളെ കൈവിടില്ല.
# ഒരിക്കലും നിന്നെ കരയിപ്പിക്കില്ല.
# ഒരിക്കലും വിട പറയില്ല.
# ഒരിക്കലും നുണ പറഞ്ഞു നിങ്ങളെ വേദനിപ്പിക്കില്ല.
#
#
# Maltese
#
# Qatt m'hu ħa nitilqek.
# Qatt mhu ser inħallik.
# Qatt mhu se tiġri u tiżerġik.
# Qatt mhu ser iġġiegħlek tibki.
# Qatt mhu se ngħid addiju.
# Qatt ma ser tgħid gidba u tweġġgħek.
#
#
# Manipuri (Meitei Mayek)
#
# ꯀꯩꯗꯧꯉꯩꯗꯁꯨ ꯅꯉꯕꯨ ꯊꯥꯗꯣꯛꯂꯣꯏꯗꯕꯅꯤ꯫
# ꯀꯩꯗꯧꯉꯩꯗꯁꯨ ꯅꯉꯕꯨ ꯅꯨꯡꯉꯥꯏꯇꯕꯥ ꯐꯥꯑꯣꯍꯜꯂꯣꯏ꯫
# ꯀꯩꯗꯧꯉꯩꯗꯁꯨ ꯂꯥꯟꯊꯦꯡꯅꯗꯨꯅꯥ ꯅꯍꯥꯀꯄꯨ ꯃꯔꯨ ꯑꯣꯏꯅꯥ ꯂꯧꯔꯣꯏ꯫
# ꯀꯩꯗꯧꯉꯩꯗꯁꯨ ꯅꯉꯕꯨ ꯀꯞꯄꯥ ꯉꯃꯂꯣꯏ꯫
# ꯀꯩꯗꯧꯉꯩꯗꯁꯨ ꯒꯨꯗꯕꯥꯏ ꯍꯥꯌꯔꯣꯏ꯫
# ꯀꯩꯗꯧꯉꯩꯗꯁꯨ ꯑꯔꯥꯅꯕꯥ ꯋꯥꯐꯝ ꯑꯃꯥ ꯍꯥꯌꯔꯣꯏ ꯑꯃꯁꯨꯡ ꯅꯍꯥꯀꯄꯨ ꯁꯣꯀꯍꯜꯂꯣꯏ꯫
#
#
# Maori
#
# E kore koe e tuku.
# E kore koe e tuku iho.
# E kore koe e oma haere ka whakarere i a koe.
# E kore koe e tangi.
# E kore e poroporoaki.
# E kore koe e korero teka ka mamae koe.
#
#
# Marathi
#
# तुला कधीच सोडणार नाही.
# तुम्हाला कधीही निराश करणार नाही.
# कधीही इकडे तिकडे पळणार नाही आणि तुम्हाला सोडून जाणार नाही.
# तुला कधीही रडवणार नाही.
# कधीच निरोप घेणार नाही.
# कधीही खोटे बोलून तुम्हाला दुखावणार नाही.
#
#
# Mizo
#
# Engtikah mah i bânsan ngai lo vang.
# Never gonna let you tih hi a ni.
# Never gonna run around leh thlaler che.
# Engtikah mah i tap tir ngai lovang.
# Never gonna say goodbye.
# Thu dik lo sawiin a ti na ngai lovang.
#
#
# Mongolian
#
# Чамд хэзээ ч бууж өгөхгүй.
# Чамайг хэзээ ч сэтгэлээр унагахгүй.
# Хэзээ ч ийш тийш гүйж, чамайг орхихгүй.
# Чамайг хэзээ ч уйлуулахгүй.
# Хэзээ ч баяртай гэж хэлэхгүй.
# Хэзээ ч худлаа ярьж чамайг гомдоохгүй.
#
#
# Myanmar (Burmese)
#
# ဘယ်တော့မှလက်မလျှော့ဘူး။
# မင်းကို ဘယ်တော့မှ စိတ်မပျက်စေနဲ့။
# မင်းကို ဘယ်တော့မှ ပြေးမပစ်ဘူး။
# မင်းကို ဘယ်တော့မှ ငိုစေမှာမဟုတ်ဘူး။
# ဘယ်တော့မှ နှုတ်မဆက်ဘူး။
# ဘယ်တော့မှ လိမ်ညာပြီး စိတ်ထိခိုက်မှာ မဟုတ်ဘူး။
#
#
# Nepali
#
# तिमीलाई कहिल्यै छाड्ने छैन।
# तिमीलाई कहिल्यै निराश पार्ने छैन।
# कहिले पनि वरिपरि दौडने छैन र तपाईलाई त्याग्नेछ।
# तिमीलाई कहिल्यै रुवाउने छैन।
# कहिल्यै अलविदा भन्न छैन।
# कहिल्यै झुट बोल्ने र तपाईलाई चोट पुर्याउने छैन।
#
#
# Northern Sotho
#
# Never gonna go go gafa.
# Never gonna go go nyamiša.
# Never gonna run around gomme a go tlogela.
# Never gonna go go lla.
# Never gonna re laelana.
# Never gonna tell a lie and go go kweša bohloko.
#
#
# Norwegian
#
# Kommer aldri til å gi deg opp.
# Kommer aldri til å svikte deg.
# Kommer aldri til å løpe rundt og forlate deg.
# Kommer aldri til å få deg til å gråte.
# Kommer aldri til å si farvel.
# Kommer aldri til å lyve og såre deg.
#
#
# Odia (Oriya)
#
# କଦାପି ତୁମକୁ ଛାଡିବ ନାହିଁ |
# ତୁମକୁ କେବେ ବି ହତାଶ କରିବ ନାହିଁ |
# କଦାପି ବୁଲିବ ନାହିଁ ଏବଂ ତୁମକୁ ପରିତ୍ୟାଗ କରିବ ନାହିଁ |
# କଦାପି ତୁମକୁ କାନ୍ଦିବ ନାହିଁ |
# କଦାପି ବିଦାୟ ନେବେ ନାହିଁ |
# କଦାପି ମିଛ କହିବ ନାହିଁ ଏବଂ ତୁମକୁ ଆଘାତ କରିବ ନାହିଁ |
#
#
# Oromo
#
# Gonkumaa siif hin dhiisu.
# Gonkumaa si hin gadi dhiisu.
# Gonkumaa fiigdee si dhiisee hin deemu.
# Gonkumaa si boochisuu hin danda'u.
# Gonkumaa nagaa dhaamuuf hin jiru.
# Gonkumaa soba dubbadhee si hin miidhu.
#
#
# Pashto
#
# تا به کله هم نه پردی کوم.
# هيڅکله به تاسو نه پرېږدي.
# هيڅکله به درڅخه وتښتي او تاسو پريږدي.
# هیڅکله به تاسو ژاړئ.
# هیڅکله به الوداع نه وایم.
# هیڅکله به درواغ ونه وایی او تاسو ته زیان ونه رسوي.
#
#
# Persian
#
# هرگز تو را رها نمی کنم
# هرگز ناامیدت نمیکنم
# هرگز نمی دوم و تو را رها نمی کنم.
# هرگز تو را به گریه نمی اندازد
# هرگز خداحافظی نمی کنم
# هرگز دروغ نمی گویم و به تو صدمه نمی زنم.
#
#
# Polish
#
# Nigdy się nie poddawaj.
# Nigdy cię nie zawiodę.
# Nigdy nie będę biegać w kółko i cię opuścić.
# Nigdy nie doprowadzę cię do płaczu.
# Nigdy się nie pożegnam.
# Nigdy nie skłamię i nie skrzywdzę cię.
#
#
# Portuguese
#
# Nunca vou desistir de você.
# Nunca vou deixar você para baixo.
# Nunca vou correr e abandonar você.
# Nunca vou fazer você chorar.
# Nunca vou dizer adeus.
# Nunca vou contar uma mentira e te machucar.
#
#
# Punjabi
#
# ਹਾਰ ਨਾ ਮੰਨਣਾ.
# ਤੁਹਾਨੂੰ ਕਦੇ ਨਿਰਾਸ਼ ਨਹੀਂ ਹੋਣ ਦੇਵੇਗਾ।
# ਕਦੇ ਵੀ ਆਲੇ-ਦੁਆਲੇ ਨਹੀਂ ਭੱਜਾਂਗਾ ਅਤੇ ਤੁਹਾਨੂੰ ਛੱਡ ਕੇ ਨਹੀਂ ਜਾਵਾਂਗਾ।
# ਤੁਹਾਨੂੰ ਕਦੇ ਰੋਣ ਨਹੀਂ ਦੇਵੇਗਾ.
# ਕਦੇ ਵੀ ਅਲਵਿਦਾ ਨਹੀਂ ਕਹਾਂਗਾ।
# ਕਦੇ ਝੂਠ ਨਹੀਂ ਬੋਲਾਂਗਾ ਅਤੇ ਤੁਹਾਨੂੰ ਦੁਖੀ ਨਹੀਂ ਕਰਾਂਗਾ।
#
#
# Quechua
#
# Manam haykapipas saqisqaykichu.
# Manam haykapipas hukmanyachisunkichu.
# Mana hayk’aqpas phawaylla phawaykuspa ch’usaqyachisunkichu.
# Manam haykapipas waqachisunkichu.
# Mana hayk'aqpas despedikusaqchu.
# Mana hayk’aqpas llullakuspa k’irisunkichu.
#
#
# Romanian
#
# Nu renunţ la tine niciodată.
# Nu te voi dezamăgi niciodată.
# N-o să alerg niciodată și să te părăsească.
# N-o să te facă niciodată să plângi.
# N-o să-ți spun niciodată la revedere.
# N-o să spun niciodată o minciună și să te rănesc.
#
#
# Russian
#
# Никогда тебя не брошу.
# Никогда не подведу тебя.
# Никогда не буду бегать и бросать тебя.
# Никогда не заставлю тебя плакать.
# Никогда не попрощаюсь.
# Никогда не солгу и не причиню тебе вреда.
#
#
# Samoan
#
# E le mafai lava ona e fiu.
# O le a le fa'avaivai lava oe.
# E le toe tamo'e solo ma tuulafoaiina oe.
# E le mafai lava ona e tagi.
# E le toe fa'atofa lava.
# E le taitai pepelo lava ma faatiga ia te oe.
#
#
# Sanskrit
#
# कदापि भवन्तं न त्यक्ष्यति।
# कदापि भवन्तं निराशं न करिष्यति।
# कदापि न धावित्वा भवन्तं परित्यक्ष्यति।
# कदापि भवन्तं रोदनं न करिष्यति।
# कदापि विदां न करिष्यामि।
# कदापि असत्यं वदन् भवन्तं आहतं न करिष्यति।
#
#
# Scots Gaelic
#
# Na toir seachad thu gu bràth.
# Na leig thu sìos gu bràth.
# Na ruith gu bràth mun cuairt agus na trèigsinn thu.
# Na toir ort caoineadh gu bràth.
# Na bi a-riamh ag ràdh soraidh slàn.
# Na bi a-riamh ag innse breug agus gad ghortachadh.
#
#
# Serbian
#
# Никад те нећу напустити.
# Никад те нећу изневерити.
# Никада нећу трчати около и напустити те.
# Никад те нећу расплакати.
# Никад се нећу опростити.
# Никада нећу рећи лаж и повриједити те.
#
#
# Sesotho
#
# Nka se u tlohele le ka mohla.
# Le ka mohla nke ke ka u nyahamisa.
# Le ka mohla nke ke ka matha ho pota-pota le ho u lahla.
# Le ka mohla u ke ke ua lla.
# Le ka mohla u ke ke ua re sala hantle.
# Le ka mohla u se ke ua bua leshano le ho u utloisa bohloko.
#
#
# Shona
#
# Handifi ndakakusiya.
# Handifi ndakakusiya iwe.
# Handife ndakamhanya ndichikusiya.
# Handifi ndakakuita kuti ucheme.
# Handife ndakataura zvakanaka.
# Usambonyepa nekukukuvadza.
#
#
# Sindhi
#
# توهان کي ڪڏهن به نه ڇڏيندس.
# توهان کي ڪڏهن به مايوس نه ڪندس.
# ڪڏهن به توهان جي چوڌاري نه ڊوڙندو ۽ توهان کي ڇڏي ڏي.
# توکي ڪڏهن به روئڻ نه ڏيندس.
# ڪڏهن به الوداع نه چوندا.
# ڪڏهن به ڪوڙ نه ڳالهائيندو ۽ توهان کي نقصان پهچائيندو.
#
#
# Sinhala
#
# ඔයාව කවදාවත් අත්හැර දමන්න යන්නේ නැහැ.
# කවදාවත් ඔබව පහත් කරන්නේ නැහැ.
# කවදාවත් දුවලා ගිහින් ඔයාව දාලා යන්නෙ නෑ.
# කවදාවත් ඔයාව අඬන්නෙ නෑ.
# කවදාවත් සමුගන්නේ නැහැ.
# කවදාවත් බොරුවක් කියලා හිත රිද්දන්නේ නෑ.
#
#
# Slovak
#
# Nikdy sa ťa nevzdám.
# Nikdy ťa nesklame.
# Nikdy nebudem behať a opustiť ťa.
# Nikdy ťa nerozplače.
# Nikdy sa nerozlúčim.
# Nikdy nebudem klamať a ublížiť ti.
#
#
# Slovenian
#
# Nikoli se ti ne bom odrekel.
# Nikoli te ne bom razočaral.
# Nikoli ne bom tekel naokoli in te zapustil.
# Nikoli te ne bom spravil v jok.
# Nikoli se ne bom poslovil.
# Nikoli ne bom lagal in te prizadel.
#
#
# Somali
#
# Waligaa kuma dhiibi doono.
# Weligaa kuma dayn doono.
# Waligaa kuma ordi doontid oo kaa tagin.
# Weligaa kuma ooyin.
# Waligaa ma dhihin nabad galyo.
# Weligaa been ha sheegin oo ku yeeli mayso.
#
#
# Spanish
#
# Nunca va a dar.
# Nunca te voy a decepcionar.
# Nunca voy a correr y abandonarte.
# Nunca te haré llorar.
# Nunca voy a decir adiós.
# Nunca voy a decir una mentira y lastimarte.
#
#
# Sundanese
#
# Moal ngantep anjeun nyerah.
# Moal nguciwakeun anjeun.
# Pernah gonna ngajalankeun sabudeureun tur gurun anjeun.
# Moal pernah ngajadikeun anjeun ceurik.
# Moal pernah pamit.
# Moal pernah bohong sareng menyakiti anjeun.
#
#
# Swahili
#
# Sitakuacha kamwe.
# Sitawahi kukukatisha tamaa.
# Kamwe sitakimbia na kukuacha.
# Kamwe sitakufanya ulie.
# Kamwe sitasema kwaheri.
# Kamwe sitasema uwongo na kukuumiza.
#
#
# Swedish
#
# Ska aldrig ge dig upp.
# Kommer aldrig att svika dig.
# Kommer aldrig springa runt och överge dig.
# Kommer aldrig få dig att gråta.
# Kommer aldrig säga adjö.
# Kommer aldrig att ljuga och skada dig.
#
#
# Tajik
#
# Ҳаргиз туро раҳо намекунам.
# Ҳеҷ гоҳ шуморо ноумед намекунам.
# Ҳеҷ гоҳ дар гирду атроф давида, шуморо тарк нахоҳам кард.
# Ҳеҷ гоҳ туро гиря намекунам.
# Ҳеҷ гоҳ хайрбод намегӯям.
# Ҳеҷ гоҳ дурӯғ нагӯям ва шуморо хафа накунам.
#
#
# Tamil
#
# எப்போதும் உன்னை கை விட மாட்டேன்.
# உங்களை ஒருபோதும் வீழ்த்த மாட்டேன்.
# ஒருபோதும் ஓடிவந்து உன்னை விட்டு வெளியேற மாட்டேன்.
# உன்னை ஒருபோதும் அழ வைக்க மாட்டேன்.
# ஒருபோதும் விடைபெற மாட்டேன்.
# ஒருபோதும் பொய் சொல்லி உங்களை காயப்படுத்த மாட்டேன்.
#
#
# Tatar
#
# Беркайчан да сезне ташларга җыенмыйм.
# Сезне беркайчан да рәнҗетмәячәкмен.
# Беркайчан да йөгереп китмәячәкмен.
# Сезне беркайчан да елатмас.
# Беркайчан да саубуллашмыйм.
# Беркайчан да ялган сөйләргә һәм рәнҗетергә ярамый.
#
#
# Telugu
#
# నిన్ను ఎప్పటికీ వదులుకోను.
# నిన్ను ఎప్పుడూ నిరాశపరచను.
# ఎప్పుడూ పరిగెత్తి నిన్ను విడిచిపెట్టను.
# నిన్ను ఎప్పటికీ ఏడిపించను.
# ఎప్పటికీ వీడ్కోలు చెప్పను.
# ఎప్పుడూ అబద్ధం చెప్పి మిమ్మల్ని బాధపెట్టను.
#
#
# Thai
#
# ไม่เคยจะให้คุณขึ้น
# ไม่เคยจะทำให้คุณผิดหวัง
# ไม่เคยจะวิ่งไปรอบ ๆ และทอดทิ้งคุณ
# ไม่เคยจะทำให้คุณร้องไห้
# ไม่เคยจะกล่าวคำอำลา
# ไม่เคยจะโกหกและทำร้ายคุณ
#
#
# Tigrinya
#
# ፈጺሙ ኣይገድፈካን እዩ።
# ፈጺሙ ከሕፍር ኣይክእልን እዩ።
# ፈጺሙ ጎይዩ ኣብ ምድረበዳኻ ኣይክተርፍን እዩ።
# ፈጺሙ ከብክየካ ኣይክእልን እዩ።
# ፈጺመ ተፋንዩ ኣይኮንኩን።
# ሓሶት ተዛሪቡ ኣይጎድኣካን ፈጺሙ።
#
#
# Tsonga
#
# A ndzi nge pfuki ndzi ku tshikile.
# Never gonna ku ku khomisa tingana.
# Never gonna run around yi ku tshika.
# Never gonna ku ku endla u rila.
# A ndzi nge pfuki ndzi hambanile.
# Never gonna tell a lie yi ku vavisa.
#
#
# Turkish
#
# Senden asla vazgeçmeyeceğim.
# Seni asla hayal kırıklığına uğratmayacağım.
# Asla ortalıkta dolaşıp seni terk etmeyeceğim.
# Seni asla ağlatmayacağım.
# Asla vedalaşmayacağım.
# Asla yalan söylemez ve seni incitmez.
#
#
# Turkmen
#
# Hiç haçan senden ýüz öwürmerin.
# Hiç haçan seni ruhdan düşürmerin.
# Hiç haçan ylgap, seni terk etmerin.
# Hiç haçan seni aglatjak däl.
# Hiç haçan hoşlaşjak däl.
# Hiç haçan ýalan sözlemez we saňa zyýan bermerin.
#
#
# Ukrainian
#
# Ніколи не здам тебе.
# Ніколи не підведу вас.
# Ніколи не буду бігати і покидати вас.
# Ніколи не змусить вас плакати.
# Ніколи не прощаюся.
# Ніколи не збрешу і не заподію тобі болю.
#
#
# Urdu
#
# آپ کو کبھی نہیں چھوڑوں گا۔
# آپ کو کبھی مایوس نہیں ہونے دیں گے۔
# کبھی بھی آپ کے ارد گرد بھاگنے اور آپ کو چھوڑنے والا نہیں ہے۔
# آپ کو کبھی نہیں رونے دوں گا۔
# کبھی الوداع نہیں کہوں گا۔
# کبھی جھوٹ نہیں بولیں گے اور آپ کو تکلیف نہیں دیں گے۔
#
#
# Uyghur
#
# ھەرگىز سىزدىن ۋاز كەچمەيدۇ.
# ھەرگىز سىزنى ئۈمىدسىزلەندۈرمەيدۇ.
# ھەرگىز يۈگۈرۈپ بېرىپ سىزنى تاشلىۋەتمەڭ.
# ھەرگىز سېنى يىغلىمايدۇ.
# ھەرگىز خوشلاشمايمەن.
# ھەرگىز يالغان سۆزلىمەيدۇ ۋە سىزگە ئازار بەرمەيدۇ.
#
#
# Uzbek
#
# Hech qachon sendan voz kechmayman.
# Hech qachon sizni tushkunlikka tushirmayman.
# Hech qachon yugurib sizni tashlab ketmayman.
# Sizni hech qachon yig'latmaydi.
# Hech qachon xayrlashmayman.
# Hech qachon yolg'on gapirmayman va sizni xafa qilmayman.
#
#
# Vietnamese
#
# Tôi không đời nào bỏ cậu đâu.
# Sẽ không bao giờ làm bạn thất vọng.
# Sẽ không bao giờ chạy xung quanh và bỏ rơi bạn.
# Sẽ không bao giờ làm bạn khóc.
# Sẽ không bao giờ nói lời tạm biệt.
# Sẽ không bao giờ nói dối và làm tổn thương bạn.
#
#
# Welsh
#
# Byth yn mynd i roi'r gorau iddi.
# Ni fydd byth yn eich siomi.
# Peidiwch byth â rhedeg o gwmpas a'ch gadael.
# Byth yn mynd i wneud i chi grio.
# Byth yn mynd i ffarwelio.
# Byth yn mynd i ddweud celwydd a brifo chi.
#
#
# Xhosa
#
# Andisoze ndancama.
# Andisoze ndikuphoxe.
# Andisoze ndibaleke ndikushiye.
# Soze ndikukhalise.
# Ungaze uthi goodbye.
# Ungaze uxoke kwaye ukulimaze.
#
#
# Yiddish
#
# קיינמאָל וועט געבן איר אַרויף.
# קיינמאָל וועט לאָזן איר אַראָפּ.
# קיינמאָל גיין אַרום און וויסט איר.
# קיינמאָל וועט מאַכן איר וויינען.
# קיינמאָל וועט זאָגן זייַ געזונט.
# קיינמאָל זאָגן אַ ליגן און שאַטן איר.
#
#
# Yoruba
#
# Mi o ni fi ọ silẹ laelae.
# Maṣe jẹ ki o ṣubu.
# Maṣe sare ni ayika ati kọ ọ silẹ.
# Maṣe jẹ ki o kigbe.
# Maṣe sọ o dabọ.
# Maṣe parọ rara ki o si ṣe ọ lara.
#
#
# Zulu
#
# Angisoze ngalilahla ithemba.
# Ngeke ngikudumaze.
# Angisoze ngagijima ngiyokulahla.
# Ngeke ngikukhalise.
# Ngeke ngivalelise.
# Ungalokothi uqambe amanga futhi ukulimaze.
#
#
# Hebrew
#
# לעולם לא אוותר עליך.
# לעולם לא יאכזב אותך.
# לעולם לא תרוץ ונוטש אותך.
# לעולם לא יגרום לך לבכות.
# לעולם לא אגיד שלום.
# לעולם אל אגיד שקר ויפגע בך.
#
#
# Javanese
#
# Ora bakal nyerah.
# Ora bakal nguciwani sampeyan.
# Ora bakal mlayu lan ninggalake sampeyan.
# Ora bakal nggawe sampeyan nangis.
# Ora bakal pamit.
# Ora bakal ngapusi lan nglarani kowe.
#
#
# Chinese (Simplified)
#
# 绝不会放弃你。
# 永远不会让你失望。
# 永远不会跑来跑去抛弃你。
# 永远不会让你哭泣。
# 永远不会说再见。
# 永远不会说谎伤害你。

# %% [markdown]
# ### Detect the languages?

# %%
languages[0]
# Out:
# {'language': 'af',
#  'name': 'Afrikaans',
#  'lyric': "\nGaan jou nooit opgee nie.\nGaan jou nooit in die steek laat nie.\nGaan nooit rondhardloop en jou in die steek laat nie.\nSal jou nooit laat huil nie.\nGaan nooit totsiens sê nie.\nGaan nooit 'n leuen vertel en jou seermaak nie.\n"}

# %%
for i, language in enumerate(languages):
    languages[i]['detected_language'] = translate_client.detect_language(language['lyric'])['language']

# %%
for language in languages:
    print("For lyrics in {} ({}) the detect language was {}.".format(language['name'],language['language'],language['detected_language']))
# Out:
# For lyrics in Afrikaans (af) the detect language was af.
# For lyrics in Akan (ak) the detect language was ak.
# For lyrics in Albanian (sq) the detect language was sq.
# For lyrics in Amharic (am) the detect language was am.
# For lyrics in Arabic (ar) the detect language was ar.
# For lyrics in Armenian (hy) the detect language was hy.
# For lyrics in Assamese (as) the detect language was as.
# For lyrics in Aymara (ay) the detect language was ay.
# For lyrics in Azerbaijani (az) the detect language was az.
# For lyrics in Bambara (bm) the detect language was bm.
# For lyrics in Basque (eu) the detect language was eu.
# For lyrics in Belarusian (be) the detect language was be.
# For lyrics in Bengali (bn) the detect language was bn.
# For lyrics in Bhojpuri (bho) the detect language was bho.
# For lyrics in Bosnian (bs) the detect language was hr.
# For lyrics in Bulgarian (bg) the detect language was bg.
# For lyrics in Catalan (ca) the detect language was ca.
# For lyrics in Cebuano (ceb) the detect language was ceb.
# For lyrics in Chichewa (ny) the detect language was ny.
# For lyrics in Chinese (Simplified) (zh) the detect language was zh-CN.
# For lyrics in Chinese (Traditional) (zh-TW) the detect language was zh-TW.
# For lyrics in Corsican (co) the detect language was co.
# For lyrics in Croatian (hr) the detect language was hr.
# For lyrics in Czech (cs) the detect language was cs.
# For lyrics in Danish (da) the detect language was da.
# For lyrics in Divehi (dv) the detect language was dv.
# For lyrics in Dogri (doi) the detect language was doi.
# For lyrics in Dutch (nl) the detect language was nl.
# For lyrics in English (en) the detect language was en.
# For lyrics in Esperanto (eo) the detect language was eo.
# For lyrics in Estonian (et) the detect language was et.
# For lyrics in Ewe (ee) the detect language was ee.
# For lyrics in Filipino (tl) the detect language was fil.
# For lyrics in Finnish (fi) the detect language was fi.
# For lyrics in French (fr) the detect language was fr.
# For lyrics in Frisian (fy) the detect language was fy.
# For lyrics in Galician (gl) the detect language was gl.
# For lyrics in Ganda (lg) the detect language was lg.
# For lyrics in Georgian (ka) the detect language was ka.
# For lyrics in German (de) the detect language was de.
# For lyrics in Goan Konkani (gom) the detect language was gom.
# For lyrics in Greek (el) the detect language was el.
# For lyrics in Guarani (gn) the detect language was gn.
# For lyrics in Gujarati (gu) the detect language was gu.
# For lyrics in Haitian Creole (ht) the detect language was ht.
# For lyrics in Hausa (ha) the detect language was ha.
# For lyrics in Hawaiian (haw) the detect language was haw.
# For lyrics in Hebrew (iw) the detect language was iw.
# For lyrics in Hindi (hi) the detect language was hi.
# For lyrics in Hmong (hmn) the detect language was hmn.
# For lyrics in Hungarian (hu) the detect language was hu.
# For lyrics in Icelandic (is) the detect language was is.
# For lyrics in Igbo (ig) the detect language was ig.
# For lyrics in Iloko (ilo) the detect language was ilo.
# For lyrics in Indonesian (id) the detect language was id.
# For lyrics in Irish (ga) the detect language was ga.
# For lyrics in Italian (it) the detect language was it.
# For lyrics in Japanese (ja) the detect language was ja.
# For lyrics in Javanese (jw) the detect language was jv.
# For lyrics in Kannada (kn) the detect language was kn.
# For lyrics in Kazakh (kk) the detect language was kk.
# For lyrics in Khmer (km) the detect language was km.
# For lyrics in Kinyarwanda (rw) the detect language was rw.
# For lyrics in Korean (ko) the detect language was ko.
# For lyrics in Krio (kri) the detect language was kri.
# For lyrics in Kurdish (Kurmanji) (ku) the detect language was ku.
# For lyrics in Kurdish (Sorani) (ckb) the detect language was ckb.
# For lyrics in Kyrgyz (ky) the detect language was ky.
# For lyrics in Lao (lo) the detect language was lo.
# For lyrics in Latin (la) the detect language was la.
# For lyrics in Latvian (lv) the detect language was lv.
# For lyrics in Lingala (ln) the detect language was ln.
# For lyrics in Lithuanian (lt) the detect language was lt.
# For lyrics in Luxembourgish (lb) the detect language was lb.
# For lyrics in Macedonian (mk) the detect language was mk.
# For lyrics in Maithili (mai) the detect language was mai.
# For lyrics in Malagasy (mg) the detect language was mg.
# For lyrics in Malay (ms) the detect language was ms.
# For lyrics in Malayalam (ml) the detect language was ml.
# For lyrics in Maltese (mt) the detect language was mt.
# For lyrics in Manipuri (Meitei Mayek) (mni-Mtei) the detect language was mni-Mtei.
# For lyrics in Maori (mi) the detect language was mi.
# For lyrics in Marathi (mr) the detect language was mr.
# For lyrics in Mizo (lus) the detect language was lus.
# For lyrics in Mongolian (mn) the detect language was mn.
# For lyrics in Myanmar (Burmese) (my) the detect language was my.
# For lyrics in Nepali (ne) the detect language was ne.
# For lyrics in Northern Sotho (nso) the detect language was nso.
# For lyrics in Norwegian (no) the detect language was no.
# For lyrics in Odia (Oriya) (or) the detect language was or.
# For lyrics in Oromo (om) the detect language was om.
# For lyrics in Pashto (ps) the detect language was ps.
# For lyrics in Persian (fa) the detect language was fa.
# For lyrics in Polish (pl) the detect language was pl.
# For lyrics in Portuguese (pt) the detect language was pt.
# For lyrics in Punjabi (pa) the detect language was pa.
# For lyrics in Quechua (qu) the detect language was qu.
# For lyrics in Romanian (ro) the detect language was ro.
# For lyrics in Russian (ru) the detect language was ru.
# For lyrics in Samoan (sm) the detect language was sm.
# For lyrics in Sanskrit (sa) the detect language was sa.
# For lyrics in Scots Gaelic (gd) the detect language was gd.
# For lyrics in Serbian (sr) the detect language was sr.
# For lyrics in Sesotho (st) the detect language was st.
# For lyrics in Shona (sn) the detect language was sn.
# For lyrics in Sindhi (sd) the detect language was sd.
# For lyrics in Sinhala (si) the detect language was si.
# For lyrics in Slovak (sk) the detect language was sk.
# For lyrics in Slovenian (sl) the detect language was sl.
# For lyrics in Somali (so) the detect language was so.
# For lyrics in Spanish (es) the detect language was es.
# For lyrics in Sundanese (su) the detect language was su.
# For lyrics in Swahili (sw) the detect language was sw.
# For lyrics in Swedish (sv) the detect language was sv.
# For lyrics in Tajik (tg) the detect language was tg.
# For lyrics in Tamil (ta) the detect language was ta.
# For lyrics in Tatar (tt) the detect language was tt.
# For lyrics in Telugu (te) the detect language was te.
# For lyrics in Thai (th) the detect language was th.
# For lyrics in Tigrinya (ti) the detect language was ti.
# For lyrics in Tsonga (ts) the detect language was ts.
# For lyrics in Turkish (tr) the detect language was tr.
# For lyrics in Turkmen (tk) the detect language was tk.
# For lyrics in Ukrainian (uk) the detect language was uk.
# For lyrics in Urdu (ur) the detect language was ur.
# For lyrics in Uyghur (ug) the detect language was ug.
# For lyrics in Uzbek (uz) the detect language was uz.
# For lyrics in Vietnamese (vi) the detect language was vi.
# For lyrics in Welsh (cy) the detect language was cy.
# For lyrics in Xhosa (xh) the detect language was xh.
# For lyrics in Yiddish (yi) the detect language was yi.
# For lyrics in Yoruba (yo) the detect language was yo.
# For lyrics in Zulu (zu) the detect language was zu.
# For lyrics in Hebrew (he) the detect language was iw.
# For lyrics in Javanese (jv) the detect language was jv.
# For lyrics in Chinese (Simplified) (zh-CN) the detect language was zh-CN.

# %% [markdown]
# ---
# ## Cloud Text-to-Speech - After Translation

# %% [markdown]
# ### French

# %%
from google.cloud import texttospeech
speech_client = texttospeech.TextToSpeechClient()

# %%
print(languages[34]['name'],'\n',languages[34]['lyric'])
# Out:
# French
#
# Je ne t'abandonnerai jamais.
# Je ne te laisserai jamais tomber.
# Je ne vais jamais courir et t'abandonner.
# Je ne te ferai jamais pleurer.
# Je ne dirai jamais au revoir.
# Je ne mentirai jamais et ne te blesserai jamais.

# %%
synth = texttospeech.SynthesisInput(text = languages[34]['lyric'])
voice =texttospeech.VoiceSelectionParams(language_code = "fr-FR", name = 'fr-FR-Wavenet-B')
audio = texttospeech.AudioConfig(audio_encoding = texttospeech.AudioEncoding.MP3)
response = speech_client.synthesize_speech(input = synth, voice = voice, audio_config=audio)
with open(f"./{DIR}/lyric_fr.mp3", "wb") as out:
    out.write(response.audio_content)
    print(f'./{DIR}/lyric_fr.mp3')
display.Audio(filename = f"./{DIR}/lyric_fr.mp3")
# Out:
# ./temp/nlp_ai_fun/lyric_fr.mp3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 8
#       6     out.write(response.audio_content)
#       7     print(f'./{DIR}/lyric_fr.mp3')
# ----> 8 display.Audio(filename = f"./{DIR}/lyric_fr.mp3")
#
# AttributeError: 'function' object has no attribute 'Audio'
