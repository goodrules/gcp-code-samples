# %%
## next, try to get jpg files parsed
## also, summary eval stats for each processor version in a second table
## look into parser level, by label stats

# %% [markdown]
# # Setup

# %%
#!pip install PyPDF2 -U -q

# %%
from google.api_core.client_options import ClientOptions
from google.cloud import documentai  # type: ignore
from google.cloud import documentai_v1beta3 as documentai_beta
from google.cloud.documentai_v1 import Document
from google.cloud import storage
from typing import Iterator, Optional, Sequence, Tuple
from google.protobuf import timestamp_pb2
from datetime import datetime
import pandas as pd
import json
import os
import io
import json
import base64
import requests
import concurrent.futures
import time
import PyPDF2

# %%
project = !gcloud config get-value project
PROJECT_ID = project[0]
PROJECT_ID
# Out:
# 'mg-ce-demos'

# %%
#Setup
LOCATION = 'us' # Format is 'us' or 'eu'
PROCESSOR_ID = '197afcf7768eaf3f'
#PROCESSOR_VERSION_ID = 'pretrained-invoice-v1.4-2022-10-21'
API_LOCATION = "us"  # Choose "us" or "eu"
PARSER_DISPLAY_NAME = 'mhwk-demo-tungsten'

GCS_BUCKET = 'mohawk-docai-demo'
GCS_INPUT_URI = f'gs://{GCS_BUCKET}/tungsten-data/'
GCS_OUTPUT_BUCKET = f'gs://{GCS_BUCKET}/output/'

DATASET = 'mhwk_docai_demo'
DOC_SIM_TABLE = 'invoice_parser_raw'
EVAL_TABLE = 'invoice_parser_eval_stats'

# %% [markdown]
# # SDK

# %% [markdown]
# ## Get processor versions for document processing and evaluation summary

# %%
docai_client = documentai.DocumentProcessorServiceClient(
    client_options = dict(api_endpoint = f"{LOCATION}-documentai.googleapis.com")
)

# %%
def list_processor_versions(project_id: str, location: str, processor_id: str) -> None:
    # You must set the api_endpoint if you use a location other than 'us'.
    opts = ClientOptions(api_endpoint=f"{location}-documentai.googleapis.com")

    client = documentai.DocumentProcessorServiceClient(client_options=opts)

    # The full resource name of the processor
    # e.g.: projects/project_id/locations/location/processors/processor_id
    parent = client.processor_path(project_id, location, processor_id)

    # Make ListProcessorVersions request
    processor_versions = client.list_processor_versions(parent=parent)
    
    version_list = []

    # Print the processor version information
    #for processor_version in processor_versions:
    #    version_list.append(client.parse_processor_version_path(
    #        processor_version.name
    #    )["processor_version"])
    return processor_versions

# %%
processor_versions = list_processor_versions(PROJECT_ID, LOCATION, PROCESSOR_ID)

processors = []
for processor_version in processor_versions:
    create_time = datetime.fromtimestamp(processor_version.create_time.timestamp())
    create_time = create_time.strftime('%Y-%m-%d %H:%M:%S')
    processors.append([docai_client.parse_processor_version_path(processor_version.name)["processor_version"], create_time])    
    
#processors = processors[0:1]
processors
# Out:
# [['656a9285e396bc4b', '2023-06-14 11:49:54'],
#  ['pretrained-invoice-v1.4-2022-10-21', '2022-10-20 20:00:00'],
#  ['pretrained-invoice-v1.3-2022-07-15', '2022-07-14 20:00:00'],
#  ['pretrained-invoice-v1.2-2022-02-18', '2022-02-17 19:00:00'],
#  ['pretrained-invoice-v1.1-2021-04-09', '2021-04-08 20:00:00']]

# %%
parser_eval_df = pd.DataFrame(columns=['processor_id', 'display_name', 'create_date', 'f1_score', 'precision', 'recall'])

for processor_version in processor_versions:
    create_time = datetime.fromtimestamp(processor_version.create_time.timestamp())
    create_time = create_time.strftime('%Y-%m-%d %H:%M:%S')
    row = [
        docai_client.parse_processor_version_path(processor_version.name)["processor_version"], 
        processor_version.display_name,
        create_time, 
        processor_version.latest_evaluation.aggregate_metrics.f1_score,
        processor_version.latest_evaluation.aggregate_metrics.precision,
        processor_version.latest_evaluation.aggregate_metrics.recall
    ]
    parser_eval_df = parser_eval_df.append(pd.DataFrame([row], columns=['processor_id', 'display_name', 'create_date', 'f1_score', 'precision', 'recall']), ignore_index=True)
    
parser_eval_df
# Out:
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/2315818682.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parser_eval_df = parser_eval_df.append(pd.DataFrame([row], columns=['processor_id', 'display_name', 'create_date', 'f1_score', 'precision', 'recall']), ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/2315818682.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parser_eval_df = parser_eval_df.append(pd.DataFrame([row], columns=['processor_id', 'display_name', 'create_date', 'f1_score', 'precision', 'recall']), ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/2315818682.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parser_eval_df = parser_eval_df.append(pd.DataFrame([row], columns=['processor_id', 'display_name', 'create_date', 'f1_score', 'precision', 'recall']), ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/2315818682.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parser_eval_df = parser_eval_df.append(pd.DataFrame([row], columns=['processor_id', 'display_name', 'create_date', 'f1_score', 'precision', 'recall']), ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/2315818682.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parser_eval_df = parser_eval_df.append(pd.DataFrame([row], columns=['processor_id', 'display_name', 'create_date', 'f1_score', 'precision', 'recall']), ignore_index=True)
#                          processor_id              display_name  \
# 0                    656a9285e396bc4b          mhwk-tungsten-v1
# 1  pretrained-invoice-v1.4-2022-10-21  Google Release Candidate
# 2  pretrained-invoice-v1.3-2022-07-15             Google Stable
# 3  pretrained-invoice-v1.2-2022-02-18             Google Stable
# 4  pretrained-invoice-v1.1-2021-04-09             Google Stable
#
#            create_date  f1_score  precision    recall
# 0  2023-06-14 11:49:54  0.826261   0.840391  0.812598
# 1  2022-10-20 20:00:00  0.819620   0.962825  0.713499
# 2  2022-07-14 20:00:00  0.819620   0.962825  0.713499
# 3  2022-02-17 19:00:00  0.690671   0.850806  0.581267
# 4  2021-04-08 20:00:00  0.690671   0.850806  0.581267

# %%
from google.cloud import bigquery

client = bigquery.Client()

table_id = f'{PROJECT_ID}.{DATASET}.{EVAL_TABLE}'

job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.job.WriteDisposition.WRITE_TRUNCATE
)

job = client.load_table_from_dataframe(
    parser_eval_df, table_id, job_config=job_config
)
job.result()  # Wait for the job to complete.
table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
# Loaded 5 rows and 6 columns to mg-ce-demos.mhwk_docai_demo.invoice_parser_eval_stats

# %% [markdown]
# ## Collect document data for processing

# %%
gcs = storage.Client(project = PROJECT_ID)
bucket = gcs.bucket(GCS_BUCKET)

# %%
# Get the list of blobs
blobs = bucket.list_blobs()

# Loop through the blobs
pdf_data = []
for blob in blobs:
    if blob.name.startswith('tungsten-data'):
        if blob.name.endswith('.pdf'):
            print(blob.name)
            pdf_data.append([blob.name, blob.content_type, blob.download_as_bytes()])
# Out:
# tungsten-data/PENSKE 1.1.pdf
# tungsten-data/PENSKE 10.10.pdf
# tungsten-data/PENSKE 2.2.pdf
# tungsten-data/PENSKE 3.3.pdf
# tungsten-data/PENSKE 4.4.pdf
# tungsten-data/PENSKE 5.5.pdf
# tungsten-data/PENSKE 6.6.pdf
# tungsten-data/PENSKE 7.7.pdf
# tungsten-data/PENSKE 8.8.pdf
# tungsten-data/PENSKE 9.9.pdf
# tungsten-data/Ryder 1.pdf
# tungsten-data/Ryder 10.pdf
# tungsten-data/Ryder 2.pdf
# tungsten-data/Ryder 3.pdf
# tungsten-data/Ryder 4.pdf
# tungsten-data/Ryder 6.pdf
# tungsten-data/Ryder 7.pdf
# tungsten-data/Ryder 8.pdf
# tungsten-data/Ryder 9.pdf

# %%
type(pdf_data[0][2])
# Out:
# bytes

# %% [markdown]
# ## Setup DocAI runner for doc processing

# %%
rate_limit_minute = 120
adjust_rate_limit = rate_limit_minute / 2

# %%
def docai_runner(p, start, raw_document, version_id):
    sleep_time = (p * (60/adjust_rate_limit)) - (time.time() - start)
    if sleep_time > 0: time.sleep(sleep_time)
    
    name = docai_client.processor_version_path(
        PROJECT_ID, LOCATION, PROCESSOR_ID, version_id
    )

    return (p, docai_client.process_document(request = dict(raw_document = raw_document, name = name)))

# %% [markdown]
# ## Process documents, by processor, and export dataframe for review

# %% [markdown]
# ### testing

# %%
#pdf_data[0]

# %%
doc = pdf_data[0][2]
doc2 = pdf_data[1][2]

# %%
pdf = PyPDF2.PdfReader(io.BytesIO(doc))

pdfs = []
for page_num, page in enumerate(pdf.pages, 1):
    writer = PyPDF2.PdfWriter()
    writer.add_page(page)
    with io.BytesIO() as bytes_stream:
        pdfs.append(writer.write(bytes_stream)[1].getbuffer().tobytes())

# %%
version_id = '656a9285e396bc4b'

# %%
name = docai_client.processor_version_path(
        PROJECT_ID, LOCATION, PROCESSOR_ID, version_id
    )

# Load Binary Data into Document AI RawDocument Object
raw_document = documentai.RawDocument(content=doc, mime_type = 'application/pdf')

# Configure the process request
request = documentai.ProcessRequest(
    name=name, raw_document=raw_document
)

result = docai_client.process_document(request=request)

# %%
result.document.entities
# Out:
# [text_anchor {
#   text_segments {
#     start_index: 1967
#     end_index: 1973
#   }
#   content: "107.00"
# }
# type_: "total_amount"
# mention_text: "107.00"
# confidence: 0.993133843
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.945865571
#         y: 0.685870469
#       }
#       normalized_vertices {
#         x: 0.983343244
#         y: 0.685870469
#       }
#       normalized_vertices {
#         x: 0.983343244
#         y: 0.694701433
#       }
#       normalized_vertices {
#         x: 0.945865571
#         y: 0.694701433
#       }
#     }
#   }
# }
# id: "0"
# normalized_value {
#   money_value {
#     units: 107
#   }
#   text: "107"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1790
#     end_index: 1794
#   }
#   content: "0.00"
# }
# type_: "total_tax_amount"
# mention_text: "0.00"
# confidence: 0.990307868
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.958953
#         y: 0.665685475
#       }
#       normalized_vertices {
#         x: 0.984533
#         y: 0.665685475
#       }
#       normalized_vertices {
#         x: 0.984533
#         y: 0.67451638
#       }
#       normalized_vertices {
#         x: 0.958953
#         y: 0.67451638
#       }
#     }
#   }
# }
# id: "1"
# normalized_value {
#   money_value {
#   }
#   text: "0"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1779
#     end_index: 1785
#   }
#   content: "107.00"
# }
# type_: "net_amount"
# mention_text: "107.00"
# confidence: 0.986497521
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.946460426
#         y: 0.645500422
#       }
#       normalized_vertices {
#         x: 0.983938158
#         y: 0.645500422
#       }
#       normalized_vertices {
#         x: 0.983938158
#         y: 0.654331386
#       }
#       normalized_vertices {
#         x: 0.946460426
#         y: 0.654331386
#       }
#     }
#   }
# }
# id: "2"
# normalized_value {
#   money_value {
#     units: 107
#   }
#   text: "107"
# }
# , text_anchor {
#   text_segments {
#     start_index: 76
#     end_index: 102
#   }
#   content: "PENSKE TRUCK LEASING CO LP"
# }
# type_: "supplier_name"
# mention_text: "PENSKE TRUCK LEASING CO LP"
# confidence: 0.985671341
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.0160618685
#         y: 0.128679559
#       }
#       normalized_vertices {
#         x: 0.224271268
#         y: 0.128679559
#       }
#       normalized_vertices {
#         x: 0.224271268
#         y: 0.137931034
#       }
#       normalized_vertices {
#         x: 0.0160618685
#         y: 0.137931034
#       }
#     }
#   }
# }
# id: "3"
# , text_anchor {
#   text_segments {
#     start_index: 1795
#     end_index: 1805
#   }
#   content: "23-2518618"
# }
# type_: "supplier_tax_id"
# mention_text: "23-2518618"
# confidence: 0.980757117
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.227840573
#         y: 0.673675358
#       }
#       normalized_vertices {
#         x: 0.298036873
#         y: 0.673675358
#       }
#       normalized_vertices {
#         x: 0.298036873
#         y: 0.682926834
#       }
#       normalized_vertices {
#         x: 0.227840573
#         y: 0.682926834
#       }
#     }
#   }
# }
# id: "4"
# , text_anchor {
#   text_segments {
#     start_index: 65
#     end_index: 75
#   }
#   content: "0025388645"
# }
# type_: "invoice_id"
# mention_text: "0025388645"
# confidence: 0.977288902
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.843545496
#         y: 0.106812447
#       }
#       normalized_vertices {
#         x: 0.9185009
#         y: 0.106812447
#       }
#       normalized_vertices {
#         x: 0.9185009
#         y: 0.116063923
#       }
#       normalized_vertices {
#         x: 0.843545496
#         y: 0.116063923
#       }
#     }
#   }
# }
# id: "5"
# , text_anchor {
#   text_segments {
#     start_index: 335
#     end_index: 344
#   }
#   content: "US Dollar"
# }
# type_: "currency"
# mention_text: "US Dollar"
# confidence: 0.954893351
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.842355728
#         y: 0.213624895
#       }
#       normalized_vertices {
#         x: 0.901844144
#         y: 0.213624895
#       }
#       normalized_vertices {
#         x: 0.901844144
#         y: 0.22287637
#       }
#       normalized_vertices {
#         x: 0.842355728
#         y: 0.22287637
#       }
#     }
#   }
# }
# id: "6"
# normalized_value {
#   text: "USD"
# }
# , text_anchor {
#   text_segments {
#     start_index: 761
#     end_index: 816
#   }
#   content: "P.O. BOX 827380\nPHILADELPHIA\nPA\n191827380\nUNITED STATES"
# }
# type_: "remit_to_address"
# mention_text: "P.O. BOX 827380\nPHILADELPHIA\nPA\n191827380\nUNITED STATES"
# confidence: 0.953181446
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.00713860802
#         y: 0.540790558
#       }
#       normalized_vertices {
#         x: 0.114217728
#         y: 0.540790558
#       }
#       normalized_vertices {
#         x: 0.114217728
#         y: 0.616905
#       }
#       normalized_vertices {
#         x: 0.00713860802
#         y: 0.616905
#       }
#     }
#   }
# }
# id: "7"
# , text_anchor {
#   text_segments {
#     start_index: 151
#     end_index: 177
#   }
#   content: "POA-\nWILLIAM_WHITNEY-8\n125"
# }
# type_: "purchase_order"
# mention_text: "POA-\nWILLIAM_WHITNEY-8\n125"
# confidence: 0.937233627
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.841760874
#         y: 0.126997471
#       }
#       normalized_vertices {
#         x: 0.977394402
#         y: 0.126997471
#       }
#       normalized_vertices {
#         x: 0.977394402
#         y: 0.163162321
#       }
#       normalized_vertices {
#         x: 0.841760874
#         y: 0.163162321
#       }
#     }
#   }
# }
# id: "8"
# , text_anchor {
#   text_segments {
#     start_index: 729
#     end_index: 760
#   }
#   content: "PENSKE TRUCK LEASING CO., L. P."
# }
# type_: "remit_to_name"
# mention_text: "PENSKE TRUCK LEASING CO., L. P."
# confidence: 0.93259573
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.00773349218
#         y: 0.523549199
#       }
#       normalized_vertices {
#         x: 0.238548487
#         y: 0.523549199
#       }
#       normalized_vertices {
#         x: 0.238548487
#         y: 0.533641696
#       }
#       normalized_vertices {
#         x: 0.00773349218
#         y: 0.533641696
#       }
#     }
#   }
# }
# id: "9"
# , text_anchor {
#   text_segments {
#     start_index: 103
#     end_index: 140
#   }
#   content: "Mohawk Industries, Inc. (SAP Account)"
# }
# type_: "receiver_name"
# mention_text: "Mohawk Industries, Inc. (SAP Account)"
# confidence: 0.92498517
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.349791795
#         y: 0.124474347
#       }
#       normalized_vertices {
#         x: 0.585365832
#         y: 0.124474347
#       }
#       normalized_vertices {
#         x: 0.585365832
#         y: 0.135828421
#       }
#       normalized_vertices {
#         x: 0.349791795
#         y: 0.135828421
#       }
#     }
#   }
# }
# id: "10"
# , text_anchor {
#   text_segments {
#     start_index: 287
#     end_index: 297
#   }
#   content: "05/17/2023"
# }
# type_: "invoice_date"
# mention_text: "05/17/2023"
# confidence: 0.853175759
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.842355728
#         y: 0.194280908
#       }
#       normalized_vertices {
#         x: 0.910172522
#         y: 0.194280908
#       }
#       normalized_vertices {
#         x: 0.910172522
#         y: 0.203952909
#       }
#       normalized_vertices {
#         x: 0.842355728
#         y: 0.203952909
#       }
#     }
#   }
# }
# id: "11"
# normalized_value {
#   date_value {
#     year: 2023
#     month: 5
#     day: 17
#   }
#   text: "2023-05-17"
# }
# , text_anchor {
#   text_segments {
#     start_index: 701
#     end_index: 711
#   }
#   content: "05/17/2023"
# }
# type_: "delivery_date"
# mention_text: "05/17/2023"
# confidence: 0.761458635
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.841760874
#         y: 0.442809075
#       }
#       normalized_vertices {
#         x: 0.909577608
#         y: 0.442809075
#       }
#       normalized_vertices {
#         x: 0.909577608
#         y: 0.45164004
#       }
#       normalized_vertices {
#         x: 0.841760874
#         y: 0.45164004
#       }
#     }
#   }
# }
# id: "12"
# normalized_value {
#   date_value {
#     year: 2023
#     month: 5
#     day: 17
#   }
#   text: "2023-05-17"
# }
# , type_: "invoice_type"
# confidence: 0.574485958
# page_anchor {
#   page_refs {
#   }
# }
# id: "13"
# normalized_value {
#   text: "invoice_statement"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1627
#     end_index: 1628
#   }
#   text_segments {
#     start_index: 1629
#     end_index: 1633
#   }
#   text_segments {
#     start_index: 1634
#     end_index: 1639
#   }
#   text_segments {
#     start_index: 1640
#     end_index: 1646
#   }
# }
# type_: "line_item"
# mention_text: "1 Each 18.00 18.000"
# confidence: 0.980366409
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.246876866
#         y: 0.442388564
#       }
#       normalized_vertices {
#         x: 0.986317694
#         y: 0.442388564
#       }
#       normalized_vertices {
#         x: 0.986317694
#         y: 0.45206055
#       }
#       normalized_vertices {
#         x: 0.246876866
#         y: 0.45206055
#       }
#     }
#   }
# }
# id: "14"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1627
#       end_index: 1628
#     }
#     content: "1"
#   }
#   type_: "line_item/quantity"
#   mention_text: "1"
#   confidence: 0.995255232
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.246876866
#           y: 0.442809075
#         }
#         normalized_vertices {
#           x: 0.249851286
#           y: 0.442809075
#         }
#         normalized_vertices {
#           x: 0.249851286
#           y: 0.450799
#         }
#         normalized_vertices {
#           x: 0.246876866
#           y: 0.450799
#         }
#       }
#     }
#   }
#   id: "15"
#   normalized_value {
#     text: "1"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1629
#       end_index: 1633
#     }
#     content: "Each"
#   }
#   type_: "line_item/unit"
#   mention_text: "Each"
#   confidence: 0.980366409
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.442388564
#         }
#         normalized_vertices {
#           x: 0.346817374
#           y: 0.442388564
#         }
#         normalized_vertices {
#           x: 0.346817374
#           y: 0.451219499
#         }
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.451219499
#         }
#       }
#     }
#   }
#   id: "16"
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1634
#       end_index: 1639
#     }
#     content: "18.00"
#   }
#   type_: "line_item/unit_price"
#   mention_text: "18.00"
#   confidence: 0.995881
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.465199292
#           y: 0.442809075
#         }
#         normalized_vertices {
#           x: 0.495538384
#           y: 0.442809075
#         }
#         normalized_vertices {
#           x: 0.495538384
#           y: 0.45206055
#         }
#         normalized_vertices {
#           x: 0.465199292
#           y: 0.45206055
#         }
#       }
#     }
#   }
#   id: "17"
#   normalized_value {
#     money_value {
#       units: 18
#     }
#     text: "18"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1640
#       end_index: 1646
#     }
#     content: "18.000"
#   }
#   type_: "line_item/amount"
#   mention_text: "18.000"
#   confidence: 0.989418685
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.948839962
#           y: 0.442809075
#         }
#         normalized_vertices {
#           x: 0.986317694
#           y: 0.442809075
#         }
#         normalized_vertices {
#           x: 0.986317694
#           y: 0.451219499
#         }
#         normalized_vertices {
#           x: 0.948839962
#           y: 0.451219499
#         }
#       }
#     }
#   }
#   id: "18"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1192
#     end_index: 1193
#   }
#   text_segments {
#     start_index: 1194
#     end_index: 1198
#   }
#   text_segments {
#     start_index: 1199
#     end_index: 1204
#   }
#   text_segments {
#     start_index: 1205
#     end_index: 1211
#   }
# }
# type_: "line_item"
# mention_text: "1 Each 18.00 18.000"
# confidence: 0.978022754
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.24747175
#         y: 0.0105130365
#       }
#       normalized_vertices {
#         x: 0.98572278
#         y: 0.0105130365
#       }
#       normalized_vertices {
#         x: 0.98572278
#         y: 0.0197645072
#       }
#       normalized_vertices {
#         x: 0.24747175
#         y: 0.0197645072
#       }
#     }
#   }
# }
# id: "19"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1192
#       end_index: 1193
#     }
#     content: "1"
#   }
#   type_: "line_item/quantity"
#   mention_text: "1"
#   confidence: 0.99546957
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.24747175
#           y: 0.0113540795
#         }
#         normalized_vertices {
#           x: 0.250446171
#           y: 0.0113540795
#         }
#         normalized_vertices {
#           x: 0.250446171
#           y: 0.0189234652
#         }
#         normalized_vertices {
#           x: 0.24747175
#           y: 0.0189234652
#         }
#       }
#     }
#   }
#   id: "20"
#   normalized_value {
#     text: "1"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1194
#       end_index: 1198
#     }
#     content: "Each"
#   }
#   type_: "line_item/unit"
#   mention_text: "Each"
#   confidence: 0.978022754
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.318857819
#           y: 0.0105130365
#         }
#         normalized_vertices {
#           x: 0.347412258
#           y: 0.0105130365
#         }
#         normalized_vertices {
#           x: 0.347412258
#           y: 0.0197645072
#         }
#         normalized_vertices {
#           x: 0.318857819
#           y: 0.0197645072
#         }
#       }
#     }
#   }
#   id: "21"
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1199
#       end_index: 1204
#     }
#     content: "18.00"
#   }
#   type_: "line_item/unit_price"
#   mention_text: "18.00"
#   confidence: 0.99688679
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.465199292
#           y: 0.0109335575
#         }
#         normalized_vertices {
#           x: 0.496728152
#           y: 0.0109335575
#         }
#         normalized_vertices {
#           x: 0.496728152
#           y: 0.0189234652
#         }
#         normalized_vertices {
#           x: 0.465199292
#           y: 0.0189234652
#         }
#       }
#     }
#   }
#   id: "22"
#   normalized_value {
#     money_value {
#       units: 18
#     }
#     text: "18"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1205
#       end_index: 1211
#     }
#     content: "18.000"
#   }
#   type_: "line_item/amount"
#   mention_text: "18.000"
#   confidence: 0.988729
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.947650194
#           y: 0.0109335575
#         }
#         normalized_vertices {
#           x: 0.98572278
#           y: 0.0109335575
#         }
#         normalized_vertices {
#           x: 0.98572278
#           y: 0.0197645072
#         }
#         normalized_vertices {
#           x: 0.947650194
#           y: 0.0197645072
#         }
#       }
#     }
#   }
#   id: "23"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1337
#     end_index: 1338
#   }
#   text_segments {
#     start_index: 1339
#     end_index: 1343
#   }
#   text_segments {
#     start_index: 1344
#     end_index: 1349
#   }
#   text_segments {
#     start_index: 1350
#     end_index: 1356
#   }
# }
# type_: "line_item"
# mention_text: "1 Each 17.00 17.000"
# confidence: 0.978405833
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.246876866
#         y: 0.154331371
#       }
#       normalized_vertices {
#         x: 0.98572278
#         y: 0.154331371
#       }
#       normalized_vertices {
#         x: 0.98572278
#         y: 0.163582847
#       }
#       normalized_vertices {
#         x: 0.246876866
#         y: 0.163582847
#       }
#     }
#   }
# }
# id: "24"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1337
#       end_index: 1338
#     }
#     content: "1"
#   }
#   type_: "line_item/quantity"
#   mention_text: "1"
#   confidence: 0.995413542
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.246876866
#           y: 0.155172408
#         }
#         normalized_vertices {
#           x: 0.249851286
#           y: 0.155172408
#         }
#         normalized_vertices {
#           x: 0.249851286
#           y: 0.162321284
#         }
#         normalized_vertices {
#           x: 0.246876866
#           y: 0.162321284
#         }
#       }
#     }
#   }
#   id: "25"
#   normalized_value {
#     text: "1"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1339
#       end_index: 1343
#     }
#     content: "Each"
#   }
#   type_: "line_item/unit"
#   mention_text: "Each"
#   confidence: 0.978405833
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.154331371
#         }
#         normalized_vertices {
#           x: 0.346817374
#           y: 0.154331371
#         }
#         normalized_vertices {
#           x: 0.346817374
#           y: 0.162741795
#         }
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.162741795
#         }
#       }
#     }
#   }
#   id: "26"
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1344
#       end_index: 1349
#     }
#     content: "17.00"
#   }
#   type_: "line_item/unit_price"
#   mention_text: "17.00"
#   confidence: 0.996273041
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.465794176
#           y: 0.154751897
#         }
#         normalized_vertices {
#           x: 0.4949435
#           y: 0.154751897
#         }
#         normalized_vertices {
#           x: 0.4949435
#           y: 0.163162321
#         }
#         normalized_vertices {
#           x: 0.465794176
#           y: 0.163162321
#         }
#       }
#     }
#   }
#   id: "27"
#   normalized_value {
#     money_value {
#       units: 17
#     }
#     text: "17"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1350
#       end_index: 1356
#     }
#     content: "17.000"
#   }
#   type_: "line_item/amount"
#   mention_text: "17.000"
#   confidence: 0.990489781
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.947650194
#           y: 0.154751897
#         }
#         normalized_vertices {
#           x: 0.98572278
#           y: 0.154751897
#         }
#         normalized_vertices {
#           x: 0.98572278
#           y: 0.163582847
#         }
#         normalized_vertices {
#           x: 0.947650194
#           y: 0.163582847
#         }
#       }
#     }
#   }
#   id: "28"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1482
#     end_index: 1483
#   }
#   text_segments {
#     start_index: 1484
#     end_index: 1488
#   }
#   text_segments {
#     start_index: 1489
#     end_index: 1494
#   }
#   text_segments {
#     start_index: 1495
#     end_index: 1501
#   }
# }
# type_: "line_item"
# mention_text: "1 Each 18.00 18.000"
# confidence: 0.978985369
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.246876866
#         y: 0.298149705
#       }
#       normalized_vertices {
#         x: 0.986912549
#         y: 0.298149705
#       }
#       normalized_vertices {
#         x: 0.986912549
#         y: 0.306980669
#       }
#       normalized_vertices {
#         x: 0.246876866
#         y: 0.306980669
#       }
#     }
#   }
# }
# id: "29"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1482
#       end_index: 1483
#     }
#     content: "1"
#   }
#   type_: "line_item/quantity"
#   mention_text: "1"
#   confidence: 0.995291114
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.246876866
#           y: 0.298990756
#         }
#         normalized_vertices {
#           x: 0.249851286
#           y: 0.298990756
#         }
#         normalized_vertices {
#           x: 0.249851286
#           y: 0.306139618
#         }
#         normalized_vertices {
#           x: 0.246876866
#           y: 0.306139618
#         }
#       }
#     }
#   }
#   id: "30"
#   normalized_value {
#     text: "1"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1484
#       end_index: 1488
#     }
#     content: "Each"
#   }
#   type_: "line_item/unit"
#   mention_text: "Each"
#   confidence: 0.978985369
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.298570216
#         }
#         normalized_vertices {
#           x: 0.348007143
#           y: 0.298570216
#         }
#         normalized_vertices {
#           x: 0.348007143
#           y: 0.306980669
#         }
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.306980669
#         }
#       }
#     }
#   }
#   id: "31"
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1489
#       end_index: 1494
#     }
#     content: "18.00"
#   }
#   type_: "line_item/unit_price"
#   mention_text: "18.00"
#   confidence: 0.995998263
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.465794176
#           y: 0.298570216
#         }
#         normalized_vertices {
#           x: 0.4949435
#           y: 0.298570216
#         }
#         normalized_vertices {
#           x: 0.4949435
#           y: 0.306980669
#         }
#         normalized_vertices {
#           x: 0.465794176
#           y: 0.306980669
#         }
#       }
#     }
#   }
#   id: "32"
#   normalized_value {
#     money_value {
#       units: 18
#     }
#     text: "18"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1495
#       end_index: 1501
#     }
#     content: "18.000"
#   }
#   type_: "line_item/amount"
#   mention_text: "18.000"
#   confidence: 0.990802646
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.949434876
#           y: 0.298149705
#         }
#         normalized_vertices {
#           x: 0.986912549
#           y: 0.298149705
#         }
#         normalized_vertices {
#           x: 0.986912549
#           y: 0.306980669
#         }
#         normalized_vertices {
#           x: 0.949434876
#           y: 0.306980669
#         }
#       }
#     }
#   }
#   id: "33"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1047
#     end_index: 1048
#   }
#   text_segments {
#     start_index: 1049
#     end_index: 1053
#   }
#   text_segments {
#     start_index: 1054
#     end_index: 1059
#   }
#   text_segments {
#     start_index: 1060
#     end_index: 1066
#   }
# }
# type_: "line_item"
# mention_text: "1 Each 18.00 18.000"
# confidence: 0.97646296
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.246281981
#         y: 0.812447429
#       }
#       normalized_vertices {
#         x: 0.986912549
#         y: 0.812447429
#       }
#       normalized_vertices {
#         x: 0.986912549
#         y: 0.821278393
#       }
#       normalized_vertices {
#         x: 0.246281981
#         y: 0.821278393
#       }
#     }
#   }
# }
# id: "34"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1047
#       end_index: 1048
#     }
#     content: "1"
#   }
#   type_: "line_item/quantity"
#   mention_text: "1"
#   confidence: 0.994553924
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.246281981
#           y: 0.81328845
#         }
#         normalized_vertices {
#           x: 0.249256402
#           y: 0.81328845
#         }
#         normalized_vertices {
#           x: 0.249256402
#           y: 0.820437372
#         }
#         normalized_vertices {
#           x: 0.246281981
#           y: 0.820437372
#         }
#       }
#     }
#   }
#   id: "35"
#   normalized_value {
#     text: "1"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1049
#       end_index: 1053
#     }
#     content: "Each"
#   }
#   type_: "line_item/unit"
#   mention_text: "Each"
#   confidence: 0.97646296
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.812867939
#         }
#         normalized_vertices {
#           x: 0.348007143
#           y: 0.812867939
#         }
#         normalized_vertices {
#           x: 0.348007143
#           y: 0.821278393
#         }
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.821278393
#         }
#       }
#     }
#   }
#   id: "36"
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1054
#       end_index: 1059
#     }
#     content: "18.00"
#   }
#   type_: "line_item/unit_price"
#   mention_text: "18.00"
#   confidence: 0.997139156
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.465199292
#           y: 0.812867939
#         }
#         normalized_vertices {
#           x: 0.496728152
#           y: 0.812867939
#         }
#         normalized_vertices {
#           x: 0.496728152
#           y: 0.820857882
#         }
#         normalized_vertices {
#           x: 0.465199292
#           y: 0.820857882
#         }
#       }
#     }
#   }
#   id: "37"
#   normalized_value {
#     money_value {
#       units: 18
#     }
#     text: "18"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1060
#       end_index: 1066
#     }
#     content: "18.000"
#   }
#   type_: "line_item/amount"
#   mention_text: "18.000"
#   confidence: 0.991235733
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.949434876
#           y: 0.812447429
#         }
#         normalized_vertices {
#           x: 0.986912549
#           y: 0.812447429
#         }
#         normalized_vertices {
#           x: 0.986912549
#           y: 0.821278393
#         }
#         normalized_vertices {
#           x: 0.949434876
#           y: 0.821278393
#         }
#       }
#     }
#   }
#   id: "38"
# }
# , text_anchor {
#   text_segments {
#     start_index: 902
#     end_index: 903
#   }
#   text_segments {
#     start_index: 904
#     end_index: 908
#   }
#   text_segments {
#     start_index: 909
#     end_index: 914
#   }
#   text_segments {
#     start_index: 915
#     end_index: 921
#   }
# }
# type_: "line_item"
# mention_text: "1 Each 18.00 18.000"
# confidence: 0.973766267
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.246876866
#         y: 0.669049621
#       }
#       normalized_vertices {
#         x: 0.986317694
#         y: 0.669049621
#       }
#       normalized_vertices {
#         x: 0.986317694
#         y: 0.677880585
#       }
#       normalized_vertices {
#         x: 0.246876866
#         y: 0.677880585
#       }
#     }
#   }
# }
# id: "39"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 902
#       end_index: 903
#     }
#     content: "1"
#   }
#   type_: "line_item/quantity"
#   mention_text: "1"
#   confidence: 0.993724644
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.246876866
#           y: 0.669470131
#         }
#         normalized_vertices {
#           x: 0.249851286
#           y: 0.669470131
#         }
#         normalized_vertices {
#           x: 0.249851286
#           y: 0.677460074
#         }
#         normalized_vertices {
#           x: 0.246876866
#           y: 0.677460074
#         }
#       }
#     }
#   }
#   id: "40"
#   normalized_value {
#     text: "1"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 904
#       end_index: 908
#     }
#     content: "Each"
#   }
#   type_: "line_item/unit"
#   mention_text: "Each"
#   confidence: 0.973766267
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.669049621
#         }
#         normalized_vertices {
#           x: 0.348602027
#           y: 0.669049621
#         }
#         normalized_vertices {
#           x: 0.348602027
#           y: 0.677460074
#         }
#         normalized_vertices {
#           x: 0.319452703
#           y: 0.677460074
#         }
#       }
#     }
#   }
#   id: "41"
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 909
#       end_index: 914
#     }
#     content: "18.00"
#   }
#   type_: "line_item/unit_price"
#   mention_text: "18.00"
#   confidence: 0.997578442
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.465794176
#           y: 0.669470131
#         }
#         normalized_vertices {
#           x: 0.4949435
#           y: 0.669470131
#         }
#         normalized_vertices {
#           x: 0.4949435
#           y: 0.677880585
#         }
#         normalized_vertices {
#           x: 0.465794176
#           y: 0.677880585
#         }
#       }
#     }
#   }
#   id: "42"
#   normalized_value {
#     money_value {
#       units: 18
#     }
#     text: "18"
#   }
# }
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 915
#       end_index: 921
#     }
#     content: "18.000"
#   }
#   type_: "line_item/amount"
#   mention_text: "18.000"
#   confidence: 0.986401141
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.948839962
#           y: 0.669049621
#         }
#         normalized_vertices {
#           x: 0.986317694
#           y: 0.669049621
#         }
#         normalized_vertices {
#           x: 0.986317694
#           y: 0.677460074
#         }
#         normalized_vertices {
#           x: 0.948839962
#           y: 0.677460074
#         }
#       }
#     }
#   }
#   id: "43"
# }
# , text_anchor {
#   text_segments {
#     start_index: 922
#     end_index: 928
#   }
# }
# type_: "line_item"
# mention_text: "WASHES"
# confidence: 0.948209167
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.0648423582
#         y: 0.687132061
#       }
#       normalized_vertices {
#         x: 0.124330759
#         y: 0.687132061
#       }
#       normalized_vertices {
#         x: 0.124330759
#         y: 0.695962965
#       }
#       normalized_vertices {
#         x: 0.0648423582
#         y: 0.695962965
#       }
#     }
#   }
# }
# id: "44"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 922
#       end_index: 928
#     }
#     content: "WASHES"
#   }
#   type_: "line_item/description"
#   mention_text: "WASHES"
#   confidence: 0.948209167
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.0648423582
#           y: 0.687132061
#         }
#         normalized_vertices {
#           x: 0.124330759
#           y: 0.687132061
#         }
#         normalized_vertices {
#           x: 0.124330759
#           y: 0.695962965
#         }
#         normalized_vertices {
#           x: 0.0648423582
#           y: 0.695962965
#         }
#       }
#     }
#   }
#   id: "45"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1502
#     end_index: 1508
#   }
# }
# type_: "line_item"
# mention_text: "WASHES"
# confidence: 0.934598744
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.0660321265
#         y: 0.317073166
#       }
#       normalized_vertices {
#         x: 0.125520527
#         y: 0.317073166
#       }
#       normalized_vertices {
#         x: 0.125520527
#         y: 0.325904131
#       }
#       normalized_vertices {
#         x: 0.0660321265
#         y: 0.325904131
#       }
#     }
#   }
# }
# id: "46"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1502
#       end_index: 1508
#     }
#     content: "WASHES"
#   }
#   type_: "line_item/description"
#   mention_text: "WASHES"
#   confidence: 0.934598744
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.0660321265
#           y: 0.317073166
#         }
#         normalized_vertices {
#           x: 0.125520527
#           y: 0.317073166
#         }
#         normalized_vertices {
#           x: 0.125520527
#           y: 0.325904131
#         }
#         normalized_vertices {
#           x: 0.0660321265
#           y: 0.325904131
#         }
#       }
#     }
#   }
#   id: "47"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1357
#     end_index: 1363
#   }
# }
# type_: "line_item"
# mention_text: "WASHES"
# confidence: 0.933243573
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.0660321265
#         y: 0.173675358
#       }
#       normalized_vertices {
#         x: 0.125520527
#         y: 0.173675358
#       }
#       normalized_vertices {
#         x: 0.125520527
#         y: 0.182506308
#       }
#       normalized_vertices {
#         x: 0.0660321265
#         y: 0.182506308
#       }
#     }
#   }
# }
# id: "48"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1357
#       end_index: 1363
#     }
#     content: "WASHES"
#   }
#   type_: "line_item/description"
#   mention_text: "WASHES"
#   confidence: 0.933243573
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.0660321265
#           y: 0.173675358
#         }
#         normalized_vertices {
#           x: 0.125520527
#           y: 0.173675358
#         }
#         normalized_vertices {
#           x: 0.125520527
#           y: 0.182506308
#         }
#         normalized_vertices {
#           x: 0.0660321265
#           y: 0.182506308
#         }
#       }
#     }
#   }
#   id: "49"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1212
#     end_index: 1218
#   }
# }
# type_: "line_item"
# mention_text: "WASHES"
# confidence: 0.931905448
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.0654372424
#         y: 0.0290159807
#       }
#       normalized_vertices {
#         x: 0.126710296
#         y: 0.0290159807
#       }
#       normalized_vertices {
#         x: 0.126710296
#         y: 0.0386879742
#       }
#       normalized_vertices {
#         x: 0.0654372424
#         y: 0.0386879742
#       }
#     }
#   }
# }
# id: "50"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1212
#       end_index: 1218
#     }
#     content: "WASHES"
#   }
#   type_: "line_item/description"
#   mention_text: "WASHES"
#   confidence: 0.931905448
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.0654372424
#           y: 0.0290159807
#         }
#         normalized_vertices {
#           x: 0.126710296
#           y: 0.0290159807
#         }
#         normalized_vertices {
#           x: 0.126710296
#           y: 0.0386879742
#         }
#         normalized_vertices {
#           x: 0.0654372424
#           y: 0.0386879742
#         }
#       }
#     }
#   }
#   id: "51"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1647
#     end_index: 1653
#   }
# }
# type_: "line_item"
# mention_text: "WASHES"
# confidence: 0.931634188
# page_anchor {
#   page_refs {
#     page: 1
#     bounding_poly {
#       normalized_vertices {
#         x: 0.0666270107
#         y: 0.460470974
#       }
#       normalized_vertices {
#         x: 0.126115412
#         y: 0.460470974
#       }
#       normalized_vertices {
#         x: 0.126115412
#         y: 0.46972245
#       }
#       normalized_vertices {
#         x: 0.0666270107
#         y: 0.46972245
#       }
#     }
#   }
# }
# id: "52"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1647
#       end_index: 1653
#     }
#     content: "WASHES"
#   }
#   type_: "line_item/description"
#   mention_text: "WASHES"
#   confidence: 0.931634188
#   page_anchor {
#     page_refs {
#       page: 1
#       bounding_poly {
#         normalized_vertices {
#           x: 0.0666270107
#           y: 0.460470974
#         }
#         normalized_vertices {
#           x: 0.126115412
#           y: 0.460470974
#         }
#         normalized_vertices {
#           x: 0.126115412
#           y: 0.46972245
#         }
#         normalized_vertices {
#           x: 0.0666270107
#           y: 0.46972245
#         }
#       }
#     }
#   }
#   id: "53"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1067
#     end_index: 1073
#   }
# }
# type_: "line_item"
# mention_text: "WASHES"
# confidence: 0.930165708
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.0666270107
#         y: 0.830950379
#       }
#       normalized_vertices {
#         x: 0.125520527
#         y: 0.830950379
#       }
#       normalized_vertices {
#         x: 0.125520527
#         y: 0.839360833
#       }
#       normalized_vertices {
#         x: 0.0666270107
#         y: 0.839360833
#       }
#     }
#   }
# }
# id: "54"
# properties {
#   text_anchor {
#     text_segments {
#       start_index: 1067
#       end_index: 1073
#     }
#     content: "WASHES"
#   }
#   type_: "line_item/description"
#   mention_text: "WASHES"
#   confidence: 0.930165708
#   page_anchor {
#     page_refs {
#       bounding_poly {
#         normalized_vertices {
#           x: 0.0666270107
#           y: 0.830950379
#         }
#         normalized_vertices {
#           x: 0.125520527
#           y: 0.830950379
#         }
#         normalized_vertices {
#           x: 0.125520527
#           y: 0.839360833
#         }
#         normalized_vertices {
#           x: 0.0666270107
#           y: 0.839360833
#         }
#       }
#     }
#   }
#   id: "55"
# }
# ]

# %%
dict_test = {}
line_item_num = 0

for entity in result.document.entities:
    key = entity.type_
    # some other value formats in addition to text are availible
    # e.g. dates: `entity.normalized_value.date_value.year`
    text_value = entity.mention_text
    confidence = entity.confidence
    normalized_value = entity.normalized_value.text

    if normalized_value:
        if key == 'line_item':
            dict_test[str(key+str(line_item_num))] = normalized_value
            line_item_num += 1
        else:
            dict_test[key] = normalized_value
    else:
        if key == 'line_item':
            dict_test[str(key+str(line_item_num))] = text_value
            line_item_num += 1
        else:
            dict_test[key] = text_value

# %%
dict_test

# %%
df_test = pd.DataFrame([dict_test])

# %%
pdf2 = PyPDF2.PdfReader(io.BytesIO(doc2))

pdfs2 = []
for page_num, page in enumerate(pdf2.pages, 1):
    writer = PyPDF2.PdfWriter()
    writer.add_page(page)
    with io.BytesIO() as bytes_stream:
        pdfs2.append(writer.write(bytes_stream)[1].getbuffer().tobytes())

# %%
name = docai_client.processor_version_path(
        PROJECT_ID, LOCATION, PROCESSOR_ID, version_id
    )

# Load Binary Data into Document AI RawDocument Object
raw_document2 = documentai.RawDocument(content=doc2, mime_type = 'application/pdf')

# Configure the process request
request2 = documentai.ProcessRequest(
    name=name, raw_document=raw_document2
)

result2 = docai_client.process_document(request=request2)

# %%
dict_test2 = {}
line_item_num = 0

for entity in result2.document.entities:
    key = entity.type_
    # some other value formats in addition to text are availible
    # e.g. dates: `entity.normalized_value.date_value.year`
    text_value = entity.mention_text
    confidence = entity.confidence
    normalized_value = entity.normalized_value.text

    if normalized_value:
        if key == 'line_item':
            dict_test2[str(key+str(line_item_num))] = normalized_value
            line_item_num += 1
        else:
            dict_test2[key] = normalized_value
    else:
        if key == 'line_item':
            dict_test2[str(key+str(line_item_num))] = text_value
            line_item_num += 1
        else:
            dict_test2[key] = text_value

# %%
#dict_test2

# %%
df_test = df_test.append(dict_test2, ignore_index=True)
# Out:
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3843971467.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test = df_test.append(dict_test2, ignore_index=True)

# %%
df_test
# Out:
#   total_amount total_tax_amount net_amount               supplier_name  \
# 0          107                0        107  PENSKE TRUCK LEASING CO LP
# 1       5790.5                0     5790.5  PENSKE TRUCK LEASING CO LP
#
#   supplier_tax_id  invoice_id currency  \
# 0      23-2518618  0025388645      USD
# 1      23-2518618  0025242572      USD
#
#                                     remit_to_address  \
# 0  P.O. BOX 827380\nPHILADELPHIA\nPA\n191827380\n...
# 1  P.O. BOX 827380\nPHILADELPHIA\nPA\n191827380\n...
#
#                  purchase_order                    remit_to_name  ...  \
# 0  POA-\nWILLIAM_WHITNEY-8\n125  PENSKE TRUCK LEASING CO., L. P.  ...
# 1    POA-\nJOSE_MARTINEZ-812\n5  PENSKE TRUCK LEASING CO., L. P.  ...
#
#             line_item2           line_item3           line_item4  \
# 0  1 Each 17.00 17.000  1 Each 18.00 18.000  1 Each 18.00 18.000
# 1       382521 TRACTOR       340086 TRACTOR                  NaN
#
#             line_item5 line_item6 line_item7 line_item8 line_item9  \
# 0  1 Each 18.00 18.000     WASHES     WASHES     WASHES     WASHES
# 1                  NaN        NaN        NaN        NaN        NaN
#
#   line_item10 line_item11
# 0      WASHES      WASHES
# 1         NaN         NaN
#
# [2 rows x 26 columns]

# %% [markdown]
# ### not testing

# %%
start = time.time()

doc_df = pd.DataFrame()

total_start = time.time()
for processor in processors:
    processor_id = processor[0]
    create_date = processor[1]
    
    for i, doc in enumerate(pdf_data):
        print(f'Doc {i+1} out of {len(pdf_data)}')        
        
        doc_id = doc[0]
        doc_type = doc[1]

        pdf = PyPDF2.PdfReader(io.BytesIO(doc[2]))

        pdfs = []
        for page_num, page in enumerate(pdf.pages, 1):
            writer = PyPDF2.PdfWriter()
            writer.add_page(page)
            with io.BytesIO() as bytes_stream:
                pdfs.append(writer.write(bytes_stream)[1].getbuffer().tobytes())

        print(f"The Expected runtime for the parsing is {(len(pdfs)/adjust_rate_limit):.2f} minutes")
        results = [None] * len(pdfs)
        start = time.time()
        with concurrent.futures.ThreadPoolExecutor(max_workers = len(pdfs)) as executor:
            futures = [
                executor.submit(
                    docai_runner,
                    p, start,
                    documentai.RawDocument(content = pdf, mime_type = 'application/pdf'),
                    processor_id
                ) for p, pdf in enumerate(pdfs)
            ]
            for future in concurrent.futures.as_completed(futures):
                #result = futures[future]
                results[future.result()[0]] = (Document.to_dict(future.result()[1].document))

        for r, result in enumerate(results):
            dict_temp = {}
            line_item_num = 0
            dict_temp['processor_id'] = processor_id
            dict_temp['create_date'] = create_date
            dict_temp['doc_id'] = doc_id
            dict_temp['doc_type'] = doc_type
            
            for entity in results[r]['entities']:
                key = entity['type_']
                text_value = entity['mention_text']
                #confidence = entity['confidence']
                
                if key == 'line_item':
                    dict_temp[str(key+str(line_item_num))] = text_value
                    line_item_num += 1
                else:
                    dict_temp[key] = text_value
                
                #if 'normalized_value' in results[r]['entities'][e].keys():
                #    normalized_value = entity['normalized_value']['text']
                #    if key == 'line_item':
                #        dict_temp[str(key+str(line_item_num))] = normalized_value
                #        line_item_num += 1
                #    else:
                #        dict_temp[key] = normalized_value
                #else:
                #    if key == 'line_item':
                #        dict_temp[str(key+str(line_item_num))] = text_value
                #        line_item_num += 1
                #    else:
                #        dict_temp[key] = text_value
            
            doc_df = doc_df.append(dict_temp, ignore_index=True)
      

end = time.time()

print(end - start)
# Out:
# Doc 1 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 2 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 3 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 4 out of 19
# The Expected runtime for the parsing is 0.05 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 5 out of 19
# The Expected runtime for the parsing is 0.05 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 6 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 7 out of 19
# The Expected runtime for the parsing is 0.05 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 8 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 9 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 10 out of 19
# The Expected runtime for the parsing is 0.67 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 11 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 12 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 13 out of 19
# The Expected runtime for the parsing is 0.13 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 14 out of 19
# The Expected runtime for the parsing is 0.07 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 15 out of 19
# The Expected runtime for the parsing is 0.07 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 16 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 17 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 18 out of 19
# The Expected runtime for the parsing is 0.05 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 19 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 1 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 2 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 3 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 4 out of 19
# The Expected runtime for the parsing is 0.05 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 5 out of 19
# The Expected runtime for the parsing is 0.05 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 6 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 7 out of 19
# The Expected runtime for the parsing is 0.05 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 8 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 9 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 10 out of 19
# The Expected runtime for the parsing is 0.67 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 11 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 12 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 13 out of 19
# The Expected runtime for the parsing is 0.13 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 14 out of 19
# The Expected runtime for the parsing is 0.07 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 15 out of 19
# The Expected runtime for the parsing is 0.07 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# ...
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 11 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 12 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 13 out of 19
# The Expected runtime for the parsing is 0.13 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 14 out of 19
# The Expected runtime for the parsing is 0.07 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 15 out of 19
# The Expected runtime for the parsing is 0.07 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 16 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 17 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 18 out of 19
# The Expected runtime for the parsing is 0.05 minutes
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# Doc 19 out of 19
# The Expected runtime for the parsing is 0.03 minutes
# 3.914013385772705
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)
# /var/folders/q8/1gf829m141157nbz7kc4_19h00tb0q/T/ipykernel_26080/3590599460.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   doc_df = doc_df.append(dict_temp, ignore_index=True)

# %%
doc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   processor_id           450 non-null    object
#  1   create_date            450 non-null    object
#  2   doc_id                 450 non-null    object
#  3   doc_type               450 non-null    object
#  4   total_amount           175 non-null    object
#  5   supplier_name          159 non-null    object
#  6   invoice_id             95 non-null     object
#  7   currency               101 non-null    object
#  8   remit_to_address       95 non-null     object
#  9   purchase_order         182 non-null    object
#  10  remit_to_name          99 non-null     object
#  11  receiver_name          95 non-null     object
#  12  invoice_date           123 non-null    object
#  13  delivery_date          77 non-null     object
#  14  invoice_type           270 non-null    object
#  15  line_item0             405 non-null    object
#  16  line_item1             395 non-null    object
#  17  line_item2             357 non-null    object
#  18  line_item3             311 non-null    object
#  19  total_tax_amount       281 non-null    object
#  20  net_amount             119 non-null    object
#  21  supplier_tax_id        81 non-null     object
#  22  line_item4             271 non-null    object
#  23  line_item5             257 non-null    object
#  24  line_item6             193 non-null    object
#  25  line_item7             119 non-null    object
#  26  line_item8             87 non-null     object
#  27  line_item9             73 non-null     object
#  28  line_item10            58 non-null     object
#  29  line_item11            54 non-null     object
#  30  receiver_address       76 non-null     object
#  31  supplier_address       78 non-null     object
#  32  supplier_website       76 non-null     object
#  33  receiver_tax_id        144 non-null    object
#  34  due_date               26 non-null     object
#  35  vat                    186 non-null    object
#  36  ship_to_name           36 non-null     object
#  37  carrier                2 non-null      object
#  38  ship_to_address        14 non-null     object
#  39  supplier_iban          134 non-null    object
#  40  freight_amount         172 non-null    object
#  41  supplier_email         18 non-null     object
#  42  supplier_registration  18 non-null     object
# dtypes: object(43)
# memory usage: 151.3+ KB

# %% [markdown]
# ### Data cleanup

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
doc_df.head()
# Out:
#   total_amount               supplier_name  invoice_id currency  \
# 0          107  PENSKE TRUCK LEASING CO LP  0025388645      USD
# 1          107                         NaN         NaN      NaN
# 2       5790.5  PENSKE TRUCK LEASING CO LP  0025242572      USD
# 3       5790.5                         NaN         NaN      NaN
# 4          250  PENSKE TRUCK LEASING CO LP  0025388643      USD
#
#                                     remit_to_address  \
# 0  P.O. BOX 827380\nPHILADELPHIA\nPA\n191827380\n...
# 1                                                NaN
# 2  P.O. BOX 827380\nPHILADELPHIA\nPA\n191827380\n...
# 3                                                NaN
# 4  P.O. BOX 827380\nPHILADELPHIA\nPA\n191827380\n...
#
#                  purchase_order                    remit_to_name  \
# 0  POA-\nWILLIAM_WHITNEY-8\n125  PENSKE TRUCK LEASING CO., L. P.
# 1                           NaN                              NaN
# 2    POA-\nJOSE_MARTINEZ-812\n5  PENSKE TRUCK LEASING CO., L. P.
# 3                           NaN                              NaN
# 4    POA-\nJOSE_CARBAJAL-812\n5  PENSKE TRUCK LEASING CO., L. P.
#
#                            receiver_name invoice_date delivery_date  \
# 0  Mohawk Industries, Inc. (SAP Account)   2023-05-17    2023-05-17
# 1                                    NaN          NaN           NaN
# 2  Mohawk Industries, Inc. (SAP Account)   2023-04-27    2023-04-27
# 3                                    NaN          NaN           NaN
# 4  Mohawk Industries, Inc. (SAP Account)   2023-05-17    2023-05-17
#
#         invoice_type                 line_item0                 line_item1  \
# 0  invoice_statement        1 Each 18.00 18.000        1 Each 18.00 18.000
# 1  invoice_statement        1 Each 17.00 17.000        1 Each 18.00 18.000
# 2  invoice_statement  1 Each 4,683.73 4,683.730  1 Each 1,106.77 1,106.770
# 3  receipt_statement                        NaN                        NaN
# 4  invoice_statement      1 Each 250.00 250.000           2 PARKING SPACES
#
#             line_item2           line_item3 total_tax_amount net_amount  \
# 0               WASHES               WASHES              NaN        NaN
# 1  1 Each 18.00 18.000  1 Each 18.00 18.000                0        107
# 2       382521 TRACTOR       340086 TRACTOR              NaN        NaN
# 3                  NaN                  NaN                0     5790.5
# 4                  NaN                  NaN                0        250
#
#   supplier_tax_id line_item4 line_item5 line_item6 line_item7 line_item8  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1      23-2518618     WASHES     WASHES     WASHES     WASHES        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3      23-2518618        NaN        NaN        NaN        NaN        NaN
# 4      23-2518618        NaN        NaN        NaN        NaN        NaN
#
#   line_item9 line_item10 line_item11 receiver_address supplier_address  \
# 0        NaN         NaN         NaN              NaN              NaN
# 1        NaN         NaN         NaN              NaN              NaN
# 2        NaN         NaN         NaN              NaN              NaN
# 3        NaN         NaN         NaN              NaN              NaN
# 4        NaN         NaN         NaN              NaN              NaN
#
#   supplier_website receiver_tax_id due_date  vat ship_to_name carrier  \
# 0              NaN             NaN      NaN  NaN          NaN     NaN
# 1              NaN             NaN      NaN  NaN          NaN     NaN
# 2              NaN             NaN      NaN  NaN          NaN     NaN
# 3              NaN             NaN      NaN  NaN          NaN     NaN
# 4              NaN             NaN      NaN  NaN          NaN     NaN
#
#   ship_to_address supplier_iban freight_amount supplier_email  \
# 0             NaN           NaN            NaN            NaN
# 1             NaN           NaN            NaN            NaN
# 2             NaN           NaN            NaN            NaN
# 3             NaN           NaN            NaN            NaN
# 4             NaN           NaN            NaN            NaN
#
#   supplier_registration
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
#doc_df.info()

# %%
df_v2 = doc_df[doc_df['processor_id'] == 'fa9b312c4aaa765']
df_v2['confidence'] = df_v2['confidence'].apply(lambda x: x + ((1-x)*.3))
df_v2.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       processor_id          create_date                 doc_id  \
# 0  fa9b312c4aaa765  2023-05-30 18:49:11  thor-docs/2992820.pdf
# 0  fa9b312c4aaa765  2023-05-30 18:49:11  thor-docs/2992820.pdf
# 1  fa9b312c4aaa765  2023-05-30 18:49:11  thor-docs/2992820.pdf
# 2  fa9b312c4aaa765  2023-05-30 18:49:11  thor-docs/2992820.pdf
# 3  fa9b312c4aaa765  2023-05-30 18:49:11  thor-docs/2992820.pdf
#
#           doc_type             label  confidence
# 0  application/pdf        all_labels    0.922956
# 0  application/pdf      total_amount    0.999135
# 1  application/pdf      invoice_date    0.997411
# 2  application/pdf        invoice_id    0.994932
# 3  application/pdf  supplier_address    0.971805

# %% [markdown]
# ## Import data to BQ

# %% [markdown]
# ### Overwrite table

# %%
from google.cloud import bigquery

client = bigquery.Client()

table_id = f'{PROJECT_ID}.{DATASET}.{DOC_SIM_TABLE}'

job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.job.WriteDisposition.WRITE_TRUNCATE
)

job = client.load_table_from_dataframe(
    doc_df, table_id, job_config=job_config
)
job.result()  # Wait for the job to complete.
table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
# Loaded 450 rows and 43 columns to mg-ce-demos.mhwk_docai_demo.invoice_parser_raw

# %% [markdown]
# ### Append to table

# %%
from google.cloud import bigquery

client = bigquery.Client()

table_id = f'{PROJECT_ID}.{DATASET}.{DOC_SIM_TABLE}'

job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.job.WriteDisposition.WRITE_APPEND
)

job = client.load_table_from_dataframe(
    doc_df, table_id, job_config=job_config
)
job.result()  # Wait for the job to complete.
table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)

# %% [markdown]
# # Extras

# %%
#EOF_MARKER = b'%%EOF'

# check if EOF is somewhere else in the file
#if EOF_MARKER in response:
    # we can remove the early %%EOF and put it at the end of the file
#    response = response.replace(EOF_MARKER, b'')
#    response = response + EOF_MARKER
else:
    # Some files really don't have an EOF marker
    # In this case it helped to manually review the end of the file
#    print(response[-8:]) # see last characters at the end of the file
    # printed b'\n%%EO%E'
#    response = response[:-6] + EOF_MARKER

# %% [markdown]
# # Manual upload

# %%
eval_summ_df = pd.DataFrame()

for file in os.listdir("doc_data_sample/"):
    if file.endswith(".json"):
        df = pd.read_json(str('data_eval/' + file))
        df = df.reset_index()
        df = df.rename(columns={'index': 'label'})
        df = df.drop('isFuzzyMatch', axis=1)
        df = pd.concat([df.drop(['metrics'], axis=1), df['metrics'].apply(pd.Series)], axis=1)
        df['id'] = df['processorName'].astype(str) + df['versionName'].astype(str) + df['createTime'].astype(str)

        eval_summ_df = pd.concat([eval_summ_df, df])
eval_summ_df = eval_summ_df.reset_index()

# %%
#df = pd.read_json(str('doc_data_sample/' + 'invoice-example-output.json'))
json_file_path = "doc_data_sample/invoice-example-output.json"

with open(json_file_path, 'r') as j:
     json_data = json.loads(j.read())

# %%
type(json_data)

# %%
json_data.keys()

# %%
for i in json_data['entities']:
    if 'confidence' in i.keys():
        print(i['type'])
        print(i['confidence'])
    else:
        print(i['type'])
        print(0)

# %%
doc_ent_df = pd.DataFrame(columns=['doc_id', 'mimeType', 'text', 'label', 'confidence'])

for i in json_data['entities']:
    if 'confidence' in i.keys():
        row = ['manual_doc_1', json_data['mimeType'], json_data['text'], i['type'], float(i['confidence'])]
        doc_ent_df = doc_ent_df.append(pd.DataFrame([row], columns=['doc_id', 'mimeType', 'text', 'label', 'confidence']), ignore_index=True)
    else:
        row = ['manual_doc_1', json_data['mimeType'], json_data['text'], i['type'], float(0)]
        doc_ent_df = doc_ent_df.append(pd.DataFrame([row], columns=['doc_id', 'mimeType', 'text', 'label', 'confidence']), ignore_index=True)

#doc_ent_df = doc_ent_df[doc_ent_df.confidence != 0]
        
doc_conf_mean = float(doc_ent_df.describe().T.reset_index()['mean'])
final_row = ['manual_doc_1', json_data['mimeType'], json_data['text'], 'all_labels', doc_conf_mean]
doc_ent_df.loc[len(doc_ent_df)] = final_row

#doc_ent_df = doc_ent_df.append(final_row, ignore_index=True)
doc_ent_df

# %%
from google.cloud import bigquery

client = bigquery.Client()

table_id = f'{PROJECT_ID}.{DATASET}.{TABLE}'

job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.job.WriteDisposition.WRITE_TRUNCATE
)

job = client.load_table_from_dataframe(
    doc_ent_df, table_id, job_config=job_config
)
job.result()  # Wait for the job to complete.
table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
